# %%
#Packages
import numpy as np  
import matplotlib.pyplot as plt  
get_ipython().run_line_magic('matplotlib', 'inline')
import pandas as pd  
from apyori import apriori

# %%
#Load data
df_mlt = pd.read_csv('/Users/mtran/Documents/SMUDataSciences/2019-Summer/Diabetic_Cleaned.csv')
print("Finished loading data")
# Out:
# Finished loading data

# %%
#Make dataframes for each column
ordinal = ["age"]
categorical = ["gender", "max_glu_serum", "A1Cresult","diabetesMed"]
medicines = ["insulin"]

# %%
df_mlt_ordinal = df_mlt[ordinal]
df_mlt_categorical = df_mlt[categorical]
df_mlt_medicines = df_mlt[medicines]

# %%
#Make age ordinal
for i in range(0, 10):
    val = "[" + str(i*10) + "-" + str((i+1)*10) + ")"
    df_mlt_ordinal.loc[df_mlt_ordinal['age'] == val, 'age'] = i
# Out:
# C:\Users\mtran\AppData\Local\Continuum\anaconda3\envs\DS7331_Python3.5R\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#Differentiate A1Cresult values from max_glu_serum
df_mlt_categorical.A1Cresult[df_mlt_categorical.A1Cresult == 'None'] = 'A1C None'
df_mlt_categorical.A1Cresult[df_mlt_categorical.A1Cresult == 'Norm'] = 'A1C Norm'
df_mlt_categorical.A1Cresult[df_mlt_categorical.A1Cresult == '>7'] = 'A1C >7'
df_mlt_categorical.A1Cresult[df_mlt_categorical.A1Cresult == '>8'] = 'A1C >8'
df_mlt_categorical.diabetesMed[df_mlt_categorical.diabetesMed == 'No'] = 'DM No'
df_mlt_categorical.diabetesMed[df_mlt_categorical.diabetesMed == 'Yes'] = 'DM Yes'
# Out:
# C:\Users\mtran\AppData\Local\Continuum\anaconda3\envs\DS7331_Python3.5R\lib\site-packages\pandas\core\generic.py:7626: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\mtran\AppData\Local\Continuum\anaconda3\envs\DS7331_Python3.5R\lib\site-packages\IPython\core\interactiveshell.py:2878: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# #### Creating dataframe

# %%
#Creating dataframe
df_mlt_med_x = pd.concat([df_mlt_ordinal, df_mlt_categorical, df_mlt_medicines], axis = 1)
print("Done")
# Out:
# Done

# %%
#Print dataframe
df_mlt_med_x
# Out:
#         age  gender max_glu_serum A1Cresult diabetesMed insulin
# 0         0  Female          None  A1C None       DM No      No
# 1         1  Female          None  A1C None      DM Yes      Up
# 2         2  Female          None  A1C None      DM Yes      No
# 3         3    Male          None  A1C None      DM Yes      Up
# 4         4    Male          None  A1C None      DM Yes  Steady
# 5         5    Male          None  A1C None      DM Yes  Steady
# 6         6    Male          None  A1C None      DM Yes  Steady
# 7         7    Male          None  A1C None      DM Yes      No
# 8         8  Female          None  A1C None      DM Yes  Steady
# 9         9  Female          None  A1C None      DM Yes  Steady
# 10        4  Female          None  A1C None      DM Yes  Steady
# 11        6    Male          None  A1C None      DM Yes  Steady
# 12        4  Female          None  A1C None      DM Yes    Down
# 13        8    Male          None  A1C None      DM Yes  Steady
# 14        6  Female          None  A1C None      DM Yes  Steady
# 15        6    Male          None  A1C None      DM Yes      Up
# 16        5    Male          None  A1C None      DM Yes  Steady
# 17        5  Female          None  A1C None      DM Yes      No
# 18        7    Male          None  A1C None      DM Yes  Steady
# 19        7    Male          None  A1C None      DM Yes  Steady
# 20        5  Female          None  A1C None      DM Yes    Down
# 21        6    Male          None  A1C None      DM Yes  Steady
# 22        7  Female          None  A1C None       DM No      No
# 23        8  Female          None  A1C None       DM No      No
# 24        7  Female          None  A1C None      DM Yes  Steady
# 25        5  Female          None  A1C None      DM Yes      No
# 26        8    Male          None    A1C >7      DM Yes      No
# 27        5  Female          None  A1C None      DM Yes  Steady
# 28        2    Male          None  A1C None      DM Yes    Down
# 29        8  Female          None  A1C None      DM Yes      No
# ...     ...     ...           ...       ...         ...     ...
# 101736    6  Female          None  A1C None      DM Yes    Down
# 101737    4  Female          None  A1C None      DM Yes      No
# 101738    7    Male          None  A1C None      DM Yes  Steady
# 101739    7    Male          None  A1C None      DM Yes    Down
# 101740    4    Male          None  A1C None      DM Yes    Down
# 101741    9    Male          None  A1C None       DM No    Down
# 101742    7    Male          None    A1C >8      DM Yes    Down
# 101743    8    Male          None  A1C None      DM Yes      No
# 101744    8  Female          None  A1C None       DM No      No
# 101745    5    Male          None    A1C >8      DM Yes    Down
# 101746    7    Male          None  A1C None      DM Yes      Up
# 101747    7  Female          None    A1C >7      DM Yes      No
# 101748    4  Female          None    A1C >7      DM Yes    Down
# 101749    7  Female          None  A1C Norm      DM Yes  Steady
# 101750    8  Female          None  A1C None      DM Yes  Steady
# 101751    7    Male          None  A1C Norm      DM Yes      No
# 101752    4  Female          None  A1C None      DM Yes      No
# 101753    4    Male          None  A1C None      DM Yes    Down
# 101754    7  Female          None    A1C >7      DM Yes      No
# 101755    4  Female          None    A1C >8      DM Yes      No
# 101756    6  Female          None  A1C None      DM Yes    Down
# 101757    7  Female          None  A1C None      DM Yes      No
# 101758    8  Female          None  A1C None      DM Yes      No
# 101759    8    Male          None  A1C None      DM Yes      No
# 101760    6  Female          None  A1C None      DM Yes  Steady
# 101761    7    Male          None    A1C >8      DM Yes  Steady
# 101762    8  Female          None  A1C None      DM Yes      No
# 101763    7    Male          None  A1C None      DM Yes      No
# 101764    8  Female          None  A1C None      DM Yes      No
# 101765    7    Male          None  A1C None       DM No    Down
#
# [101766 rows x 6 columns]

# %%
num_records = len(df_mlt_med_x)
print(num_records)
# Out:
# 101766

# %%
# %%time

records = []  
for i in range(0, num_records):  
    records.append([str(df_mlt_med_x.values[i,j]) for j in range(0, 6)])
# Out:
# Wall time: 2h 26min 1s

# %%
# %%time

association_rules = apriori(records, min_support=0.1, min_confidence=0.5, min_lift=1.1, min_length=2)
association_results = list(association_rules)
# Out:
# Wall time: 6.15 s

# %%
print(len(association_results))
# Out:
# 15

# %% [markdown]
# #### Creating dataframe of rules

# %%
# %%time

rules_df = pd.DataFrame(columns=['Rule', 'Support', 'Confidence', 'Lift'])

for item in association_results:
    pair = item[0] 
    items = [x for x in pair]
    rl = str(items[0] + " -> " + items[1])
    sp = str(item[1])
    cf = str(item[2][0][2])
    lf = str(item[2][0][3])
    
    rules_df.loc[len(rules_df), :] = [rl, sp, cf, lf]
# Out:
# Wall time: 67 ms

# %% [markdown]
# #### Print and sort rules by support, and confidence

# %%
#Sort rules descending by Support
rules_df.sort_values(by='Support', ascending=False)
# Out:
#                   Rule         Support      Confidence           Lift
# 2     DM Yes -> Steady  0.215946386809  0.919113341698  1.28713052789
# 1          No -> DM No  0.210286343179  0.735471010757  1.57580358508
# 9     DM Yes -> Steady  0.202945974097  0.915185890903  1.28163050783
# 7           None -> No  0.197285930468  0.725875845114  1.55524519978
# 4       A1C None -> No   0.18365662402  0.741990551431  1.58977220576
# 5   A1C None -> DM Yes  0.173849812315  0.915545435728  1.28213401605
# 11    A1C None -> None  0.171638857772  0.731694034853  1.56771112177
# 12  A1C None -> DM Yes  0.161311243441  0.910482529118  1.27504389847
# 8     DM Yes -> Steady  0.117013540868  0.920176184221  1.28861893742
# 6         No -> Female  0.115569050567  0.737505486925   1.5801626078
# 14    DM Yes -> Steady   0.10970265118  0.915982934033  1.28274669068
# 13          None -> No  0.108464516636   0.72790820364  1.55959968528
# 3         None -> Male  0.107717705324  0.509268292683  1.10139617624
# 0          8 -> Female  0.103325275632  0.611443856487   1.1373251357
# 10      A1C None -> No  0.101340329776   0.74215601612  1.59012672667

# %%
#Sort rules descending by confidence
rules_df.sort_values(by='Confidence', ascending=False)
# Out:
#                   Rule         Support      Confidence           Lift
# 8     DM Yes -> Steady  0.117013540868  0.920176184221  1.28861893742
# 2     DM Yes -> Steady  0.215946386809  0.919113341698  1.28713052789
# 14    DM Yes -> Steady   0.10970265118  0.915982934033  1.28274669068
# 5   A1C None -> DM Yes  0.173849812315  0.915545435728  1.28213401605
# 9     DM Yes -> Steady  0.202945974097  0.915185890903  1.28163050783
# 12  A1C None -> DM Yes  0.161311243441  0.910482529118  1.27504389847
# 10      A1C None -> No  0.101340329776   0.74215601612  1.59012672667
# 4       A1C None -> No   0.18365662402  0.741990551431  1.58977220576
# 6         No -> Female  0.115569050567  0.737505486925   1.5801626078
# 1          No -> DM No  0.210286343179  0.735471010757  1.57580358508
# 11    A1C None -> None  0.171638857772  0.731694034853  1.56771112177
# 13          None -> No  0.108464516636   0.72790820364  1.55959968528
# 7           None -> No  0.197285930468  0.725875845114  1.55524519978
# 0          8 -> Female  0.103325275632  0.611443856487   1.1373251357
# 3         None -> Male  0.107717705324  0.509268292683  1.10139617624
