# %%
import pandas as pd
import numpy as np
import matplotlib as plt
get_ipython().run_line_magic('matplotlib','inline')
import Orange
from apyori import apriori
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d06d02e222ea> in <module>
#       3 import matplotlib as plt
#       4 get_ipython().run_line_magic('matplotlib','inline')
# ----> 5 import Orange
#       6 from apyori import apriori
#
# ModuleNotFoundError: No module named 'Orange'

# %%
df_mlt = pd.read_csv('/Users/mtran/Documents/SMUDataSciences/2019-Summer/Diabetic_Cleaned.csv')
print("Finished loading data")
# Out:
# Finished loading data

# %%
#Make data frames
ordinal = ["age"]
categorical = ["gender","max_glu_serum","A1Cresult","diabetesMed"]
medicines = ["insulin"]

# %%
df_mlt_ordinal = df_mlt[ordinal]
df_mlt_categorical = df_mlt[categorical]
df_mlt_medicines = df_mlt[medicines]

# %%
#Make age ordinal
for i in range(0,10):
    val = "[" + str(i*10) + "-" + str((i+1)*10) + ")"
    df_mlt_ordinal.loc[df_mlt_ordinal['age']==val,'age'] = i
# Out:
# C:\Users\mtran\AppData\Local\Continuum\anaconda3\envs\DS7331_Python3.5R\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\mtran\AppData\Local\Continuum\anaconda3\envs\DS7331_Python3.5R\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_mlt_med_x = pd.concat([df_mlt_ordinal, df_mlt_categorical, df_mlt_medicines], axis = 1)
print("Done")
# Out:
# Done

# %%
df_mlt_med_x
# Out:
#              age  gender max_glu_serum A1Cresult diabetesMed insulin
# 0         [0-10)  Female          None      None          No      No
# 1        [10-20)  Female          None      None         Yes      Up
# 2        [20-30)  Female          None      None         Yes      No
# 3        [30-40)    Male          None      None         Yes      Up
# 4        [40-50)    Male          None      None         Yes  Steady
# 5        [50-60)    Male          None      None         Yes  Steady
# 6        [60-70)    Male          None      None         Yes  Steady
# 7        [70-80)    Male          None      None         Yes      No
# 8        [80-90)  Female          None      None         Yes  Steady
# 9       [90-100)  Female          None      None         Yes  Steady
# 10       [40-50)  Female          None      None         Yes  Steady
# 11       [60-70)    Male          None      None         Yes  Steady
# 12       [40-50)  Female          None      None         Yes    Down
# 13       [80-90)    Male          None      None         Yes  Steady
# 14       [60-70)  Female          None      None         Yes  Steady
# 15       [60-70)    Male          None      None         Yes      Up
# 16       [50-60)    Male          None      None         Yes  Steady
# 17       [50-60)  Female          None      None         Yes      No
# 18       [70-80)    Male          None      None         Yes  Steady
# 19       [70-80)    Male          None      None         Yes  Steady
# 20       [50-60)  Female          None      None         Yes    Down
# 21       [60-70)    Male          None      None         Yes  Steady
# 22       [70-80)  Female          None      None          No      No
# 23       [80-90)  Female          None      None          No      No
# 24       [70-80)  Female          None      None         Yes  Steady
# 25       [50-60)  Female          None      None         Yes      No
# 26       [80-90)    Male          None        >7         Yes      No
# 27       [50-60)  Female          None      None         Yes  Steady
# 28       [20-30)    Male          None      None         Yes    Down
# 29       [80-90)  Female          None      None         Yes      No
# ...          ...     ...           ...       ...         ...     ...
# 101736   [60-70)  Female          None      None         Yes    Down
# 101737   [40-50)  Female          None      None         Yes      No
# 101738   [70-80)    Male          None      None         Yes  Steady
# 101739   [70-80)    Male          None      None         Yes    Down
# 101740   [40-50)    Male          None      None         Yes    Down
# 101741  [90-100)    Male          None      None          No    Down
# 101742   [70-80)    Male          None        >8         Yes    Down
# 101743   [80-90)    Male          None      None         Yes      No
# 101744   [80-90)  Female          None      None          No      No
# 101745   [50-60)    Male          None        >8         Yes    Down
# 101746   [70-80)    Male          None      None         Yes      Up
# 101747   [70-80)  Female          None        >7         Yes      No
# 101748   [40-50)  Female          None        >7         Yes    Down
# 101749   [70-80)  Female          None      Norm         Yes  Steady
# 101750   [80-90)  Female          None      None         Yes  Steady
# 101751   [70-80)    Male          None      Norm         Yes      No
# 101752   [40-50)  Female          None      None         Yes      No
# 101753   [40-50)    Male          None      None         Yes    Down
# 101754   [70-80)  Female          None        >7         Yes      No
# 101755   [40-50)  Female          None        >8         Yes      No
# 101756   [60-70)  Female          None      None         Yes    Down
# 101757   [70-80)  Female          None      None         Yes      No
# 101758   [80-90)  Female          None      None         Yes      No
# 101759   [80-90)    Male          None      None         Yes      No
# 101760   [60-70)  Female          None      None         Yes  Steady
# 101761   [70-80)    Male          None        >8         Yes  Steady
# 101762   [80-90)  Female          None      None         Yes      No
# 101763   [70-80)    Male          None      None         Yes      No
# 101764   [80-90)  Female          None      None         Yes      No
# 101765   [70-80)    Male          None      None          No    Down
#
# [101766 rows x 6 columns]

# %%
data = Orange.data.Table("df_mlt_med_x")

rules = Orange.associate.AssociationRulesSparseInducer(data, support = 0.5)

print "%5s %5s" % ("Support", "Conf")
for r in rules:
    print "%5.3f  %5.3f" % (r.support, r.confidence, r)
# Out:
# SystemErrorTraceback (most recent call last)
# <ipython-input-24-2afa694c3d7b> in <module>()
# ----> 1 data = Orange.data.Table("df_mlt_med_x")
#       2
#       3 rules = Orange.associate.AssociationRulesSparseInducer(data, support = 0.5)
#       4
#       5 print "%5s %5s" % ("Support", "Conf")
#
# SystemError: file 'df_mlt_med_x' is not found or has unknown extension

# %%
inducer = Orange.associate.AssociationRulesSparseInducer(support = 0.5, store_examples = True)
itemsets = inducer.get_itemsets(data)
