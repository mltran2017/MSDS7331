# %% [markdown]
# ## Support Vector Machines (SVM) models

# %%
#diabetes df
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score

#this code below is to make %%time magic work
import glob
import os
from __future__ import print_function
#this code above is to make %%time magic work

# %%
#import the data
directory = 'C:/Users/N1110/Desktop/7331_Project/data/'
df = pd.read_csv(directory + 'Diabetes_tmp_Cleaned.csv')
df_clean = df
df_clean.replace('?', np.nan, inplace=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 51 columns):
# encounter_id                101766 non-null int64
# patient_nbr                 101766 non-null int64
# race                        101766 non-null object
# gender                      101766 non-null object
# age                         101766 non-null object
# admission_type_id           101766 non-null int64
# discharge_disposition_id    101766 non-null int64
# admission_source_id         101766 non-null int64
# time_in_hospital            101766 non-null int64
# medical_specialty           101766 non-null object
# num_lab_procedures          101766 non-null int64
# num_procedures              101766 non-null int64
# num_medications             101766 non-null int64
# number_outpatient           101766 non-null int64
# number_emergency            101766 non-null int64
# number_inpatient            101766 non-null int64
# number_diagnoses            101766 non-null int64
# max_glu_serum               101766 non-null object
# A1Cresult                   101766 non-null object
# metformin                   101766 non-null object
# repaglinide                 101766 non-null object
# nateglinide                 101766 non-null object
# chlorpropamide              101766 non-null object
# glimepiride                 101766 non-null object
# acetohexamide               101766 non-null object
# glipizide                   101766 non-null object
# glyburide                   101766 non-null object
# tolbutamide                 101766 non-null object
# pioglitazone                101766 non-null object
# rosiglitazone               101766 non-null object
# acarbose                    101766 non-null object
# miglitol                    101766 non-null object
# troglitazone                101766 non-null object
# tolazamide                  101766 non-null object
# insulin                     101766 non-null object
# glyburide-metformin         101766 non-null object
# glipizide-metformin         101766 non-null object
# metformin-rosiglitazone     101766 non-null object
# metformin-pioglitazone      101766 non-null object
# change                      101766 non-null object
# diabetesMed                 101766 non-null object
# readmitted                  101766 non-null object
# diag_1_val                  101766 non-null object
# diag_2_val                  101766 non-null object
# diag_3_val                  101766 non-null object
# readmitted_tf               101766 non-null int64
# medication_count            101766 non-null int64
# admission_source            95783 non-null object
# discharge_disposition       98086 non-null object
# admission_type              97684 non-null object
# meds_increased              101766 non-null int64
# dtypes: int64(16), object(35)
# memory usage: 39.6+ MB

# %% [markdown]
# ### Data preprocessing and feature engineering

# %%
#we found num_lab_procedures is highly correlated with admission_type_id during EDA. So we would exclude one of them in our model.
#check the describe of some of the categorical variables
df_clean[['age','gender','race','diag_1_val','diag_2_val',"admission_source","admission_type","discharge_disposition","insulin"]].describe().transpose()
# Out:
#                    count unique                 top   freq
# age               101766     10             [70-80)  26068
# gender            101766      2              Female  54711
# race              101766      6           Caucasian  76099
# diag_1_val        101766     10         Circulatory  30437
# diag_2_val        101766     10         Circulatory  31881
# admission_source   95783     14  Physician Referral  36269
# admission_type     97684      7           Emergency  32219
# insulin           101766      4                  No  47497

# %% [markdown]
# Because the gender attribute binary, there is no need to encode it using OneHotEncoding. We can just convert it to an integer.
# age can be coded into int since it is ordinal.(see the 'age_range ' varaible in the example nb on titanic.csv)
# However, we should transform the race, diag_1_val attributes to take on different values--one for each possible variable outcome.
# (one hot encoding is all about making the euclid distances even among levels of features.)
#
# preparing the data for SVM ideally including the following steps in the sequence: one hot encoding, normalize (to make the features contribute equally in euclid distance), PCA, use principle comp for SVM.
#
# refer to this paper for more info on FE.
# https://media.licdn.com/dms/document/C4D1FAQGdKsBchRiF7A/feedshare-document-pdf-analyzed/0?e=1560106800&v=beta&t=toMignhoXC9PRfpoHkzKawyxUSjSCMeZJnBsoPn_SUo
# this paper also mentioned log feature help with the skewness.

# %%
#can also use binary encoder to achieve this
df_clean.gender[df_clean.gender == 'Male'] = 0
df_clean.gender[df_clean.gender == 'Female'] = 1

df_clean["gender"] = df_clean["gender"].astype(int)

# %%
#10 age groups; Ordinal encoding
#feature density plot of age can help with answering the question like: does people older age tend to be readmitted?
#can use map/apply function to achieve this

df_clean.age[df_clean.age== '[0-10)'] = 1
df_clean.age[df_clean.age== '[10-20)'] = 2
df_clean.age[df_clean.age== '[20-30)'] = 3
df_clean.age[df_clean.age== '[30-40)'] = 4
df_clean.age[df_clean.age== '[40-50)'] = 5
df_clean.age[df_clean.age== '[50-60)'] = 6
df_clean.age[df_clean.age== '[60-70)'] = 7
df_clean.age[df_clean.age== '[70-80)'] = 8
df_clean.age[df_clean.age== '[80-90)'] = 9
df_clean.age[df_clean.age== '[90-100)'] = 10

df_clean["age"] = df_clean["age"].astype(int)

# %%
#one hot encoding categorical variables

#FE based on Feature Importance plot from LR model

#add more important features: discharge_disposition_id, admission_source_id. I think they should be categorical, so I put them in dummy list


dummiesList=["diag_1_val","diag_2_val","diag_3_val","race","A1Cresult","admission_type","insulin","admission_source","discharge_disposition"]
df_clean_wDummies = pd.get_dummies(df_clean[dummiesList])

# %%
#combine with numerical features we decide to use and target readmitted_tf

NumFeatures=["num_lab_procedures","number_outpatient","number_emergency", "number_inpatient", "medication_count","number_diagnoses", "gender","age","readmitted_tf"]
df_clean_wDummies= pd.concat((df_clean_wDummies, df_clean[NumFeatures]), axis=1)

# %%
if 'Lnumber_emergency' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_emergency'] # if 'number_emergency' column still exists, delete it (as we created an ismale column)
if 'Lnum_diagnoses' in df_clean_wDummies:
    del df_clean_wDummies['Lnum_diagnoses']
if 'Lnumber_outpatient' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_outpatient']    
    
if 'Lnum_lab_procedures' in df_clean_wDummies:
    del df_clean_wDummies['Lnum_lab_procedures'] 
if 'Lnumber_inpatient' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_inpatient']

# %%
    
df_clean_wDummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 99 columns):
# diag_1_val_Circulatory                                                                                                             101766 non-null uint8
# diag_1_val_Diabeties                                                                                                               101766 non-null uint8
# diag_1_val_Digestive                                                                                                               101766 non-null uint8
# diag_1_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_1_val_Injury                                                                                                                  101766 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_1_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_1_val_None                                                                                                                    101766 non-null uint8
# diag_1_val_Other                                                                                                                   101766 non-null uint8
# diag_1_val_Respiratory                                                                                                             101766 non-null uint8
# diag_2_val_Circulatory                                                                                                             101766 non-null uint8
# diag_2_val_Diabeties                                                                                                               101766 non-null uint8
# diag_2_val_Digestive                                                                                                               101766 non-null uint8
# diag_2_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_2_val_Injury                                                                                                                  101766 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_2_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_2_val_None                                                                                                                    101766 non-null uint8
# diag_2_val_Other                                                                                                                   101766 non-null uint8
# diag_2_val_Respiratory                                                                                                             101766 non-null uint8
# diag_3_val_Circulatory                                                                                                             101766 non-null uint8
# diag_3_val_Diabeties                                                                                                               101766 non-null uint8
# diag_3_val_Digestive                                                                                                               101766 non-null uint8
# diag_3_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_3_val_Injury                                                                                                                  101766 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_3_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_3_val_None                                                                                                                    101766 non-null uint8
# diag_3_val_Other                                                                                                                   101766 non-null uint8
# diag_3_val_Respiratory                                                                                                             101766 non-null uint8
# race_AfricanAmerican                                                                                                               101766 non-null uint8
# race_Asian                                                                                                                         101766 non-null uint8
# race_Caucasian                                                                                                                     101766 non-null uint8
# race_Hispanic                                                                                                                      101766 non-null uint8
# race_Other                                                                                                                         101766 non-null uint8
# race_Unspecified                                                                                                                   101766 non-null uint8
# A1Cresult_>7                                                                                                                       101766 non-null uint8
# A1Cresult_>8                                                                                                                       101766 non-null uint8
# A1Cresult_None                                                                                                                     101766 non-null uint8
# A1Cresult_Norm                                                                                                                     101766 non-null uint8
# admission_type_Elective                                                                                                            101766 non-null uint8
# admission_type_Emergency                                                                                                           101766 non-null uint8
# admission_type_Newborn                                                                                                             101766 non-null uint8
# admission_type_Not Available                                                                                                       101766 non-null uint8
# admission_type_Not Mapped                                                                                                          101766 non-null uint8
# admission_type_Trauma Center                                                                                                       101766 non-null uint8
# admission_type_Urgent                                                                                                              101766 non-null uint8
# insulin_Down                                                                                                                       101766 non-null uint8
# insulin_No                                                                                                                         101766 non-null uint8
# insulin_Steady                                                                                                                     101766 non-null uint8
# insulin_Up                                                                                                                         101766 non-null uint8
# admission_source_Clinic Referral                                                                                                   101766 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             101766 non-null uint8
# admission_source_Emergency Room                                                                                                    101766 non-null uint8
# admission_source_Extramural Birth                                                                                                  101766 non-null uint8
# admission_source_HMO Referral                                                                                                      101766 non-null uint8
# admission_source_Not Available                                                                                                     101766 non-null uint8
# admission_source_Not Mapped                                                                                                        101766 non-null uint8
# admission_source_Physician Referral                                                                                                101766 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           101766 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    101766 non-null uint8
# admission_source_Transfer from a hospital                                                                                          101766 non-null uint8
# admission_source_Transfer from another health care facility                                                                        101766 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            101766 non-null uint8
# admission_source_Transfer from hospital inpt/same fac reslt in a sep claim                                                         101766 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    101766 non-null uint8
# discharge_disposition_Discharged to home                                                                                           101766 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to a federal health care facility.                                                    101766 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         101766 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      101766 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             101766 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        101766 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         101766 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      101766 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  101766 non-null uint8
# discharge_disposition_Expired                                                                                                      101766 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     101766 non-null uint8
# discharge_disposition_Expired in a medical facility. Medicaid only, hospice.                                                       101766 non-null uint8
# discharge_disposition_Hospice / home                                                                                               101766 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   101766 non-null uint8
# discharge_disposition_Left AMA                                                                                                     101766 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                101766 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   101766 non-null uint8
# discharge_disposition_Still patient or expected to return for outpatient services                                                  101766 non-null uint8
# num_lab_procedures                                                                                                                 101766 non-null int64
# number_outpatient                                                                                                                  101766 non-null int64
# number_emergency                                                                                                                   101766 non-null int64
# number_inpatient                                                                                                                   101766 non-null int64
# medication_count                                                                                                                   101766 non-null int64
# number_diagnoses                                                                                                                   101766 non-null int64
# gender                                                                                                                             101766 non-null int32
# age                                                                                                                                101766 non-null int32
# readmitted_tf                                                                                                                      101766 non-null int64
# dtypes: int32(2), int64(7), uint8(90)
# memory usage: 14.9 MB

# %%
#take a look of cleaned dataset before feed to model
#df_clean_wDummies.info()

# %%
df_imputed=df_clean_wDummies


from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'readmitted_tf' in df_imputed:
    y = df_imputed['readmitted_tf'].values # get the labels we want
    del df_imputed['readmitted_tf'] # get rid of the class label
    X = df_imputed.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
## Training and Testing Split
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

# %%
    # we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()

scl_obj.fit(X_train)
X_test_scaled = scl_obj.transform(X_test)

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)
# Out:
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#14 min run for SVC
# lets investigate SVMs on the data and play with the parameters and kernels
#%%time

from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

#acc = mt.accuracy_score(y_test,y_hat)
#conf = mt.confusion_matrix(y_test,y_hat)
#print('accuracy:', acc )
#print(conf)

# %%
#resume what did not run from last cell

from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)

#accuracy: 0.6822246241525007
#[[9460 1446]
# [5022 4426]]
# Out:
# accuracy: 0.6822246241525007
# [[9460 1446]
#  [5022 4426]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (58526, 98)
# (58526,)
# [29717 28809]

# %%
# Now let's do some different analysis with the SVM and look at the instances that were chosen as support vectors

# now lets look at the support for the vectors and see if we they are indicative of anything
# grabe the rows that were selected as support vectors (these are usually instances that are hard to classify)

# make a dataframe of the training data
df_tested_on = df_imputed.iloc[train_indices] # saved from above, the indices chosen for training
# now get the support vectors from the trained model
df_support = df_tested_on.iloc[svm_clf.support_,:]

df_support['readmitted_tf'] = y[svm_clf.support_] # add back in the 'Survived' Column to the pandas dataframe
df_imputed['readmitted_tf'] = y # also add it back in for the original data
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58526 entries, 20868 to 68322
# Data columns (total 99 columns):
# diag_1_val_Circulatory                                                                                                             58526 non-null uint8
# diag_1_val_Diabeties                                                                                                               58526 non-null uint8
# diag_1_val_Digestive                                                                                                               58526 non-null uint8
# diag_1_val_Genitourinary                                                                                                           58526 non-null uint8
# diag_1_val_Injury                                                                                                                  58526 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         58526 non-null uint8
# diag_1_val_Neoplasms                                                                                                               58526 non-null uint8
# diag_1_val_None                                                                                                                    58526 non-null uint8
# diag_1_val_Other                                                                                                                   58526 non-null uint8
# diag_1_val_Respiratory                                                                                                             58526 non-null uint8
# diag_2_val_Circulatory                                                                                                             58526 non-null uint8
# diag_2_val_Diabeties                                                                                                               58526 non-null uint8
# diag_2_val_Digestive                                                                                                               58526 non-null uint8
# diag_2_val_Genitourinary                                                                                                           58526 non-null uint8
# diag_2_val_Injury                                                                                                                  58526 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         58526 non-null uint8
# diag_2_val_Neoplasms                                                                                                               58526 non-null uint8
# diag_2_val_None                                                                                                                    58526 non-null uint8
# diag_2_val_Other                                                                                                                   58526 non-null uint8
# diag_2_val_Respiratory                                                                                                             58526 non-null uint8
# diag_3_val_Circulatory                                                                                                             58526 non-null uint8
# diag_3_val_Diabeties                                                                                                               58526 non-null uint8
# diag_3_val_Digestive                                                                                                               58526 non-null uint8
# diag_3_val_Genitourinary                                                                                                           58526 non-null uint8
# diag_3_val_Injury                                                                                                                  58526 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         58526 non-null uint8
# diag_3_val_Neoplasms                                                                                                               58526 non-null uint8
# diag_3_val_None                                                                                                                    58526 non-null uint8
# diag_3_val_Other                                                                                                                   58526 non-null uint8
# diag_3_val_Respiratory                                                                                                             58526 non-null uint8
# race_AfricanAmerican                                                                                                               58526 non-null uint8
# race_Asian                                                                                                                         58526 non-null uint8
# race_Caucasian                                                                                                                     58526 non-null uint8
# race_Hispanic                                                                                                                      58526 non-null uint8
# race_Other                                                                                                                         58526 non-null uint8
# race_Unspecified                                                                                                                   58526 non-null uint8
# A1Cresult_>7                                                                                                                       58526 non-null uint8
# A1Cresult_>8                                                                                                                       58526 non-null uint8
# A1Cresult_None                                                                                                                     58526 non-null uint8
# A1Cresult_Norm                                                                                                                     58526 non-null uint8
# admission_type_Elective                                                                                                            58526 non-null uint8
# admission_type_Emergency                                                                                                           58526 non-null uint8
# admission_type_Newborn                                                                                                             58526 non-null uint8
# admission_type_Not Available                                                                                                       58526 non-null uint8
# admission_type_Not Mapped                                                                                                          58526 non-null uint8
# admission_type_Trauma Center                                                                                                       58526 non-null uint8
# admission_type_Urgent                                                                                                              58526 non-null uint8
# insulin_Down                                                                                                                       58526 non-null uint8
# insulin_No                                                                                                                         58526 non-null uint8
# insulin_Steady                                                                                                                     58526 non-null uint8
# insulin_Up                                                                                                                         58526 non-null uint8
# admission_source_Clinic Referral                                                                                                   58526 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             58526 non-null uint8
# admission_source_Emergency Room                                                                                                    58526 non-null uint8
# admission_source_Extramural Birth                                                                                                  58526 non-null uint8
# admission_source_HMO Referral                                                                                                      58526 non-null uint8
# admission_source_Not Available                                                                                                     58526 non-null uint8
# admission_source_Not Mapped                                                                                                        58526 non-null uint8
# admission_source_Physician Referral                                                                                                58526 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           58526 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    58526 non-null uint8
# admission_source_Transfer from a hospital                                                                                          58526 non-null uint8
# admission_source_Transfer from another health care facility                                                                        58526 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            58526 non-null uint8
# admission_source_Transfer from hospital inpt/same fac reslt in a sep claim                                                         58526 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    58526 non-null uint8
# discharge_disposition_Discharged to home                                                                                           58526 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                58526 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                58526 non-null uint8
# discharge_disposition_Discharged/transferred to a federal health care facility.                                                    58526 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         58526 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      58526 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             58526 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        58526 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         58526 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                58526 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      58526 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                58526 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  58526 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    58526 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  58526 non-null uint8
# discharge_disposition_Expired                                                                                                      58526 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     58526 non-null uint8
# discharge_disposition_Expired in a medical facility. Medicaid only, hospice.                                                       58526 non-null uint8
# discharge_disposition_Hospice / home                                                                                               58526 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   58526 non-null uint8
# discharge_disposition_Left AMA                                                                                                     58526 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                58526 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   58526 non-null uint8
# discharge_disposition_Still patient or expected to return for outpatient services                                                  58526 non-null uint8
# num_lab_procedures                                                                                                                 58526 non-null int64
# number_outpatient                                                                                                                  58526 non-null int64
# number_emergency                                                                                                                   58526 non-null int64
# number_inpatient                                                                                                                   58526 non-null int64
# medication_count                                                                                                                   58526 non-null int64
# number_diagnoses                                                                                                                   58526 non-null int64
# gender                                                                                                                             58526 non-null int32
# age                                                                                                                                58526 non-null int32
# readmitted_tf                                                                                                                      58526 non-null int64
# dtypes: int32(2), int64(7), uint8(90)
# memory usage: 9.0 MB

# %%
# now lets see the statistics of these attributes
from pandas.tools.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['readmitted_tf'])
df_grouped = df_imputed.groupby(['readmitted_tf'])

# plot KDE of Different variables
vars_to_plot = ['age','gender','num_lab_procedures','medication_count']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Original)')

# %% [markdown]
# ## Interpret Support Vectors
# ## Look at the chosen support vectors for the classification task. Do these provide any insight into the data? Explain.
#
# The feature density plots above show the comparison of the support vectors(left) and the the original feature(right).
#
# The feature density plots of age and medication_count vector are very similare to the original ones, showing the support vectors are the most useful data points that they represent the data structure of original data so well.
#
# When looking at gender vectors, it has similar to the original on readmitted_1 group but it has lower values in readmitted_0 group at gender 0 (male) comparing to the original data.
#
# When looking at num_lab_procedures vectors, it has similar to the original on readmitted_0 group but it has higher values in readmitted_1 group comparing to the original data.

# %% [markdown]
# ## Try linear kernel for SVM
# #### Run linear kernel once to show that has lower accuracy for our dataset.  The reason can be seen from PCA plots. PCA plots here show our data is not linearaly separable.  (We did not reduce dimensions in this case, so we did not create a scree plot.)

# %%
#did not update every time, just run once to show that linear kernel has lower accuracy in our data.
#try linear kernel, 25 mins run , ACC worse
#more feature engineering can be done to improve the acc

from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='linear', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)
#print("Done")

# %%
from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)

#accuracy: 0.614031639972487
#[[9672 1312]
# [6544 2826]]
# Out:
# accuracy: 0.614031639972487
# [[9672 1312]
#  [6544 2826]]

# %% [markdown]
# ### Create PCA plot to see if our dataset is linearaly separable

# %%
#reduce dimensionality of data set to 2 feauters.
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(X_train)
pca_2d = pca.transform(X_train)
#print("Done")

# %%
#part of the code was taken from:
#http://www.dummies.com/programming/big-data/data-science/how-to-visualize-the-classifier-in-an-svm-supervised-learning-model/
import pylab as pl
plt.figure(figsize=(20,15))
for i in range(0, pca_2d.shape[0]):
    if y_train[i] == 0:
        c1 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='r', s=1,marker='+')
    elif y_train[i] == 1:
        c2 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='g', s=20,marker='*')
pl.legend([c1, c2], ['Not readmitted', 'Readmitted'])
pl.title('Diabetes data set')
pl.show()

# %% [markdown]
# #### The PCA plot below is for dataset with log transfromation of numerical variables. From these plots we can see, log transfromation of numerical variables change the look of pca plot siginficantly. Both PCA plots show our data is not linearaly separable.

# %%
from IPython.display import Image
Image(filename='C:/Users/N1110/Desktop/PCAwithLog.png')

# %% [markdown]
# ## Runtime comparsion of SVM vs. SVM_SGD
# From the results below, we can see SVM_SGD runs 1000X faster than SVM, from 14 mins in SVM to 708 ms in SVM_SGD. SGD does help the SVM model to trian in a reasonable timeframe.

# %%
# %%time

#SGD made SVM model train fast. this was done in seconds comparing with no SGD 14 mins run.
from sklearn.model_selection import StratifiedShuffleSplit 
from sklearn import metrics as mt
cv = StratifiedShuffleSplit( n_splits=1,test_size=0.5)
# use some compact notation for creating a linear SVM classifier with stichastic descent
from sklearn.linear_model import SGDClassifier

regularize_const = 0.1
iterations = 5
svm_sgd = SGDClassifier(alpha=regularize_const,
        fit_intercept=True, l1_ratio=0.0, learning_rate='optimal',
        loss='hinge', n_iter=iterations, n_jobs=-1, penalty='l2')

scl = StandardScaler()
for train_idx, test_idx in cv.split(X,y):
    svm_sgd.fit(scl.fit_transform(X[train_idx]),y[train_idx])
    yhat = svm_sgd.predict(scl.transform(X[test_idx]))
    
    conf = mt.confusion_matrix(y[test_idx],yhat)
    acc = mt.accuracy_score(y[test_idx],yhat)

print('SVM_SGD:', acc)
# Out:
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SVM_SGD: 0.655405538195468
# Wall time: 708 ms
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Accuracies Comparsion among SVM models:
# #### A number of models were built to explore on the effect of log transformation of numerical variables and feature engineering. We did not include the code for all of them, but we summarize the performances of all models below.
#
#
# ## Model Accuracies Comparsion table
# #### Original try 2 (basic model without log num - baseline demo)
# SVM-rbf kernel: 0.6293111919033114
# SVM-linear kernel: 0.614031639972487 (so decide to use rbf in future models, all SVM below refer to rbf kernel)
# SVM_SGD:0.6098500481496767
#
# #### MiniLab 1 SVM LJ try 2 updated with log num
# SVM: 0.6202711997641741
# SVM_SGD: 0.6136627164278836
#
# #### MiniLab 1 SVM LJ try 3 with log num add more features to increase acc
# SVM: 0.6526481281320625
# SVM_SGD: 0.6361849733702808
#
# #### MiniLab 1 SVM LJ try 4 without log num add more features to increase acc
# SVM:0.6588876879237496
# SVM_SGD: 0.6337480101409115
#
# #### MiniLab 1 SVM LJ try 5 without log num and add even more features based on Feature Importance Plot from LR
# SVM: 0.6822246241525007   *
# SVM_SGD: 0.655405538195468
# (* indicates the best accuracy we got in SVM models so far)
#
#
# ## Conclusions
#
# #### First, SVM in general yields better accuracy than SVM_SGD at the cost of one thousand times longer running time.
#
# #### The accuracy is siginficantly better after feature engineering, accuracy change from 0.6293111919033114 to 0.6822246241525007. See the Model Accuracies Comparsion table above.
#
# #### We also explored the effect of log transfromation of numerical variables. Since there is no assumption on normal distribution of data in SVM (the only assumption as I understand is independent and identical distributed data) , I could not justify about the log transfromation of numerical variables, so I run a few tests. The results shown below indicate log transformation of numerical variables do not help with the accuracy of SVM (actually reduce the accuracy of SVM a little bit) but help improving the accuracy of SVM_SGD slightly (need more repeatation of resampling -- different split of train and test dataset, to confirm).
#
# #### Last but not least, we also include a section of Hyper parameters tuning for SVM below, in order to adjust the parameters of the models to make them more accurate.

# %% [markdown]
# ## Hyper parameters tuning with GridSearchCV for SVM
# ####  c and gammas, GridSearchCV
# https://medium.com/@aneesha/svm-parameter-tuning-in-scikit-learn-using-gridsearchcv-2413c02125a0

# %%
from sklearn import svm, grid_search
from sklearn.model_selection import GridSearchCV

#for the sake of time, to make the run time reasonable, I used only 3 different values for C and 2 different values for gammas.
#runtime this way 3*2*3*10 mins=3hr
#otherwise it would take more than ten hours to run

def svc_param_selection(X, y, nfolds):
    Cs = [0.01, 0.5, 1]
    gammas = [0.1, 1]
    param_grid = {'C': Cs, 'gamma' : gammas}
    grid_search = GridSearchCV(svm.SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, y)
    grid_search.best_params_
    return grid_search.best_params_
# Out:
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#tried running for an hour and aborted
#svc_param_selection(X_train_scaled, y_train,10)

# %% [markdown]
# ### Make GridSearchCV faster
# I started with nfolds=10 and it took very long to run, so I did a research on how to make it efficient. I found some discussion in the below link, and decide to revise nfolds to 3 in future:
# https://stackoverflow.com/questions/35655701/is-there-a-quicker-way-of-running-gridsearchcv
# "10-fold CV is overkill and causes you to fit 10 models for each parameter group. You can get an instant 2-3x speedup by switching to 5- or 3-fold CV (i.e., cv=3 in the GridSearchCV call) without any meaningful difference in performance estimation"

# %%
# run for 3-4 hrs
svc_param_selection(X_train_scaled, y_train,3)
#out : c=1, gamma=0.1

# %% [markdown]
# ### After we got the ouput from from svc_param_selection() function (c=1, gammas=0.1), we try run a SVM model with these parameters.

# %%
#try SVM with parameters from svc_param_selection() function output c=1, gammas=0.1
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=1, kernel='rbf', degree=3, gamma=0.1) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

# %%
from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)  

#c=1, gamma=0.1, yield accuracy: 0.6151125085978186
# [[7836 3246]
# [4588 4684]]

# %% [markdown]
# ### SVM with parameters from svc_param_selection() function output c=1, gammas=0.1 yield accuracy: 0.6151125085978186. It make sense it is not as good as our base model with parameters C=0.5, gamma='auto' which gave the accuracy of 0.6822246241525007, because we only give very limited choice of values in the Cs and gammas list in svc_param_selection() function for the sake of time.  Due to the limited time we have, we just demo the method to tune the parameters here.

# %% [markdown]
# ## Subsampling for SVM_SGD
# We subsample 20% of our data and train the SVM_SGD again. We got pretty decent accuracy of 0.6720707442888725 comparing with the 0.6822246241525007 accuracy we got for the full dataset. Then we plot feature density again.
#
# The major advantage of doing so is used 46 seconds instead of 20 mins, so it is about 20 x faster.
#
#
# In addition, we summarize more findings here and attach the code with sections label below.
#
# ### SVM_SGD with subsampling
# SVM_SGD with subsampling is extremely fast (194ms) and little be less accurate than coressponding SVM, but still a decent accuracy - 0.6555959516556942.
#
#
# ### GridSearchCV with subsampling
# We experimented a few thing on GridSearchCV with subsampling and found it greatly reduce the runtime for GridSearchCV. This property may make it potentially helpful on doing GridSearchCV though we may need to read research papers to confirm it.
#
# First try of GridSearchCV with subsampling with smaller parameter list showed the step of calling svc_param_selection() which takes about 4 hours for the full dataset, only took 20 mins to run on subsample, which is 1/8 of time. Also, it gave the same result as the whole dataset GridSearchCV.
#
# When we tried SVM with parameters from svc_param_selection() function output c=1, gammas=0.1, it took only 1.6 mins comparing with the same thing with full dataset took about 40 mins+ to run.  However, the parameters it found did not give very high accuracy due to very limited choices of parameters, a little be worse than the fulldataset. Despite of low accuracy (0.6040284942274625) it yields, we can see the trend if the accuracy is improving from GridSearchCV with subsampling. So, it is still very useful.
#
# Based on the finding that GridSearchCV with subsampling gave a more reasonable run time and similar results, we tried GridSearchCV with subsampling with larger parameter list. It took 1h 15min 50s to run a 5 values for C and 4 values for gamma svc_param_selection() function with the outcome of {'C': 1, 'gamma': 0.01}. The prediction time - 41.1 seconds, is significantly shorter. The accuracy (0.672316384180791) increased a lot comparing with last SVM with parameters from last svc_param_selection() function call with smaller parameter list of parameters. We believe when we train the data with more complete list of parameters, we can keep improving the performance of model. However, due to the limit time for this project, we just stop here with a demostration of how to do GridSearchCV with subsampling.

# %%
directory = 'C:/Users/N1110/Desktop/7331_Project/data/'
df = pd.read_csv(directory + 'Diabetes_tmp_Cleaned.csv')
df_clean = df
df_clean.replace('?', np.nan, inplace=True)

subsam_df_clean=df_clean.sample(frac=0.2)

# %%
subsam_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20353 entries, 31184 to 53351
# Data columns (total 51 columns):
# encounter_id                20353 non-null int64
# patient_nbr                 20353 non-null int64
# race                        20353 non-null object
# gender                      20353 non-null object
# age                         20353 non-null object
# admission_type_id           20353 non-null int64
# discharge_disposition_id    20353 non-null int64
# admission_source_id         20353 non-null int64
# time_in_hospital            20353 non-null int64
# medical_specialty           20353 non-null object
# num_lab_procedures          20353 non-null int64
# num_procedures              20353 non-null int64
# num_medications             20353 non-null int64
# number_outpatient           20353 non-null int64
# number_emergency            20353 non-null int64
# number_inpatient            20353 non-null int64
# number_diagnoses            20353 non-null int64
# max_glu_serum               20353 non-null object
# A1Cresult                   20353 non-null object
# metformin                   20353 non-null object
# repaglinide                 20353 non-null object
# nateglinide                 20353 non-null object
# chlorpropamide              20353 non-null object
# glimepiride                 20353 non-null object
# acetohexamide               20353 non-null object
# glipizide                   20353 non-null object
# glyburide                   20353 non-null object
# tolbutamide                 20353 non-null object
# pioglitazone                20353 non-null object
# rosiglitazone               20353 non-null object
# acarbose                    20353 non-null object
# miglitol                    20353 non-null object
# troglitazone                20353 non-null object
# tolazamide                  20353 non-null object
# insulin                     20353 non-null object
# glyburide-metformin         20353 non-null object
# glipizide-metformin         20353 non-null object
# metformin-rosiglitazone     20353 non-null object
# metformin-pioglitazone      20353 non-null object
# change                      20353 non-null object
# diabetesMed                 20353 non-null object
# readmitted                  20353 non-null object
# diag_1_val                  20353 non-null object
# diag_2_val                  20353 non-null object
# diag_3_val                  20353 non-null object
# readmitted_tf               20353 non-null int64
# medication_count            20353 non-null int64
# admission_source            19163 non-null object
# discharge_disposition       19629 non-null object
# admission_type              19500 non-null object
# meds_increased              20353 non-null int64
# dtypes: int64(16), object(35)
# memory usage: 8.1+ MB

# %%
df_clean=subsam_df_clean
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20353 entries, 31184 to 53351
# Data columns (total 51 columns):
# encounter_id                20353 non-null int64
# patient_nbr                 20353 non-null int64
# race                        20353 non-null object
# gender                      20353 non-null object
# age                         20353 non-null object
# admission_type_id           20353 non-null int64
# discharge_disposition_id    20353 non-null int64
# admission_source_id         20353 non-null int64
# time_in_hospital            20353 non-null int64
# medical_specialty           20353 non-null object
# num_lab_procedures          20353 non-null int64
# num_procedures              20353 non-null int64
# num_medications             20353 non-null int64
# number_outpatient           20353 non-null int64
# number_emergency            20353 non-null int64
# number_inpatient            20353 non-null int64
# number_diagnoses            20353 non-null int64
# max_glu_serum               20353 non-null object
# A1Cresult                   20353 non-null object
# metformin                   20353 non-null object
# repaglinide                 20353 non-null object
# nateglinide                 20353 non-null object
# chlorpropamide              20353 non-null object
# glimepiride                 20353 non-null object
# acetohexamide               20353 non-null object
# glipizide                   20353 non-null object
# glyburide                   20353 non-null object
# tolbutamide                 20353 non-null object
# pioglitazone                20353 non-null object
# rosiglitazone               20353 non-null object
# acarbose                    20353 non-null object
# miglitol                    20353 non-null object
# troglitazone                20353 non-null object
# tolazamide                  20353 non-null object
# insulin                     20353 non-null object
# glyburide-metformin         20353 non-null object
# glipizide-metformin         20353 non-null object
# metformin-rosiglitazone     20353 non-null object
# metformin-pioglitazone      20353 non-null object
# change                      20353 non-null object
# diabetesMed                 20353 non-null object
# readmitted                  20353 non-null object
# diag_1_val                  20353 non-null object
# diag_2_val                  20353 non-null object
# diag_3_val                  20353 non-null object
# readmitted_tf               20353 non-null int64
# medication_count            20353 non-null int64
# admission_source            19163 non-null object
# discharge_disposition       19629 non-null object
# admission_type              19500 non-null object
# meds_increased              20353 non-null int64
# dtypes: int64(16), object(35)
# memory usage: 8.1+ MB

# %%
#Data preprocessing and feature engineering
#should make a def
#can also use binary encoder to achieve this
df_clean.gender[df_clean.gender == 'Male'] = 0
df_clean.gender[df_clean.gender == 'Female'] = 1

df_clean["gender"] = df_clean["gender"].astype(int)

#10 age groups; Ordinal encoding
#feature density plot of age can help with answering the question like: does people older age tend to be readmitted?
#can use map/apply function to achieve this

df_clean.age[df_clean.age== '[0-10)'] = 1
df_clean.age[df_clean.age== '[10-20)'] = 2
df_clean.age[df_clean.age== '[20-30)'] = 3
df_clean.age[df_clean.age== '[30-40)'] = 4
df_clean.age[df_clean.age== '[40-50)'] = 5
df_clean.age[df_clean.age== '[50-60)'] = 6
df_clean.age[df_clean.age== '[60-70)'] = 7
df_clean.age[df_clean.age== '[70-80)'] = 8
df_clean.age[df_clean.age== '[80-90)'] = 9
df_clean.age[df_clean.age== '[90-100)'] = 10

df_clean["age"] = df_clean["age"].astype(int)

#one hot encoding categorical variables

#FE based on Feature Importance plot from LR model

#add more important features: discharge_disposition_id, admission_source_id. I think they should be categorical, so I put them in dummy list


dummiesList=["diag_1_val","diag_2_val","diag_3_val","race","A1Cresult","admission_type","insulin","admission_source","discharge_disposition"]
df_clean_wDummies = pd.get_dummies(df_clean[dummiesList])


#combine with numerical features we decide to use and target readmitted_tf

NumFeatures=["num_lab_procedures","number_outpatient","number_emergency", "number_inpatient", "medication_count","number_diagnoses", "gender","age","readmitted_tf"]
df_clean_wDummies= pd.concat((df_clean_wDummies, df_clean[NumFeatures]), axis=1)

df_clean_wDummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20353 entries, 31184 to 53351
# Data columns (total 94 columns):
# diag_1_val_Circulatory                                                                                                             20353 non-null uint8
# diag_1_val_Diabeties                                                                                                               20353 non-null uint8
# diag_1_val_Digestive                                                                                                               20353 non-null uint8
# diag_1_val_Genitourinary                                                                                                           20353 non-null uint8
# diag_1_val_Injury                                                                                                                  20353 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         20353 non-null uint8
# diag_1_val_Neoplasms                                                                                                               20353 non-null uint8
# diag_1_val_None                                                                                                                    20353 non-null uint8
# diag_1_val_Other                                                                                                                   20353 non-null uint8
# diag_1_val_Respiratory                                                                                                             20353 non-null uint8
# diag_2_val_Circulatory                                                                                                             20353 non-null uint8
# diag_2_val_Diabeties                                                                                                               20353 non-null uint8
# diag_2_val_Digestive                                                                                                               20353 non-null uint8
# diag_2_val_Genitourinary                                                                                                           20353 non-null uint8
# diag_2_val_Injury                                                                                                                  20353 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         20353 non-null uint8
# diag_2_val_Neoplasms                                                                                                               20353 non-null uint8
# diag_2_val_None                                                                                                                    20353 non-null uint8
# diag_2_val_Other                                                                                                                   20353 non-null uint8
# diag_2_val_Respiratory                                                                                                             20353 non-null uint8
# diag_3_val_Circulatory                                                                                                             20353 non-null uint8
# diag_3_val_Diabeties                                                                                                               20353 non-null uint8
# diag_3_val_Digestive                                                                                                               20353 non-null uint8
# diag_3_val_Genitourinary                                                                                                           20353 non-null uint8
# diag_3_val_Injury                                                                                                                  20353 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         20353 non-null uint8
# diag_3_val_Neoplasms                                                                                                               20353 non-null uint8
# diag_3_val_None                                                                                                                    20353 non-null uint8
# diag_3_val_Other                                                                                                                   20353 non-null uint8
# diag_3_val_Respiratory                                                                                                             20353 non-null uint8
# race_AfricanAmerican                                                                                                               20353 non-null uint8
# race_Asian                                                                                                                         20353 non-null uint8
# race_Caucasian                                                                                                                     20353 non-null uint8
# race_Hispanic                                                                                                                      20353 non-null uint8
# race_Other                                                                                                                         20353 non-null uint8
# race_Unspecified                                                                                                                   20353 non-null uint8
# A1Cresult_>7                                                                                                                       20353 non-null uint8
# A1Cresult_>8                                                                                                                       20353 non-null uint8
# A1Cresult_None                                                                                                                     20353 non-null uint8
# A1Cresult_Norm                                                                                                                     20353 non-null uint8
# admission_type_Elective                                                                                                            20353 non-null uint8
# admission_type_Emergency                                                                                                           20353 non-null uint8
# admission_type_Newborn                                                                                                             20353 non-null uint8
# admission_type_Not Available                                                                                                       20353 non-null uint8
# admission_type_Not Mapped                                                                                                          20353 non-null uint8
# admission_type_Trauma Center                                                                                                       20353 non-null uint8
# admission_type_Urgent                                                                                                              20353 non-null uint8
# insulin_Down                                                                                                                       20353 non-null uint8
# insulin_No                                                                                                                         20353 non-null uint8
# insulin_Steady                                                                                                                     20353 non-null uint8
# insulin_Up                                                                                                                         20353 non-null uint8
# admission_source_Clinic Referral                                                                                                   20353 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             20353 non-null uint8
# admission_source_Emergency Room                                                                                                    20353 non-null uint8
# admission_source_HMO Referral                                                                                                      20353 non-null uint8
# admission_source_Not Available                                                                                                     20353 non-null uint8
# admission_source_Not Mapped                                                                                                        20353 non-null uint8
# admission_source_Physician Referral                                                                                                20353 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           20353 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    20353 non-null uint8
# admission_source_Transfer from a hospital                                                                                          20353 non-null uint8
# admission_source_Transfer from another health care facility                                                                        20353 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            20353 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    20353 non-null uint8
# discharge_disposition_Discharged to home                                                                                           20353 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                20353 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                20353 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         20353 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      20353 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             20353 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        20353 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         20353 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                20353 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      20353 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                20353 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  20353 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    20353 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  20353 non-null uint8
# discharge_disposition_Expired                                                                                                      20353 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     20353 non-null uint8
# discharge_disposition_Hospice / home                                                                                               20353 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   20353 non-null uint8
# discharge_disposition_Left AMA                                                                                                     20353 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                20353 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   20353 non-null uint8
# num_lab_procedures                                                                                                                 20353 non-null int64
# number_outpatient                                                                                                                  20353 non-null int64
# number_emergency                                                                                                                   20353 non-null int64
# number_inpatient                                                                                                                   20353 non-null int64
# medication_count                                                                                                                   20353 non-null int64
# number_diagnoses                                                                                                                   20353 non-null int64
# gender                                                                                                                             20353 non-null int32
# age                                                                                                                                20353 non-null int32
# readmitted_tf                                                                                                                      20353 non-null int64
# dtypes: int32(2), int64(7), uint8(85)
# memory usage: 3.0 MB

# %%
df_imputed=df_clean_wDummies


from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'readmitted_tf' in df_imputed:
    y = df_imputed['readmitted_tf'].values # get the labels we want
    del df_imputed['readmitted_tf'] # get rid of the class label
    X = df_imputed.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
## Training and Testing Split
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

    # we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()

scl_obj.fit(X_train)
X_test_scaled = scl_obj.transform(X_test)

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)
# Out:
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# estimate 4 mins
# actual 46 seconds
# lets investigate SVMs on the data and play with the parameters and kernels
#%%time

from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

# %%
from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# accuracy: 0.6720707442888725
# [[1955  303]
#  [1032  781]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (12398, 93)
# (12398,)
# [6352 6046]

# %%
# Now let's do some different analysis with the SVM and look at the instances that were chosen as support vectors

# now lets look at the support for the vectors and see if we they are indicative of anything
# grabe the rows that were selected as support vectors (these are usually instances that are hard to classify)

# make a dataframe of the training data
df_tested_on = df_imputed.iloc[train_indices] # saved from above, the indices chosen for training
# now get the support vectors from the trained model
df_support = df_tested_on.iloc[svm_clf.support_,:]

df_support['readmitted_tf'] = y[svm_clf.support_] # add back in the 'Survived' Column to the pandas dataframe
df_imputed['readmitted_tf'] = y # also add it back in for the original data
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12398 entries, 41478 to 19815
# Data columns (total 94 columns):
# diag_1_val_Circulatory                                                                                                             12398 non-null uint8
# diag_1_val_Diabeties                                                                                                               12398 non-null uint8
# diag_1_val_Digestive                                                                                                               12398 non-null uint8
# diag_1_val_Genitourinary                                                                                                           12398 non-null uint8
# diag_1_val_Injury                                                                                                                  12398 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         12398 non-null uint8
# diag_1_val_Neoplasms                                                                                                               12398 non-null uint8
# diag_1_val_None                                                                                                                    12398 non-null uint8
# diag_1_val_Other                                                                                                                   12398 non-null uint8
# diag_1_val_Respiratory                                                                                                             12398 non-null uint8
# diag_2_val_Circulatory                                                                                                             12398 non-null uint8
# diag_2_val_Diabeties                                                                                                               12398 non-null uint8
# diag_2_val_Digestive                                                                                                               12398 non-null uint8
# diag_2_val_Genitourinary                                                                                                           12398 non-null uint8
# diag_2_val_Injury                                                                                                                  12398 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         12398 non-null uint8
# diag_2_val_Neoplasms                                                                                                               12398 non-null uint8
# diag_2_val_None                                                                                                                    12398 non-null uint8
# diag_2_val_Other                                                                                                                   12398 non-null uint8
# diag_2_val_Respiratory                                                                                                             12398 non-null uint8
# diag_3_val_Circulatory                                                                                                             12398 non-null uint8
# diag_3_val_Diabeties                                                                                                               12398 non-null uint8
# diag_3_val_Digestive                                                                                                               12398 non-null uint8
# diag_3_val_Genitourinary                                                                                                           12398 non-null uint8
# diag_3_val_Injury                                                                                                                  12398 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         12398 non-null uint8
# diag_3_val_Neoplasms                                                                                                               12398 non-null uint8
# diag_3_val_None                                                                                                                    12398 non-null uint8
# diag_3_val_Other                                                                                                                   12398 non-null uint8
# diag_3_val_Respiratory                                                                                                             12398 non-null uint8
# race_AfricanAmerican                                                                                                               12398 non-null uint8
# race_Asian                                                                                                                         12398 non-null uint8
# race_Caucasian                                                                                                                     12398 non-null uint8
# race_Hispanic                                                                                                                      12398 non-null uint8
# race_Other                                                                                                                         12398 non-null uint8
# race_Unspecified                                                                                                                   12398 non-null uint8
# A1Cresult_>7                                                                                                                       12398 non-null uint8
# A1Cresult_>8                                                                                                                       12398 non-null uint8
# A1Cresult_None                                                                                                                     12398 non-null uint8
# A1Cresult_Norm                                                                                                                     12398 non-null uint8
# admission_type_Elective                                                                                                            12398 non-null uint8
# admission_type_Emergency                                                                                                           12398 non-null uint8
# admission_type_Newborn                                                                                                             12398 non-null uint8
# admission_type_Not Available                                                                                                       12398 non-null uint8
# admission_type_Not Mapped                                                                                                          12398 non-null uint8
# admission_type_Trauma Center                                                                                                       12398 non-null uint8
# admission_type_Urgent                                                                                                              12398 non-null uint8
# insulin_Down                                                                                                                       12398 non-null uint8
# insulin_No                                                                                                                         12398 non-null uint8
# insulin_Steady                                                                                                                     12398 non-null uint8
# insulin_Up                                                                                                                         12398 non-null uint8
# admission_source_Clinic Referral                                                                                                   12398 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             12398 non-null uint8
# admission_source_Emergency Room                                                                                                    12398 non-null uint8
# admission_source_HMO Referral                                                                                                      12398 non-null uint8
# admission_source_Not Available                                                                                                     12398 non-null uint8
# admission_source_Not Mapped                                                                                                        12398 non-null uint8
# admission_source_Physician Referral                                                                                                12398 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           12398 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    12398 non-null uint8
# admission_source_Transfer from a hospital                                                                                          12398 non-null uint8
# admission_source_Transfer from another health care facility                                                                        12398 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            12398 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    12398 non-null uint8
# discharge_disposition_Discharged to home                                                                                           12398 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                12398 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                12398 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         12398 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      12398 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             12398 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        12398 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         12398 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                12398 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      12398 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                12398 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  12398 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    12398 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  12398 non-null uint8
# discharge_disposition_Expired                                                                                                      12398 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     12398 non-null uint8
# discharge_disposition_Hospice / home                                                                                               12398 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   12398 non-null uint8
# discharge_disposition_Left AMA                                                                                                     12398 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                12398 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   12398 non-null uint8
# num_lab_procedures                                                                                                                 12398 non-null int64
# number_outpatient                                                                                                                  12398 non-null int64
# number_emergency                                                                                                                   12398 non-null int64
# number_inpatient                                                                                                                   12398 non-null int64
# medication_count                                                                                                                   12398 non-null int64
# number_diagnoses                                                                                                                   12398 non-null int64
# gender                                                                                                                             12398 non-null int32
# age                                                                                                                                12398 non-null int32
# readmitted_tf                                                                                                                      12398 non-null int64
# dtypes: int32(2), int64(7), uint8(85)
# memory usage: 1.9 MB

# %%
# now lets see the statistics of these attributes
from pandas.tools.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['readmitted_tf'])
df_grouped = df_imputed.groupby(['readmitted_tf'])

# plot KDE of Different variables
vars_to_plot = ['age','gender','num_lab_procedures','medication_count']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Original)')

# %% [markdown]
# ## Interpret Support Vectors
# The plots above show the comparison of the support vectors(left) and the the original feature(right).
#
# The feature density plots show the support vectors look a little bit worse than the full dataset, but still represent the data structure of original data well.
#
# The feature density plots of age and medication_count vector are very similare to the original ones, showing the support vectors are the most useful data points that they represent the data structure of original data so well.
#
# When looking at gender vectors, it has similar to the original on readmitted_1 group but it has lower values in readmitted_0 group at gender 0 (male) comparing to the original data.
#
# When looking at num_lab_procedures vectors, it has similar to the original on readmitted_0 group but it has higher values in readmitted_1 group comparing to the original data.

# %% [markdown]
# ### SVM_SGD with subsampling
# fast and little be less accurate than coressponding SVM.

# %%
# %%time

#SGD made SVM model train fast. this was done in seconds comparing with no SGD 14 mins run.
from sklearn.model_selection import StratifiedShuffleSplit 
from sklearn import metrics as mt
cv = StratifiedShuffleSplit( n_splits=1,test_size=0.5)
# use some compact notation for creating a linear SVM classifier with stichastic descent
from sklearn.linear_model import SGDClassifier

regularize_const = 0.1
iterations = 5
svm_sgd = SGDClassifier(alpha=regularize_const,
        fit_intercept=True, l1_ratio=0.0, learning_rate='optimal',
        loss='hinge', n_iter=iterations, n_jobs=-1, penalty='l2')

scl = StandardScaler()
for train_idx, test_idx in cv.split(X,y):
    svm_sgd.fit(scl.fit_transform(X[train_idx]),y[train_idx])
    yhat = svm_sgd.predict(scl.transform(X[test_idx]))
    
    conf = mt.confusion_matrix(y[test_idx],yhat)
    acc = mt.accuracy_score(y[test_idx],yhat)

print('SVM_SGD:', acc)
# Out:
# SVM_SGD: 0.6555959516556942
# Wall time: 194 ms
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### GridSearchCV with subsampling
# #### First try of GridSearchCV with subsampling with smaller parameter list

# %%
#GridSearchCV on subsample
from sklearn import svm, grid_search
from sklearn.model_selection import GridSearchCV

#for the sake of time, to make the run time reasonable, I used only 3 different values for C and 2 different values for gammas.
#runtime this way 3*2*3*10 mins=3hr
#otherwise it would take more than ten hours to run

def svc_param_selection(X, y, nfolds):
    Cs = [0.01, 0.5, 1]
    gammas = [0.1, 1]
    param_grid = {'C': Cs, 'gamma' : gammas}
    grid_search = GridSearchCV(svm.SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, y)
    grid_search.best_params_
    return grid_search.best_params_
# Out:
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\N1110\Anaconda3\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#20 min
# %%time
svc_param_selection(X_train_scaled, y_train,3)
#{'C': 1, 'gamma': 0.1}
# Out:
# {'C': 1, 'gamma': 0.1}

# %%
#1.6 mins
# %%time
#try SVM with parameters from svc_param_selection() function output c=1, gammas=0.1
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=1, kernel='rbf', degree=3, gamma=0.1) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# accuracy: 0.6040284942274625
# [[1775  483]
#  [1129  684]]

# %% [markdown]
# ### Try GridSearchCV with subsampling with larger parameter list

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm, grid_search
def svc_param_selection(X, y, nfolds):
    Cs = [0.001, 0.01, 0.1, 1, 10]
    gammas = [0.001, 0.01, 0.1, 1]
    param_grid = {'C': Cs, 'gamma' : gammas}
    grid_search = GridSearchCV(svm.SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, y)
    grid_search.best_params_
    return grid_search.best_params_

# %%
#estimation 1 hr
#actual time
# %%time
svc_param_selection(X_train_scaled, y_train,3)

#Wall time: 1h 15min 50s
#Out[55]:
#{'C': 1, 'gamma': 0.01}
# Out:
# Wall time: 1h 15min 50s
# {'C': 1, 'gamma': 0.01}

# %%
# %%time
#try SVM with parameters from svc_param_selection() function output c=1, gammas=0.1
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=1, kernel='rbf', degree=3, gamma=0.01) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)  

#accuracy: 0.672316384180791
#[[1890  368]
# [ 966  847]]
#Wall time: 41.1 s
# Out:
# accuracy: 0.672316384180791
# [[1890  368]
#  [ 966  847]]
# Wall time: 41.1 s
