# %%
#diabetes df
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
import ipywidgets
from ipywidgets import widgets as wd
import sklearn
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn import metrics as mt
from sklearn import preprocessing
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline

# %%
df_mlt = pd.read_csv('/Users/mtran/Documents/SMUDataSciences/2019-Summer/MiniLab/Diabetic_Cleaned.csv')
print("Finished loading data")
# Out:
# Finished loading data

# %%
#make dataframes for each column
ordinal = ["age", "time_in_hospital"]
categorical = ["race", "gender", "admission_type_id", "discharge_disposition_id", "admission_source_id", "medical_specialty", "max_glu_serum", "A1Cresult", "change", "diabetesMed", "diag_1_val", "diag_2_val", "diag_3_val", "meds_increased"]
continuous = ["num_lab_procedures", "num_procedures", "num_medications", "number_outpatient", "number_emergency", "number_inpatient", "number_diagnoses", "medication_count"]
medicines = ["metformin", "repaglinide", "nateglinide", "chlorpropamide", "glimepiride", "acetohexamide", "glipizide", "glyburide", "tolbutamide", "pioglitazone", "rosiglitazone", "acarbose", "miglitol", "troglitazone", "tolazamide", "insulin", "glyburide-metformin", "glipizide-metformin", "metformin-rosiglitazone", "metformin-pioglitazone"]
response = ["readmitted_tf"]

# %%
df_mlt_ordinal = df_mlt[ordinal]
df_mlt_categorical = df_mlt[categorical]
df_mlt_continuous = df_mlt[continuous]
df_mlt_medicines = df_mlt[medicines]
df_mlt_response = df_mlt[response]

# %%
#Make age ordinal
for i in range(0, 10):
    val = "[" + str(i*10) + "-" + str((i+1)*10) + ")"
    df_mlt_ordinal.loc[df_mlt_ordinal['age'] == val, 'age'] = i

# %%
#Make all categorical columns categorical
df_mlt_categorical['admission_type_id'] = df_mlt_categorical['admission_type_id'].astype(object)
df_mlt_categorical['discharge_disposition_id'] = df_mlt_categorical['discharge_disposition_id'].astype(object)
df_mlt_categorical['admission_source_id'] = df_mlt_categorical['admission_source_id'].astype(object)
df_mlt_categorical['admission_type_id'] = df_mlt_categorical['admission_type_id'].astype(object)
df_mlt_categorical['meds_increased'] = df_mlt_categorical['meds_increased'].astype(object)
print("Done")
# Out:
# Done

# %%
#Attempted to log all numerical columns ---ended up with only taking the log for 3

#medication_count contains 0
#df_mlt_continuous["medication_count"][df_mlt_continuous["medication_count"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["medication_count"]=np.nan
#df_mlt_continuous["medication_count"]=np.log(df_mlt_continuous["medication_count"])

#num_lab_procedures
df_mlt_continuous["num_lab_procedures"][df_mlt_continuous["num_lab_procedures"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["num_lab_procedures"]=np.nan
df_mlt_continuous["num_lab_procedures"]=np.log(df_mlt_continuous["num_lab_procedures"])

#num_medications
df_mlt_continuous["num_medications"][df_mlt_continuous["num_medications"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["num_medications"]=np.nan
df_mlt_continuous["num_medications"]=np.log(df_mlt_continuous["num_medications"])

#num_procedures contains 0
#df_mlt_continuous["num_procedures"][df_mlt_continuous["num_procedures"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["num_procedures"]=np.nan
#df_mlt_continuous["num_procedures"]=np.log(df_mlt_continuous["num_procedures"])

#num_diagnoses
df_mlt_continuous["number_diagnoses"][df_mlt_continuous["number_diagnoses"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["number_diagnoses"]=np.nan
df_mlt_continuous["number_diagnoses"]=np.log(df_mlt_continuous["number_diagnoses"])

#number_emergency contains 0
#df_mlt_continuous["number_emergency"][df_mlt_continuous["number_emergency"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["number_emergency"]=np.nan
#df_mlt_continuous["number_emergency"]=np.log(df_mlt_continuous["number_emergency"])

#number_inpatient contains 0
#df_mlt_continuous["number_inpatient"][df_mlt_continuous["number_inpatient"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["number_inpatient"]=np.nan
#df_mlt_continuous["number_inpatient"]=np.log(df_mlt_continuous["number_inpatient"])

#number_outpatient contains 0
#df_mlt_continuous["number_outpatient"][df_mlt_continuous["number_outpatient"]==0]=0.0001 #add small value to 0
#df_mlt_continuous["number_outpatient"]=np.nan
#df_mlt_continuous["number_outpatient"]=np.log(df_mlt_continuous["number_outpatient"])


#Inital attempt to log all numerical values
#df_mlt_continuous['lmedication_count'] = np.log(df_mlt_continuous["medication_count"])
#df_mlt_continuous['lnum_lab_procedures'] = np.log(df_mlt_continuous["num_lab_procedures"])
#df_mlt_continuous['lnum_medications'] = np.log(df_mlt_continuous["num_medications"])
#df_mlt_continuous['lnum_procedures'] = np.log(df_mlt_continuous["num_procedures"])
#df_mlt_continuous['lnumber_diagnoses'] = np.log(df_mlt_continuous["number_diagnoses"])
#df_mlt_continuous['lnumber_emergency'] = np.log(df_mlt_continuous["number_emergency"])
#df_mlt_continuous['lnumber_inpatient'] = np.log(df_mlt_continuous["number_inpatient"])
#df_mlt_continuous['lnumber_outpatient'] = np.log(df_mlt_continuous["number_outpatient"])

#df_mlt_lcontinuous = pd.concat((df_mlt_continuous['lmedication_count'],df_mlt_continuous['lnum_lab_procedures'],
                            #df_mlt_continuous['lnum_medications'],df_mlt_continuous['lnum_procedures'],
                            #df_mlt_continuous['lnumber_diagnoses'],df_mlt_continuous['lnumber_emergency'],
                            #df_mlt_continuous['lnumber_inpatient'],df_mlt_continuous['lnumber_outpatient']),axis=1)
print("Done")
# Out:
# Done

# %%
#Creating X and Y dataframes
df_mlt_x = pd.concat([df_mlt_ordinal, df_mlt_categorical, df_mlt_continuous], axis = 1)
df_mlt_med_x = pd.concat([df_mlt_ordinal, df_mlt_categorical, df_mlt_continuous, df_mlt_medicines], axis = 1)
df_mlt_hot_x = pd.concat([df_mlt_ordinal, pd.get_dummies(df_mlt_categorical), df_mlt_continuous], axis = 1)
df_mlt_hot_med_x = pd.concat([df_mlt_ordinal, pd.get_dummies(df_mlt_categorical), df_mlt_continuous, pd.get_dummies(df_mlt_medicines)], axis = 1)
df_mlt_y = df_mlt_response
print("Done")
# Out:
# Done

# %%
df_mlt_hot = pd.concat([df_mlt_hot_x,df_mlt_y], axis=1)
df_mlt_hot.dtypes
# Out:
# age                              int64
# time_in_hospital                 int64
# race_AfricanAmerican             uint8
# race_Asian                       uint8
# race_Caucasian                   uint8
# race_Hispanic                    uint8
# race_Other                       uint8
# race_Unspecified                 uint8
# gender_Female                    uint8
# gender_Male                      uint8
# admission_type_id_1              uint8
# admission_type_id_2              uint8
# admission_type_id_3              uint8
# admission_type_id_4              uint8
# admission_type_id_5              uint8
# admission_type_id_6              uint8
# admission_type_id_7              uint8
# admission_type_id_8              uint8
# discharge_disposition_id_1       uint8
# discharge_disposition_id_2       uint8
# discharge_disposition_id_3       uint8
# discharge_disposition_id_4       uint8
# discharge_disposition_id_5       uint8
# discharge_disposition_id_6       uint8
# discharge_disposition_id_7       uint8
# discharge_disposition_id_8       uint8
# discharge_disposition_id_9       uint8
# discharge_disposition_id_10      uint8
# discharge_disposition_id_11      uint8
# discharge_disposition_id_12      uint8
#                                 ...
# diag_2_val_Diabeties             uint8
# diag_2_val_Digestive             uint8
# diag_2_val_Genitourinary         uint8
# diag_2_val_Injury                uint8
# diag_2_val_Musculoskeletal       uint8
# diag_2_val_Neoplasms             uint8
# diag_2_val_None                  uint8
# diag_2_val_Other                 uint8
# diag_2_val_Respiratory           uint8
# diag_3_val_Circulatory           uint8
# diag_3_val_Diabeties             uint8
# diag_3_val_Digestive             uint8
# diag_3_val_Genitourinary         uint8
# diag_3_val_Injury                uint8
# diag_3_val_Musculoskeletal       uint8
# diag_3_val_Neoplasms             uint8
# diag_3_val_None                  uint8
# diag_3_val_Other                 uint8
# diag_3_val_Respiratory           uint8
# meds_increased_0                 uint8
# meds_increased_1                 uint8
# num_lab_procedures             float64
# num_procedures                   int64
# num_medications                float64
# number_outpatient                int64
# number_emergency                 int64
# number_inpatient                 int64
# number_diagnoses               float64
# medication_count                 int64
# readmitted_tf                    int64
# Length: 185, dtype: object

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'readmitted_tf' in df_mlt_hot:
    y = df_mlt_hot['readmitted_tf'].values # get the labels we want
    del df_mlt_hot['readmitted_tf'] # get rid of the class label
    X = df_mlt_hot.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
#Model 5 - Log of 3 numericals: num_lab_procedures, num_medications, number_diagnoses

# create a reusable logisitic regression object
# here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None) # get object

iter_num=0
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

# train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("Model 5 - Accuracy:", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
# Out:
# ====Iteration 0  ====
# Model 5 - Accuracy: 0.6824211457207429
# confusion matrix
#  [[9015 2007]
#  [4457 4875]]
# ====Iteration 1  ====
# Model 5 - Accuracy: 0.67844158396384
# confusion matrix
#  [[9090 1978]
#  [4567 4719]]
# ====Iteration 2  ====
# Model 5 - Accuracy: 0.672496806524516
# confusion matrix
#  [[8975 1974]
#  [4692 4713]]

# %%
# here we can change some of the parameters interactively
from ipywidgets import widgets as wd

def lr_explor(cost):
    lr_clf = LogisticRegression(penalty='l2', C=cost, class_weight=None) # get object
    accuracies = cross_val_score(lr_clf,X,y=y,cv=cv_object) # this also can help with parallelism
    print(accuracies)

wd.interact(lr_explor,cost=(0.001,5.0,0.05),__manual=True)
# Out:
# [0.67677115 0.67583767 0.67922767]
# <function __main__.lr_explor(cost)>

# %%
# interpret the weights

# iterate over the coefficients
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = df_mlt_hot.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
# Out:
# age has weight of 0.04731127614415876
# time_in_hospital has weight of -0.003749388119503901
# race_AfricanAmerican has weight of 0.07067534360227264
# race_Asian has weight of -0.23391856221234328
# race_Caucasian has weight of 0.12857540919644345
# race_Hispanic has weight of 0.0011226485070554232
# race_Other has weight of -0.10868759572177894
# race_Unspecified has weight of -0.3206967636991189
# gender_Female has weight of -0.1966405905627199
# gender_Male has weight of -0.26628892981218827
# admission_type_id_1 has weight of -0.6360101500996377
# admission_type_id_2 has weight of -0.3791039689102484
# admission_type_id_3 has weight of -0.7830500447823118
# admission_type_id_4 has weight of -0.87458976642867
# admission_type_id_5 has weight of -0.6888324139127165
# admission_type_id_6 has weight of 0.045589289625080874
# admission_type_id_7 has weight of 3.683443052346864
# admission_type_id_8 has weight of -0.8303755182475603
# discharge_disposition_id_1 has weight of 0.14652398825153123
# discharge_disposition_id_2 has weight of 0.14078333452286382
# discharge_disposition_id_3 has weight of 0.022704760930731774
# discharge_disposition_id_4 has weight of 0.3446419170484061
# discharge_disposition_id_5 has weight of 0.5205891943406453
# discharge_disposition_id_6 has weight of 0.29947958764010546
# discharge_disposition_id_7 has weight of 2.0605047629585487
# discharge_disposition_id_8 has weight of 1.4389294763096039
# discharge_disposition_id_9 has weight of 2.486435643738888
# discharge_disposition_id_10 has weight of 0.587409857571744
# discharge_disposition_id_11 has weight of -5.571087886094647
# discharge_disposition_id_12 has weight of 0.8339951077896465
# discharge_disposition_id_13 has weight of -1.9224290734578966
# discharge_disposition_id_14 has weight of -2.7402662103832003
# discharge_disposition_id_15 has weight of 0.13065322068553972
# discharge_disposition_id_16 has weight of 0.6366309803488089
# discharge_disposition_id_17 has weight of -0.062052721951164506
# discharge_disposition_id_18 has weight of -0.11737589619480437
# discharge_disposition_id_19 has weight of -1.22455200334587
# discharge_disposition_id_20 has weight of -0.3142742879211725
# discharge_disposition_id_22 has weight of -0.005692047874074017
# discharge_disposition_id_23 has weight of 2.2640581432806623
# discharge_disposition_id_24 has weight of 0.0033365596120832394
# discharge_disposition_id_25 has weight of -0.2564695550789488
# discharge_disposition_id_27 has weight of -0.3685104896056009
# discharge_disposition_id_28 has weight of 0.2031041164832619
# admission_source_id_1 has weight of -0.5693139881370889
# admission_source_id_2 has weight of -0.6742348592418949
# admission_source_id_3 has weight of -0.1385858373284853
# admission_source_id_4 has weight of -0.73839981362228
# admission_source_id_5 has weight of -0.8501486999926253
# admission_source_id_6 has weight of -0.7570019154927821
# admission_source_id_7 has weight of -0.23409455702705154
# admission_source_id_8 has weight of -0.9269209341585406
# admission_source_id_9 has weight of -1.276985690760914
# admission_source_id_10 has weight of 3.3625229506401397
# admission_source_id_14 has weight of -0.25065506370672197
# admission_source_id_17 has weight of -0.6770208829604734
# admission_source_id_20 has weight of -0.056223938365075186
# admission_source_id_22 has weight of 0.02414175324464704
# admission_source_id_25 has weight of 3.2999919564989053
# medical_specialty_AllergyandImmunology has weight of 0.8625633675938124
# medical_specialty_Anesthesiology has weight of -0.373189224195324
# medical_specialty_Anesthesiology-Pediatric has weight of -0.05780450750851034
# medical_specialty_Cardiology has weight of -0.06165128226497968
# medical_specialty_Cardiology-Pediatric has weight of 0.581508725542417
# medical_specialty_DCPTEAM has weight of -0.7561765774861231
# medical_specialty_Dentistry has weight of -0.12017762441831056
# medical_specialty_Dermatology has weight of 0.45566906851903977
# medical_specialty_Emergency/Trauma has weight of 0.25640971813301505
# medical_specialty_Endocrinology has weight of -0.3303251662111287
# medical_specialty_Endocrinology-Metabolism has weight of -0.47756242204692184
# medical_specialty_Family/GeneralPractice has weight of 0.08509365921855731
# medical_specialty_Gastroenterology has weight of 0.33207399942994414
# medical_specialty_Gynecology has weight of -0.7887613469598895
# medical_specialty_Hematology has weight of 0.49078204671468584
# medical_specialty_Hematology/Oncology has weight of 0.36557855399275074
# medical_specialty_Hospitalist has weight of 0.10481187525527914
# medical_specialty_InfectiousDiseases has weight of 0.3880443246662118
# medical_specialty_InternalMedicine has weight of -0.18664734345866044
# medical_specialty_Nephrology has weight of 0.28296858688051063
# medical_specialty_Neurology has weight of -0.412734398315494
# medical_specialty_Neurophysiology has weight of 0.0
# medical_specialty_Obsterics&Gynecology-GynecologicOnco has weight of -0.18839809148540596
# medical_specialty_Obstetrics has weight of -0.48440666484593825
# medical_specialty_ObstetricsandGynecology has weight of -0.5848917216761526
# medical_specialty_Oncology has weight of -0.140576888193761
# medical_specialty_Ophthalmology has weight of -0.12840219512981454
# medical_specialty_Orthopedics has weight of -0.12349893571170843
# medical_specialty_Orthopedics-Reconstructive has weight of -0.4037962008304938
# medical_specialty_Osteopath has weight of 0.31716969996304406
# medical_specialty_Otolaryngology has weight of -0.3418314123574542
# medical_specialty_OutreachServices has weight of 0.29143472961703004
# medical_specialty_Pathology has weight of 0.5904336140596067
# medical_specialty_Pediatrics has weight of -0.08017579928830128
# medical_specialty_Pediatrics-AllergyandImmunology has weight of 0.3270032607429492
# medical_specialty_Pediatrics-CriticalCare has weight of 0.29290328074880567
# medical_specialty_Pediatrics-EmergencyMedicine has weight of 0.2994318036552294
# medical_specialty_Pediatrics-Endocrinology has weight of -0.5301591683946104
# medical_specialty_Pediatrics-Hematology-Oncology has weight of -0.3779020415872763
# medical_specialty_Pediatrics-InfectiousDiseases has weight of 0.0
# medical_specialty_Pediatrics-Neurology has weight of -0.17184294597281194
# medical_specialty_Pediatrics-Pulmonology has weight of 1.4163727589647306
# medical_specialty_Perinatology has weight of -0.21703648784372587
# medical_specialty_PhysicalMedicineandRehabilitation has weight of -0.241546422466389
# medical_specialty_PhysicianNotFound has weight of 0.505848068609047
# medical_specialty_Podiatry has weight of 0.694563455594197
# medical_specialty_Proctology has weight of -0.28410161587221766
# medical_specialty_Psychiatry has weight of -0.07107072597409327
# medical_specialty_Psychiatry-Addictive has weight of -0.43193517363721284
# medical_specialty_Psychiatry-Child/Adolescent has weight of -0.36176722622587104
# medical_specialty_Psychology has weight of 0.2901138332089882
# medical_specialty_Pulmonology has weight of -0.05948710129425216
# medical_specialty_Radiologist has weight of 0.1943571506046086
# medical_specialty_Radiology has weight of 0.10971756954115092
# medical_specialty_Resident has weight of 0.5097711874636515
# medical_specialty_Rheumatology has weight of -0.11271144359520811
# medical_specialty_Speech has weight of -0.4206189476052471
# medical_specialty_SportsMedicine has weight of 0.40348933813813603
# medical_specialty_Surgeon has weight of -0.3018926985041247
# medical_specialty_Surgery-Cardiovascular has weight of -0.5111269601035057
# medical_specialty_Surgery-Cardiovascular/Thoracic has weight of -0.8445853586447473
# medical_specialty_Surgery-Colon&Rectal has weight of 0.24859719552485302
# medical_specialty_Surgery-General has weight of 0.09653726869682072
# medical_specialty_Surgery-Maxillofacial has weight of -0.05698202216725948
# medical_specialty_Surgery-Neuro has weight of -0.6379192846022746
# medical_specialty_Surgery-Pediatric has weight of -0.3095173005550468
# medical_specialty_Surgery-Plastic has weight of 0.11288237735170643
# medical_specialty_Surgery-PlasticwithinHeadandNeck has weight of 0.0
# medical_specialty_Surgery-Thoracic has weight of -0.2636101161760618
# medical_specialty_Surgery-Vascular has weight of 0.28025731170512996
# medical_specialty_SurgicalSpecialty has weight of 0.3967711274493221
# medical_specialty_Unspecified has weight of 0.19779233948129218
# medical_specialty_Urology has weight of 0.0029400261302803964
# max_glu_serum_>200 has weight of -0.13726648687235524
# max_glu_serum_>300 has weight of 0.04256200817225062
# max_glu_serum_None has weight of -0.1530826282093273
# max_glu_serum_Norm has weight of -0.21514241339506068
# A1Cresult_>7 has weight of -0.108086678267219
# A1Cresult_>8 has weight of -0.09953363283193079
# A1Cresult_None has weight of -0.03220079363067912
# A1Cresult_Norm has weight of -0.22310841557219344
# change_Ch has weight of -0.24191537103767546
# change_No has weight of -0.22101414935440494
# diabetesMed_No has weight of -0.3112797098428737
# diabetesMed_Yes has weight of -0.151649810470836
# diag_1_val_Circulatory has weight of 0.028992081784473968
# diag_1_val_Diabeties has weight of 0.20934401586046825
# diag_1_val_Digestive has weight of -0.03215641045882246
# diag_1_val_Genitourinary has weight of -0.09248519636173287
# diag_1_val_Injury has weight of -0.12276867397411304
# diag_1_val_Musculoskeletal has weight of 0.01851128772322492
# diag_1_val_Neoplasms has weight of -0.09821295553534282
# diag_1_val_None has weight of -0.4046006295257954
# diag_1_val_Other has weight of 0.004420524348248891
# diag_1_val_Respiratory has weight of 0.026026435755137477
# diag_2_val_Circulatory has weight of 0.008739339511863616
# diag_2_val_Diabeties has weight of 0.08296652215831063
# diag_2_val_Digestive has weight of -0.07244355833292705
# diag_2_val_Genitourinary has weight of 0.006831484521323947
# diag_2_val_Injury has weight of -0.23940798875081265
# diag_2_val_Musculoskeletal has weight of -0.05681008429439647
# diag_2_val_Neoplasms has weight of -0.00924320788700867
# diag_2_val_None has weight of -0.04906844148118749
# diag_2_val_Other has weight of -0.12804423244580332
# diag_2_val_Respiratory has weight of -0.006449353411025639
# diag_3_val_Circulatory has weight of -0.0496136443352553
# diag_3_val_Diabeties has weight of -0.007183676071501737
# diag_3_val_Digestive has weight of 0.024311942721431928
# diag_3_val_Genitourinary has weight of 0.04036259514633631
# diag_3_val_Injury has weight of -0.2353611682291721
# diag_3_val_Musculoskeletal has weight of -0.08375603502912027
# diag_3_val_Neoplasms has weight of -0.1626458671117357
# diag_3_val_None has weight of 0.13974236405484805
# diag_3_val_Other has weight of -0.0928445384458771
# diag_3_val_Respiratory has weight of -0.03594149306808021
# meds_increased_0 has weight of -0.340476040577946
# meds_increased_1 has weight of -0.12245347975414582
# num_lab_procedures has weight of 0.04588521228087163
# num_procedures has weight of -0.02667715102728518
# num_medications has weight of 0.22239029034174215
# number_outpatient has weight of 0.1016055857870672
# number_emergency has weight of 0.26667583251133126
# number_inpatient has weight of 0.3533270068546308
# number_diagnoses has weight of 0.5134557669378502
# medication_count has weight of 0.018646108389205832

# %%
#Model 6 - Normalize Features with Log of 3 numericals: num_lab_procedures, num_medications, number_diagnoses
#Scale attributes by training set
scl_obj = StandardScaler()
scl_obj.fit(X_train)

x_train_scaled = scl_obj.transform(X_train) # apply to training
x_test_scaled = scl_obj.transform(X_test)

#Train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05) 
lr_clf.fit(x_train_scaled,y_train)

#Get test set predictions
y_pred6 = lr_clf.predict(x_test_scaled)

acc = mt.accuracy_score(y_test,y_pred6)
conf = mt.confusion_matrix(y_test,y_pred6)
print('Model 6 - Accuracy:', acc, '\nConfusion Matrix\n', conf)

#Sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,df_mlt_hot_x.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# Model 6 - Accuracy: 0.6726933280927582
# Confusion Matrix
#  [[8975 1974]
#  [4688 4717]]
# discharge_disposition_id_11 has weight of -0.8737557838094123
# discharge_disposition_id_14 has weight of -0.17477328167454514
# discharge_disposition_id_13 has weight of -0.13780690200842022
# admission_type_id_4 has weight of -0.12204561525044531
# admission_source_id_2 has weight of -0.11953743995009164
# admission_type_id_3 has weight of -0.10560643848608352
# admission_source_id_1 has weight of -0.08054980987305045
# medical_specialty_InternalMedicine has weight of -0.0794198288515171
# admission_source_id_4 has weight of -0.06754596579037496
# admission_source_id_17 has weight of -0.06740657704427162
# medical_specialty_Surgery-Cardiovascular/Thoracic has weight of -0.06648293896443998
# admission_source_id_6 has weight of -0.0604957620286702
# medical_specialty_Orthopedics-Reconstructive has weight of -0.057294817047494395
# discharge_disposition_id_19 has weight of -0.05707960630934091
# race_Unspecified has weight of -0.05287298317495563
# discharge_disposition_id_18 has weight of -0.051145799936929914
# admission_type_id_1 has weight of -0.0500858663466863
# medical_specialty_ObstetricsandGynecology has weight of -0.050067913239166116
# num_procedures has weight of -0.04848208958905506
# discharge_disposition_id_3 has weight of -0.03990600893580679
# diag_3_val_Neoplasms has weight of -0.0397283575250259
# diabetesMed_No has weight of -0.03789175081472421
# medical_specialty_Surgery-Neuro has weight of -0.037748132581645576
# meds_increased_0 has weight of -0.037517612549604014
# discharge_disposition_id_25 has weight of -0.03623237880836669
# discharge_disposition_id_27 has weight of -0.035918150190880224
# diag_1_val_Neoplasms has weight of -0.034289064653155246
# diag_2_val_Other has weight of -0.0341646306120191
# discharge_disposition_id_20 has weight of -0.03370346537395028
# admission_source_id_5 has weight of -0.03335633858103857
# admission_type_id_5 has weight of -0.032635937351165455
# admission_source_id_9 has weight of -0.032605920570248186
# diag_2_val_Injury has weight of -0.03140169426486637
# diag_1_val_Injury has weight of -0.029032706625045965
# medical_specialty_Pediatrics-Endocrinology has weight of -0.02818277459688055
# diag_1_val_Genitourinary has weight of -0.02563884958494783
# medical_specialty_Psychiatry-Addictive has weight of -0.02352631927418983
# medical_specialty_Surgery-Cardiovascular has weight of -0.02350365237700834
# medical_specialty_Speech has weight of -0.023005305870815
# medical_specialty_Gynecology has weight of -0.022836106582025895
# diag_3_val_Injury has weight of -0.021999667003999253
# medical_specialty_Obstetrics has weight of -0.0218245458050095
# race_Asian has weight of -0.021524901675181177
# A1Cresult_Norm has weight of -0.020940244706041757
# medical_specialty_Proctology has weight of -0.02088219308440061
# medical_specialty_Orthopedics has weight of -0.020816512095013933
# discharge_disposition_id_22 has weight of -0.020515007272394654
# medical_specialty_Perinatology has weight of -0.019656804940127545
# medical_specialty_Cardiology has weight of -0.019298388178399323
# admission_source_id_14 has weight of -0.01899773781450322
# race_Other has weight of -0.01832477376628452
# medical_specialty_Surgeon has weight of -0.018155357951348743
# gender_Male has weight of -0.017230837366372723
# medical_specialty_PhysicalMedicineandRehabilitation has weight of -0.017053498432681953
# medical_specialty_Endocrinology has weight of -0.014440871857354189
# diag_2_val_Digestive has weight of -0.01442557080109267
# medical_specialty_Otolaryngology has weight of -0.014086281725889428
# race_Hispanic has weight of -0.013843408282292063
# max_glu_serum_Norm has weight of -0.012380941961966313
# admission_source_id_8 has weight of -0.01203051302936467
# discharge_disposition_id_1 has weight of -0.010785420731665456
# medical_specialty_Surgery-Thoracic has weight of -0.010312066394561658
# medical_specialty_Oncology has weight of -0.0101351395277418
# diag_3_val_Other has weight of -0.010027269068039446
# diag_1_val_None has weight of -0.009275015409999776
# medical_specialty_Pulmonology has weight of -0.008617512233728334
# change_Ch has weight of -0.008457039946680215
# medical_specialty_Neurology has weight of -0.008210551862071423
# medical_specialty_Psychiatry has weight of -0.007864599680334393
# discharge_disposition_id_24 has weight of -0.0071711251406953195
# medical_specialty_Pediatrics-Hematology-Oncology has weight of -0.006468659197214199
# A1Cresult_>7 has weight of -0.006447695633582715
# admission_type_id_8 has weight of -0.006324059232567809
# discharge_disposition_id_28 has weight of -0.0061992574659563236
# max_glu_serum_>200 has weight of -0.006124486886473073
# medical_specialty_Endocrinology-Metabolism has weight of -0.005531106995460062
# diag_2_val_Respiratory has weight of -0.004710903523124625
# A1Cresult_>8 has weight of -0.004247513133965323
# medical_specialty_Pediatrics has weight of -0.004170072698771807
# diag_3_val_Musculoskeletal has weight of -0.003848052835983941
# medical_specialty_Surgery-Maxillofacial has weight of -0.0037715196765242655
# medical_specialty_Obsterics&Gynecology-GynecologicOnco has weight of -0.0036471517507333847
# medical_specialty_Psychology has weight of -0.003471024430041378
# diag_2_val_Neoplasms has weight of -0.0033372541850449603
# time_in_hospital has weight of -0.003096177626187838
# medical_specialty_Osteopath has weight of -0.003061843874648593
# medical_specialty_Urology has weight of -0.0027039823173263624
# discharge_disposition_id_2 has weight of -0.0026193981257489956
# medical_specialty_Rheumatology has weight of -0.002467161178120369
# medical_specialty_Anesthesiology-Pediatric has weight of -0.0020100256437246768
# diag_1_val_Musculoskeletal has weight of -0.0019824214747887893
# discharge_disposition_id_15 has weight of -0.0013689977846519754
# medical_specialty_Surgery-Plastic has weight of -0.0012672320631075657
# medical_specialty_Anesthesiology has weight of -0.0010730595261713635
# max_glu_serum_None has weight of -0.0009262849831844214
# medical_specialty_Psychiatry-Child/Adolescent has weight of -0.000914495549399552
# medical_specialty_DCPTEAM has weight of -0.0008924417979360945
# race_AfricanAmerican has weight of -0.0007955420050833023
# medical_specialty_Surgery-General has weight of -0.0007555039147384856
# diag_2_val_Musculoskeletal has weight of -0.0003323546977700113
# diag_1_val_Other has weight of -0.0001350827403878452
# medical_specialty_Neurophysiology has weight of 0.0
# medical_specialty_Hospitalist has weight of 5.130662759421554e-05
# medical_specialty_Ophthalmology has weight of 0.0003659150218220145
# medical_specialty_Pediatrics-Neurology has weight of 0.0004090082751237152
# diag_1_val_Digestive has weight of 0.000501910952277433
# discharge_disposition_id_17 has weight of 0.0013810973984819234
# admission_source_id_3 has weight of 0.0015987923424228877
# medical_specialty_Pediatrics-EmergencyMedicine has weight of 0.0016610412949277203
# diag_2_val_None has weight of 0.0020810581523492537
# medical_specialty_SurgicalSpecialty has weight of 0.0021400679389037593
# medical_specialty_Surgery-Pediatric has weight of 0.002427458838463899
# medical_specialty_PhysicianNotFound has weight of 0.0025988633682478128
# discharge_disposition_id_12 has weight of 0.002814128470827541
# medical_specialty_Radiology has weight of 0.003059621078763705
# discharge_disposition_id_10 has weight of 0.003423428845505028
# diag_3_val_Circulatory has weight of 0.004057137077955034
# medical_specialty_OutreachServices has weight of 0.004345919138644533
# medical_specialty_Surgery-Colon&Rectal has weight of 0.004563238453259492
# diag_2_val_Genitourinary has weight of 0.005029364904549891
# medical_specialty_Resident has weight of 0.005753766253287336
# medical_specialty_Hematology has weight of 0.005831767888810353
# medical_specialty_AllergyandImmunology has weight of 0.006436979961787881
# medical_specialty_InfectiousDiseases has weight of 0.006459066855757695
# medical_specialty_Dentistry has weight of 0.007122005589127315
# diag_3_val_Respiratory has weight of 0.008013966591509714
# discharge_disposition_id_16 has weight of 0.008119211512658667
# medical_specialty_Pediatrics-CriticalCare has weight of 0.008213211542889976
# change_No has weight of 0.008457039946678329
# medical_specialty_Pathology has weight of 0.008872309507400825
# admission_source_id_22 has weight of 0.009630683938255438
# diag_1_val_Respiratory has weight of 0.011121852621815538
# medical_specialty_Radiologist has weight of 0.011507581465211329
# diag_2_val_Circulatory has weight of 0.012161670717369143
# medical_specialty_Family/GeneralPractice has weight of 0.01286400397880893
# medical_specialty_Gastroenterology has weight of 0.013475405401740316
# diag_3_val_Digestive has weight of 0.014260105841168758
# medical_specialty_Podiatry has weight of 0.014569677206248422
# diag_1_val_Circulatory has weight of 0.014791946807573099
# medical_specialty_Surgery-Vascular has weight of 0.015119936472503837
# medical_specialty_Cardiology-Pediatric has weight of 0.015393255867438529
# medical_specialty_Hematology/Oncology has weight of 0.015643584795289472
# gender_Female has weight of 0.017230837366370034
# diag_3_val_Diabeties has weight of 0.017460627557833827
# medication_count has weight of 0.017629967239529632
# diag_3_val_None has weight of 0.017653571440870906
# A1Cresult_None has weight of 0.018516713034706502
# admission_source_id_20 has weight of 0.018539749617717878
# medical_specialty_Pediatrics-Pulmonology has weight of 0.02012676078197705
# discharge_disposition_id_4 has weight of 0.021644436049719093
# medical_specialty_SportsMedicine has weight of 0.022680032926338706
# medical_specialty_Surgery-PlasticwithinHeadandNeck has weight of 0.023445418878947563
# medical_specialty_Dermatology has weight of 0.023607425328504687
# medical_specialty_Pediatrics-InfectiousDiseases has weight of 0.02446362239507337
# max_glu_serum_>300 has weight of 0.026066762982788132
# medical_specialty_Nephrology has weight of 0.026420525286970014
# diag_3_val_Genitourinary has weight of 0.027038703361694755
# race_Caucasian has weight of 0.032262799710505205
# medical_specialty_Pediatrics-AllergyandImmunology has weight of 0.03742813947782135
# meds_increased_1 has weight of 0.037517612549604624
# diabetesMed_Yes has weight of 0.03789175081474738
# diag_2_val_Diabeties has weight of 0.04094611505869856
# discharge_disposition_id_6 has weight of 0.041560384012035295
# discharge_disposition_id_5 has weight of 0.04303267465598931
# diag_1_val_Diabeties has weight of 0.051767219467601294
# admission_type_id_2 has weight of 0.053850096224356846
# medical_specialty_Emergency/Trauma has weight of 0.05413107848889796
# num_lab_procedures has weight of 0.05578214167553965
# admission_source_id_7 has weight of 0.06357989212713584
# age has weight of 0.06855528285058068
# medical_specialty_Unspecified has weight of 0.06934110417852235
# discharge_disposition_id_8 has weight of 0.09816041614112475
# num_medications has weight of 0.11151148792854304
# admission_type_id_6 has weight of 0.1158067512371208
# number_outpatient has weight of 0.1291351410032231
# discharge_disposition_id_9 has weight of 0.15351421639234075
# number_diagnoses has weight of 0.17252943289534484
# number_emergency has weight of 0.25995890450521986
# discharge_disposition_id_7 has weight of 0.35054757614170917
# discharge_disposition_id_23 has weight of 0.3730461784819265
# number_inpatient has weight of 0.45528417791447984
# admission_source_id_25 has weight of 0.49103419463967657
# admission_source_id_10 has weight of 0.5078508281393859
# admission_type_id_7 has weight of 0.5844124316976143
