# %%
# All imports required for analysis are below
from __future__ import print_function
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import ipywidgets
from ipywidgets import widgets as wd
import sklearn
from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn import metrics as mt
from sklearn import preprocessing
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
import sklearn.metrics as metrics
import glob
import os

# %%
# Loading in HTML/CSS packages for use within the notebook
from IPython.core.display import HTML
HTML("<link href='https://fonts.googleapis.com/css?family=Passion+One' rel='stylesheet' type='text/css'><style>div.attn { font-family: 'Helvetica Neue'; font-size: 30px; line-height: 40px; color: #FFFFFF; text-align: center; margin: 30px 0; border-width: 10px 0; border-style: solid; border-color: #5AAAAA; padding: 30px 0; background-color: #DDDDFF; }hr { border: 0; background-color: #ffffff; border-top: 1px solid black; }hr.major { border-top: 10px solid #5AAA5A; }hr.minor { border: none; background-color: #ffffff; border-top: 5px dotted #CC3333; }div.bubble { width: 65%; padding: 20px; background: #DDDDDD; border-radius: 15px; margin: 0 auto; font-style: italic; color: #f00; }em { color: #AAA; }div.c1{visibility:hidden;margin:0;height:0;}div.note{color:red;}</style>")
# Out:
# <link href='https://fonts.googleapis.com/css?family=Passion+One' rel='stylesheet' type='text/css'><style>div.attn { font-family: 'Helvetica Neue'; font-size: 30px; line-height: 40px; color: #FFFFFF; text-align: center; margin: 30px 0; border-width: 10px 0; border-style: solid; border-color: #5AAAAA; padding: 30px 0; background-color: #DDDDFF; }hr { border: 0; background-color: #ffffff; border-top: 1px solid black; }hr.major { border-top: 10px solid #5AAA5A; }hr.minor { border: none; background-color: #ffffff; border-top: 5px dotted #CC3333; }div.bubble { width: 65%; padding: 20px; background: #DDDDDD; border-radius: 15px; margin: 0 auto; font-style: italic; color: #f00; }em { color: #AAA; }div.c1{visibility:hidden;margin:0;height:0;}div.note{color:red;}</style>

# %% [markdown]
# # Mini Lab: Logistic Regression and SVMs
# ### Group A: Mai Loan Tran, Lei Jiang, Zachary Gill, & Samantha Sprague

# %% [markdown]
# ## Table of Contents for Mini Lab
# * <a href="#Introduction">Introduction</a>
# * <a href="#CreateModels">Create Models</a>
# * <a href="#ModelAdvantages">Model Advantages</a>
# * <a href="#InterpretFeatureImportance">Interpret Feature Importance</a>
# * <a href="#InterpretSupportVectors">Interpret Support Vectors</a>
# * <a href="#Exceptional Work">Exceptional Work</a>
# * <a href="#References">References</a>

# %% [markdown]
# <a id="Introduction"></a>
# ## Introduction

# %% [markdown]
# Diabetes is the leading cause of death in the world. Roughly 422 million people have diabetes. There are three major types of diabetes: type 1, type 2, and gestational diabetes. Type 2 is the most common type of diabetes, and is thought to be preventable! While the leading cause of death, with identification and proper management of diabetes most individuals can lead happy and healthy lives. The key to manageable diabetes is often early detection and proper treatment. This begs the question, can we detect if a patient will be readmitted in the hospital for diabetes? This notebook will guide the reader through a comprehensive analysis that evaluates our ability to predict readmission to the hospital for diabetes using logistic regression and support vector machine techniques.
#
#
# The data cleaning and exploratory data analysis for this dataset is provided the additional notebook submitted for this assignment. Due to Professor Moustafa's request, this work was not included in this specific notebook for ease of grading the assignment, but is available to validate extensive work was done for cleaning the data, and generating useful features for predictive analysis. For insight on data cleaning, please see the Team A -- Data Cleaning notebook. For insight into EDA please see the Team A -- EDA notebook.

# %% [markdown]
# <a id="CreateModels"></a>
# ## Create Models

# %% [markdown]
# **Requirements:** Create a logistic regression model and a support vector machine model for the classification task involved with your dataset. Assess how well each model performs (use 80/20 training/testing split for your data). Adjust parameters of the models to make them more accurate.

# %%
# Reading in cleaned data
directory = 'C:/githubrepo/7331_Project/data/'
df_zg = pd.read_csv(directory + 'Diabetic_Cleaned.csv')
print("Done reading data.")
# Out:
# Done reading data.

# %%
# The following code chunks are to manipulate data types for ease of analysis
ordinal = ["age", "time_in_hospital"]
categorical = ["race", "gender", "admission_type_id", "discharge_disposition_id",
               "admission_source_id", "medical_specialty", "max_glu_serum",
               "A1Cresult", "change", "diabetesMed", "diag_1_val", "diag_2_val",
               "diag_3_val", "meds_increased"]
continuous = ["num_lab_procedures", "num_procedures", "num_medications",
              "number_outpatient", "number_emergency", "number_inpatient",
              "number_diagnoses", "medication_count"]
medicines = ["metformin", "repaglinide", "nateglinide", "chlorpropamide",
             "glimepiride", "acetohexamide", "glipizide", "glyburide", "tolbutamide",
             "pioglitazone", "rosiglitazone", "acarbose", "miglitol", "troglitazone",
             "tolazamide", "insulin", "glyburide-metformin", "glipizide-metformin",
             "metformin-rosiglitazone", "metformin-pioglitazone"]
response = ["readmitted_tf"]

# %%
df_zg_ordinal = df_zg[ordinal]
df_zg_categorical = df_zg[categorical]
df_zg_continuous = df_zg[continuous]
df_zg_medicines = df_zg[medicines]
df_zg_response = df_zg[response]

# %%
# Loop that makes the age Ordinal
for i in range(0, 10):
    val = "[" + str(i*10) + "-" + str((i+1)*10) + ")"
    df_zg_ordinal.loc[df_zg_ordinal['age'] == val, 'age'] = i

# %%
#Make all categorical columns categorical
df_zg_categorical['admission_type_id'] = df_zg_categorical['admission_type_id'].astype(object)
df_zg_categorical['discharge_disposition_id'] = df_zg_categorical['discharge_disposition_id'].astype(object)
df_zg_categorical['admission_source_id'] = df_zg_categorical['admission_source_id'].astype(object)
df_zg_categorical['admission_type_id'] = df_zg_categorical['admission_type_id'].astype(object)
df_zg_categorical['meds_increased'] = df_zg_categorical['meds_increased'].astype(object)
print("Done")
# Out:
# Done

# %%
#Creating X and Y dataframes
df_zg_x = pd.concat([df_zg_ordinal, df_zg_categorical, df_zg_continuous], axis = 1)
df_zg_num_x = pd.concat([df_zg_ordinal, df_zg_continuous], axis = 1)
df_zg_med_x = pd.concat([df_zg_ordinal, df_zg_categorical, df_zg_continuous, df_zg_medicines], axis = 1)
df_zg_hot_x = pd.concat([df_zg_ordinal, pd.get_dummies(df_zg_categorical), df_zg_continuous], axis = 1)
df_zg_hot_med_x = pd.concat([df_zg_ordinal, pd.get_dummies(df_zg_categorical), df_zg_continuous, pd.get_dummies(df_zg_medicines)], axis = 1)
df_zg_y = df_zg_response
print("Done")
# Out:
# Done

# %% [markdown]
# ### Training and Testing Split

# %% [markdown]
# There are several train and test splits done for the several types of models we will build in later sections in order to evaluate which set of features gives the highest accuracy. Due to our dataset, there were a lot of categorical variables that measured if a patient was taking a specific type of medication. This made our feature list very long, but difficult to leverage in models like logistic regression and SVMs because they were categorical. In addition, these categorical variables were highly skewed (as seen in the EDA analysis). We did not know how the models would perform if we included all the categorical medications, as we have often seen, simipilar models do not overfit and often provide better generalizations for test sets. These training and test sets are split 80/20.

# %%
#Code for 80/20 Training and Testing Splits 

#Hot Encoded, Not Scaled, Not including meds----------------
x_train_h, x_test_h, y_train_h, y_test_h = train_test_split(df_zg_hot_x, df_zg_y, test_size = 0.2, random_state=7)

#Hot Encoded, Not Scaled, Including meds--------------------
x_train_hm, x_test_hm, y_train_hm, y_test_hm = train_test_split(df_zg_hot_med_x, df_zg_y, test_size = 0.2, random_state=7)

#Hot Encoded, Scaled, No Meds-------------------------------
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()
scl_obj.fit(x_train_h)
x_train_hs = scl_obj.transform(x_train_h)
x_test_hs = scl_obj.transform(x_test_h)

#Hot Encoded, Scaled, Including Meds------------------------
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()
scl_obj.fit(x_train_hm)
x_train_hsm = scl_obj.transform(x_train_hm)
x_test_hsm = scl_obj.transform(x_test_hm)

#Reseting the row indexes
x_train_h.reset_index()
y_train_h.reset_index()
x_train_hm.reset_index()
y_train_hm.reset_index()

x_test_h.reset_index()
y_test_h.reset_index()
x_test_hm.reset_index()
y_test_hm.reset_index()

x_train_h.shape, x_test_h.shape
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\ipykernel_launcher.py:13: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   del sys.path[0]
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\ipykernel_launcher.py:14: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\ipykernel_launcher.py:20: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\ipykernel_launcher.py:21: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
# ((81412, 184), (20354, 184))

# %% [markdown]
# ## Logistic Regression Models

# %% [markdown]
# ###### Functions for Logistic Regression

# %%
# A function to find the optimal cutoff point from ROC curve

#https://stackoverflow.com/questions/28719067/roc-curve-and-cut-off-point-python
def Find_Optimal_Cutoff(target, predicted):
    """Parameters:
    target : Matrix with dependent or target data, where rows are observations
    predicted : Matrix with predicted data, where rows are observations
    ----------
    Return: list type, with optimal cutoff value
    """
    predicted = predicted[:,1]
    fpr, tpr, threshold = metrics.roc_curve(target, predicted)
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
    roc_t = roc.ix[(roc.tf-0).abs().argsort()[:1]]

    return list(roc_t['threshold']) 

#https://stackoverflow.com/questions/25009284/how-to-plot-roc-curve-in-python
#probs is the result of a model.predict_proba(x_test) call
#This function plots an ROC curve
def rocCurvePlot(probs, y_test):
    # calculate the fpr and tpr for all thresholds of the classification
    preds = probs[:,1]
    fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
    roc_auc = metrics.auc(fpr, tpr)

    # method I: plt
    import matplotlib.pyplot as plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %% [markdown]
# ### LR 1 -- One hot encoded variables, not scaled, not included medications

# %%
# %%time
#Code fro LR 1
#Logistic Regression: Hot Encoded, Not Scaled, Not including meds
model = LogisticRegression()
model.fit(x_train_hm, y_train_hm)

#Print all of the coefficient weights
weights = model.coef_.T
variable_names = x_train_hm.columns
allWeight = zip(weights, variable_names)
allWeight = sorted(allWeight, key=lambda x: x[0])
for coef, name in allWeight:
    print(name, 'has weight of', coef[0])

#Bar plot of the coefficient weights
pd.Series(model.coef_[0].T,index=x_train_hm.columns).plot(kind = 'bar')
plt.show()

#Find the optimal cutoff point
y_pred_cut = model.predict_proba(x_train_hm)
cutoff = Find_Optimal_Cutoff(y_train_hm, y_pred_cut)

#Prediction
#y_pred = model.predict(x_test_scaled)
y_pred_probs = model.predict_proba(x_test_hm)
y_pred = np.where(y_pred_probs >= cutoff, 1, 0)
y_pred = y_pred[:,1]

rocCurvePlot(y_pred_probs, y_test_hm)

#Accuracy metrics
f1 = f1_score(y_test_hm, y_pred, average = 'weighted')
acc = accuracy_score(y_test_hm, y_pred)
roc = roc_auc_score(y_test_hm, model.predict_proba(x_test_hm)[:,1])
conf = mt.confusion_matrix(y_test_hm, y_pred)
print("F1:", f1, "ACC:", acc, "AUC:", roc, "\nConfusion Matrix\n", conf)
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# discharge_disposition_id_11 has weight of -5.687000885917768
# discharge_disposition_id_14 has weight of -2.699368821620567
# discharge_disposition_id_13 has weight of -1.7703747450584482
# admission_source_id_9 has weight of -1.4291007938208673
# discharge_disposition_id_19 has weight of -0.9449989327546094
# medical_specialty_Surgery-Cardiovascular/Thoracic has weight of -0.9378343619786118
# admission_source_id_5 has weight of -0.8252405545342675
# admission_type_id_4 has weight of -0.7705486708802
# glyburide-metformin_Up has weight of -0.743779349602651
# admission_source_id_4 has weight of -0.7368353793573432
# admission_source_id_6 has weight of -0.7263628869127727
# medical_specialty_Pediatrics-Endocrinology has weight of -0.7207053685556961
# admission_type_id_3 has weight of -0.7129853684983268
# medical_specialty_DCPTEAM has weight of -0.6633103980188303
# admission_type_id_5 has weight of -0.6605506031581062
# admission_type_id_8 has weight of -0.6558423139964561
# admission_source_id_2 has weight of -0.6418170701686667
# admission_type_id_1 has weight of -0.616682106579677
# admission_source_id_17 has weight of -0.5989795617347143
# medical_specialty_Surgery-Neuro has weight of -0.5901794238584929
# medical_specialty_ObstetricsandGynecology has weight of -0.5768816493790022
# admission_source_id_1 has weight of -0.546941830499838
# medical_specialty_Orthopedics-Reconstructive has weight of -0.5137256228507457
# medical_specialty_Surgery-Cardiovascular has weight of -0.5093630321077254
# medical_specialty_Surgeon has weight of -0.4994877299258935
# admission_source_id_8 has weight of -0.4958767126232354
# medical_specialty_Endocrinology has weight of -0.49317807085406434
# medical_specialty_Obstetrics has weight of -0.47283194222864994
# tolazamide_Steady has weight of -0.4420260076647472
# medical_specialty_Pediatrics-Hematology-Oncology has weight of -0.4215975967155649
# acarbose_Down has weight of -0.41388316687287463
# medical_specialty_Anesthesiology has weight of -0.40270743727716707
# medical_specialty_Speech has weight of -0.39415606246444035
# rosiglitazone_Down has weight of -0.38756046417559775
# metformin-rosiglitazone_Steady has weight of -0.3832360380668208
# miglitol_No has weight of -0.3785358960367701
# repaglinide_Up has weight of -0.37798634761296496
# medical_specialty_Gynecology has weight of -0.37104939135805615
# acetohexamide_No has weight of -0.34810963206997925
# medical_specialty_Endocrinology-Metabolism has weight of -0.3457340284162339
# admission_type_id_2 has weight of -0.3389640129089791
# medical_specialty_Surgery-Maxillofacial has weight of -0.33569985821126647
# medical_specialty_Neurology has weight of -0.32818561720529016
# diag_1_val_None has weight of -0.32490846158936354
# medical_specialty_Surgery-Thoracic has weight of -0.3158349880397627
# discharge_disposition_id_20 has weight of -0.30673295438619164
# medical_specialty_Proctology has weight of -0.2865391597456313
# glipizide-metformin_No has weight of -0.27532738181815075
# admission_source_id_14 has weight of -0.26895924377851965
# medical_specialty_Neurophysiology has weight of -0.2634040482454881
# acarbose_No has weight of -0.253690943203759
# chlorpropamide_No has weight of -0.2528088996246346
# troglitazone_No has weight of -0.24810787713528248
# admission_source_id_7 has weight of -0.23660911769309095
# medical_specialty_Anesthesiology-Pediatric has weight of -0.22142758443216384
# glimepiride_Up has weight of -0.22009264397113112
# medical_specialty_Otolaryngology has weight of -0.21253016441895584
# medical_specialty_Perinatology has weight of -0.20691574232771195
# miglitol_Steady has weight of -0.2063781124643787
# medical_specialty_PhysicalMedicineandRehabilitation has weight of -0.20371345374052144
# medical_specialty_InternalMedicine has weight of -0.198517716634646
# diag_2_val_Injury has weight of -0.187744434678683
# glyburide_Up has weight of -0.1867427657310933
# metformin-pioglitazone_Steady has weight of -0.18474079456693096
# nateglinide_No has weight of -0.18304641012360617
# admission_source_id_3 has weight of -0.18240111052657604
# race_Asian has weight of -0.17833532198093846
# medical_specialty_Radiology has weight of -0.16845299300567235
# metformin_Up has weight of -0.1604367680000452
# diag_3_val_Injury has weight of -0.15798912941273582
# race_Unspecified has weight of -0.1570465324871204
# discharge_disposition_id_25 has weight of -0.15594012836246374
# medical_specialty_Obsterics&Gynecology-GynecologicOnco has weight of -0.15588781976148808
# tolbutamide_Steady has weight of -0.14880837933610339
# rosiglitazone_Up has weight of -0.14682474248606447
# chlorpropamide_Down has weight of -0.13677422848650983
# medical_specialty_Pediatrics has weight of -0.13653597689668143
# discharge_disposition_id_24 has weight of -0.13598254393107018
# discharge_disposition_id_17 has weight of -0.13379164816059536
# max_glu_serum_Norm has weight of -0.13271268728591296
# insulin_No has weight of -0.1300313612688628
# medical_specialty_Oncology has weight of -0.12572803392156956
# diag_2_val_None has weight of -0.1217736109395167
# medical_specialty_Cardiology has weight of -0.11875266637333542
# nateglinide_Steady has weight of -0.10982433839122577
# pioglitazone_No has weight of -0.10589600386662973
# glipizide_No has weight of -0.10371220589213904
# medical_specialty_Pediatrics-Neurology has weight of -0.10277586648360809
# diabetesMed_No has weight of -0.09935589642887467
# diag_3_val_Neoplasms has weight of -0.09274971631289987
# A1Cresult_Norm has weight of -0.08331606190578249
# diag_1_val_Genitourinary has weight of -0.07619567593906097
# meds_increased_0 has weight of -0.0744207193840364
# medical_specialty_Orthopedics has weight of -0.07135705738604416
# insulin_Down has weight of -0.07002903900317682
# max_glu_serum_None has weight of -0.0654744806651953
# pioglitazone_Down has weight of -0.06412458859634783
# miglitol_Up has weight of -0.06161041182769279
# diag_2_val_Other has weight of -0.060747174547588975
# max_glu_serum_>200 has weight of -0.05792998799616736
# diag_1_val_Neoplasms has weight of -0.057866769901938044
# gender_Male has weight of -0.05739521856391289
# glipizide_Up has weight of -0.05528386079593539
# diag_1_val_Injury has weight of -0.05342772264421676
# A1Cresult_>7 has weight of -0.04836539738245367
# diag_3_val_Musculoskeletal has weight of -0.046552287962019455
# medical_specialty_Pulmonology has weight of -0.04319787729466248
# diag_2_val_Digestive has weight of -0.04235900314474585
# discharge_disposition_id_18 has weight of -0.040855308396610536
# medical_specialty_Urology has weight of -0.04080380052317143
# insulin_Steady has weight of -0.03444782728330104
# diag_3_val_None has weight of -0.03247171138249376
# change_Ch has weight of -0.03206629808213112
# medication_count has weight of -0.031095902362096795
# num_procedures has weight of -0.02710277642279565
# race_Other has weight of -0.02500787776396725
# medical_specialty_Rheumatology has weight of -0.024482045632947123
# chlorpropamide_Steady has weight of -0.024085236274709196
# glyburide-metformin_Down has weight of -0.02127447122921331
# change_No has weight of -0.01754871245192018
# diag_3_val_Other has weight of -0.013378346451467526
# discharge_disposition_id_22 has weight of -0.013128551794053221
# medical_specialty_Psychiatry has weight of -0.009712043938664313
# glipizide_Steady has weight of -0.0020711868963894297
# medical_specialty_Pediatrics-EmergencyMedicine has weight of 0.0
# medical_specialty_Psychiatry-Addictive has weight of 0.0
# time_in_hospital has weight of 0.00015613932839701544
# tolazamide_No has weight of 0.0011981010557203797
# num_lab_procedures has weight of 0.0047466992141477924
# glimepiride_Down has weight of 0.004747067659917783
# repaglinide_Down has weight of 0.005241422566089907
# gender_Female has weight of 0.007780208027957043
# metformin_Down has weight of 0.00783357035576076
# num_medications has weight of 0.010160675978341915
# race_Hispanic has weight of 0.010575720602144905
# glyburide_No has weight of 0.011670031994620276
# A1Cresult_>8 has weight of 0.012951659702128119
# medical_specialty_Psychology has weight of 0.015534475558500837
# diag_1_val_Digestive has weight of 0.022044619699257414
# diag_2_val_Genitourinary has weight of 0.02303978360231636
# diag_3_val_Circulatory has weight of 0.023293199989655768
# pioglitazone_Steady has weight of 0.023771082871230635
# diag_2_val_Musculoskeletal has weight of 0.024413416958162217
# meds_increased_1 has weight of 0.024805708859925415
# admission_source_id_22 has weight of 0.026443759170276037
# admission_source_id_20 has weight of 0.027573912933069943
# admission_type_id_6 has weight of 0.027863765295254497
# metformin_Steady has weight of 0.028925708291135076
# diag_3_val_Respiratory has weight of 0.029420177695076072
# diag_1_val_Other has weight of 0.04070899728301686
# repaglinide_No has weight of 0.043955509262710156
# age has weight of 0.044030468549760025
# diag_2_val_Respiratory has weight of 0.046188107755431015
# diag_2_val_Neoplasms has weight of 0.04644605693426138
# diabetesMed_Yes has weight of 0.04974088591732301
# diag_1_val_Musculoskeletal has weight of 0.0526041469240633
# glyburide_Steady has weight of 0.05290234388134324
# medical_specialty_Family/GeneralPractice has weight of 0.05917229670251553
# discharge_disposition_id_3 has weight of 0.05919486018175945
# medical_specialty_Ophthalmology has weight of 0.05984233326476769
# glimepiride_No has weight of 0.06268050534726574
# diag_3_val_Digestive has weight of 0.06347250147512716
# medical_specialty_Surgery-General has weight of 0.06468655198647609
# diag_1_val_Respiratory has weight of 0.06711177731108102
# A1Cresult_None has weight of 0.06911478910003545
# discharge_disposition_id_27 has weight of 0.06965130798868531
# diag_3_val_Diabeties has weight of 0.07193422455978385
# glyburide_Down has weight of 0.07255537932587917
# diag_1_val_Circulatory has weight of 0.07330866515068038
# metformin_No has weight of 0.07406247885214438
# diag_2_val_Circulatory has weight of 0.08320508135657848
# number_diagnoses has weight of 0.08898865672177972
# nateglinide_Down has weight of 0.09412790607442913
# pioglitazone_Up has weight of 0.09663449909296624
# number_outpatient has weight of 0.09789207841787942
# tolbutamide_No has weight of 0.09919336884388684
# glimepiride_Steady has weight of 0.10305006047574913
# diag_3_val_Genitourinary has weight of 0.10540607726081185
# medical_specialty_Surgery-Pediatric has weight of 0.11015547254793338
# glipizide_Down has weight of 0.11145224304383475
# race_AfricanAmerican has weight of 0.11906937417905707
# medical_specialty_Surgery-Plastic has weight of 0.12280907593199915
# discharge_disposition_id_2 has weight of 0.1305795963112836
# metformin-pioglitazone_No has weight of 0.135125784075874
# diag_2_val_Diabeties has weight of 0.13971676618593748
# nateglinide_Up has weight of 0.149127831947443
# discharge_disposition_id_10 has weight of 0.15941886848459577
# medical_specialty_Unspecified has weight of 0.1628585248466933
# medical_specialty_Radiologist has weight of 0.16603056593987606
# medical_specialty_SurgicalSpecialty has weight of 0.16805358249138308
# medical_specialty_Hematology has weight of 0.1773851433698294
# race_Caucasian has weight of 0.1811296269425461
# rosiglitazone_No has weight of 0.1832876601737819
# insulin_Up has weight of 0.18489321701000877
# medical_specialty_Emergency/Trauma has weight of 0.18572557535641626
# discharge_disposition_id_1 has weight of 0.1918203235004036
# medical_specialty_Surgery-Colon&Rectal has weight of 0.19429929500965698
# medical_specialty_OutreachServices has weight of 0.19500809825107857
# troglitazone_Steady has weight of 0.19849286664169277
# max_glu_serum_>300 has weight of 0.20650214545505471
# diag_1_val_Diabeties has weight of 0.20700541318233695
# medical_specialty_Surgery-Vascular has weight of 0.21767883820867515
# glipizide-metformin_Steady has weight of 0.2257123713260543
# medical_specialty_Gastroenterology has weight of 0.2372628589362668
# acarbose_Steady has weight of 0.2393035399316858
# discharge_disposition_id_15 has weight of 0.2527910482797829
# medical_specialty_InfectiousDiseases has weight of 0.25427065207977745
# number_emergency has weight of 0.2605370807537519
# discharge_disposition_id_28 has weight of 0.2628635875829388
# repaglinide_Steady has weight of 0.27917440530326965
# medical_specialty_Nephrology has weight of 0.28383116422081195
# medical_specialty_Hematology/Oncology has weight of 0.29010207423105566
# medical_specialty_Pediatrics-CriticalCare has weight of 0.29470025076331113
# acetohexamide_Steady has weight of 0.2984946215784453
# glyburide-metformin_No has weight of 0.2992483491467078
# rosiglitazone_Steady has weight of 0.3014825359955049
# discharge_disposition_id_6 has weight of 0.3309556307823489
# metformin-rosiglitazone_No has weight of 0.3336210275761405
# number_inpatient has weight of 0.3566184958359999
# discharge_disposition_id_4 has weight of 0.3614790156159407
# chlorpropamide_Up has weight of 0.36405335389716537
# acarbose_Up has weight of 0.3786555596609941
# tolazamide_Up has weight of 0.3912128961141034
# medical_specialty_SportsMedicine has weight of 0.4003489571211225
# medical_specialty_Psychiatry-Child/Adolescent has weight of 0.4042326885984709
# medical_specialty_Hospitalist has weight of 0.40803417990182594
# medical_specialty_Osteopath has weight of 0.4136287758607618
# glyburide-metformin_Steady has weight of 0.4161904611939106
# medical_specialty_Dentistry has weight of 0.4444665519168067
# medical_specialty_Dermatology has weight of 0.45626865857508003
# medical_specialty_Podiatry has weight of 0.4612621268860516
# medical_specialty_Surgery-PlasticwithinHeadandNeck has weight of 0.46904442126465523
# medical_specialty_AllergyandImmunology has weight of 0.4946665436034514
# medical_specialty_Resident has weight of 0.5012468739025645
# medical_specialty_Pediatrics-InfectiousDiseases has weight of 0.5150400728629811
# medical_specialty_Pathology has weight of 0.5291589569740632
# discharge_disposition_id_5 has weight of 0.5487544895180421
# discharge_disposition_id_12 has weight of 0.5837662409816401
# miglitol_Down has weight of 0.5969094098356492
# medical_specialty_Pediatrics-Pulmonology has weight of 0.6258721003646807
# medical_specialty_Cardiology-Pediatric has weight of 0.6386365664061875
# medical_specialty_PhysicianNotFound has weight of 0.6417349860667572
# discharge_disposition_id_16 has weight of 0.693845953056554
# medical_specialty_Pediatrics-AllergyandImmunology has weight of 0.7705323296699955
# discharge_disposition_id_8 has weight of 1.4931067865881975
# discharge_disposition_id_7 has weight of 2.059395145598317
# discharge_disposition_id_23 has weight of 2.2063983285220625
# discharge_disposition_id_9 has weight of 2.4345383269533545
# admission_source_id_25 has weight of 3.2760072444293837
# admission_source_id_10 has weight of 3.3094843345793183
# admission_type_id_7 has weight of 3.6780943001446196
# F1: 0.671507678095125 ACC: 0.6710720251547607 AUC: 0.7419343116089305
# Confusion Matrix
#  [[7367 3602]
#  [3093 6292]]
# Wall time: 13.1 s

# %% [markdown]
# ### LR 2 -- SGD Logistic Regression w/ one hot encoded features, scaled, including medication variables

# %%
# %%time
#Code for LR 2
#SGD Logistic Regression: Hot encoded, Including Medications
regularize_const = 0.1
iterations = 5
# use some compact notation for creating a logistic regression classifier with stochastic descent
log_sgd = SGDClassifier(alpha = regularize_const,
        fit_intercept = True, l1_ratio = 0.0, learning_rate = 'optimal',
        loss = 'log', n_jobs = -1, penalty = 'l2')
cv = StratifiedShuffleSplit( n_splits = 1, test_size = 0.5 )
scl = StandardScaler()
log_sgd.fit(scl.fit_transform(x_train_hm), y_train_hm)

#Print all of the coefficient weights
weights = log_sgd.coef_.T
variable_names = x_train_hm.columns
allWeight = zip(weights, variable_names)
allWeight = sorted(allWeight, key=lambda x: x[0])
for coef, name in allWeight:
    print(name, 'has weight of', coef[0])

#Bar plot of the coefficient weights
pd.Series(model.coef_[0].T,index=x_train_hm.columns).plot(kind = 'bar')
plt.show()

#Find the optimal cutoff point
y_pred_cut = log_sgd.predict_proba(x_train_hm)
cutoff = Find_Optimal_Cutoff(y_train_hm, y_pred_cut)

#Without the cutoff point changed it predicts all of one class

#Prediction
y_pred_probs = log_sgd.predict_proba(x_test_hm)
y_pred = np.where(y_pred_probs >= cutoff, 1, 0)
y_pred = y_pred[:,1]

rocCurvePlot(y_pred_probs, y_test_hm)

#Accuracy metrics
f1 = f1_score(y_test_hm, y_pred, average = 'weighted')
acc = accuracy_score(y_test_hm, y_pred)
roc = roc_auc_score(y_test_hm, log_sgd.predict_proba(x_test_hm)[:,1])
conf = mt.confusion_matrix(y_test_hm, y_pred)
print("F1:", f1, "ACC:", acc, "AUC:", roc, "\nConfusion Matrix\n", conf)
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# discharge_disposition_id_11 has weight of -0.21339943008417359
# discharge_disposition_id_14 has weight of -0.08392767595102267
# discharge_disposition_id_13 has weight of -0.070407405398898
# admission_source_id_2 has weight of -0.05889776101991151
# admission_type_id_3 has weight of -0.05516621769054491
# admission_type_id_4 has weight of -0.05124512217273828
# medical_specialty_Surgery-Cardiovascular/Thoracic has weight of -0.04885895425718612
# discharge_disposition_id_1 has weight of -0.046807241207953335
# medical_specialty_InternalMedicine has weight of -0.04554513587634286
# admission_source_id_1 has weight of -0.038475110751429856
# discharge_disposition_id_18 has weight of -0.03833844922577539
# medical_specialty_Orthopedics-Reconstructive has weight of -0.037984168905310305
# discharge_disposition_id_3 has weight of -0.03765634410898049
# medical_specialty_ObstetricsandGynecology has weight of -0.03660573475198101
# race_Unspecified has weight of -0.03486024070370693
# diabetesMed_No has weight of -0.03156238136208638
# medical_specialty_Surgery-Neuro has weight of -0.028933892569264433
# admission_type_id_5 has weight of -0.027862935869870337
# insulin_No has weight of -0.026824285246293985
# diag_2_val_Injury has weight of -0.026150350229125662
# meds_increased_0 has weight of -0.025961217555949854
# diag_1_val_Neoplasms has weight of -0.024647873946206215
# diag_3_val_Neoplasms has weight of -0.024282037575141833
# discharge_disposition_id_22 has weight of -0.023488340920550424
# medical_specialty_Pediatrics-Endocrinology has weight of -0.023421277544321967
# metformin_Up has weight of -0.022501370649394205
# admission_source_id_9 has weight of -0.021808781337255067
# medical_specialty_Cardiology has weight of -0.02160608690714845
# admission_source_id_5 has weight of -0.020631296266210727
# diag_2_val_Other has weight of -0.020445656465456527
# glyburide_Up has weight of -0.018972065928420875
# A1Cresult_Norm has weight of -0.018147215063413123
# num_procedures has weight of -0.017698075843053003
# diag_3_val_Injury has weight of -0.016962837140092793
# admission_source_id_6 has weight of -0.015726173743023986
# diag_3_val_None has weight of -0.015349888685894767
# glimepiride_Up has weight of -0.015078321309372025
# diag_1_val_Injury has weight of -0.015007279740164402
# discharge_disposition_id_25 has weight of -0.014911915826373965
# race_Asian has weight of -0.014725033804121632
# rosiglitazone_Up has weight of -0.013938007688772219
# admission_source_id_4 has weight of -0.013863679112357672
# medical_specialty_Neurology has weight of -0.013804170971697461
# metformin_Steady has weight of -0.01371091736346981
# race_Other has weight of -0.01357983842901963
# medical_specialty_PhysicalMedicineandRehabilitation has weight of -0.013537809232167007
# rosiglitazone_Down has weight of -0.013355172557707674
# diag_1_val_Genitourinary has weight of -0.013100683455551737
# insulin_Down has weight of -0.013092401398646158
# medical_specialty_Orthopedics has weight of -0.012592515704800532
# medical_specialty_Surgery-Cardiovascular has weight of -0.012497571873599768
# medical_specialty_Endocrinology has weight of -0.012485726660158854
# gender_Male has weight of -0.01235097623851827
# repaglinide_Up has weight of -0.011850644130152892
# discharge_disposition_id_19 has weight of -0.011750073841488963
# glyburide-metformin_Up has weight of -0.011454872234128638
# diag_2_val_Digestive has weight of -0.010510865766683666
# diag_2_val_None has weight of -0.01019603936872748
# admission_type_id_1 has weight of -0.009924202213704176
# medical_specialty_Gynecology has weight of -0.009683382006242088
# A1Cresult_>7 has weight of -0.009645479161085182
# acarbose_No has weight of -0.00962560730734626
# medical_specialty_DCPTEAM has weight of -0.009581620001093683
# race_Hispanic has weight of -0.009419122755464181
# medical_specialty_Surgeon has weight of -0.009265488356287632
# diag_1_val_Musculoskeletal has weight of -0.00885600123541346
# repaglinide_No has weight of -0.00853368645163407
# pioglitazone_No has weight of -0.008410610157688457
# medical_specialty_Otolaryngology has weight of -0.008009635985729568
# medical_specialty_Surgery-Thoracic has weight of -0.007903604302634017
# max_glu_serum_Norm has weight of -0.007866846988955713
# glipizide_No has weight of -0.007798639244374651
# medical_specialty_Urology has weight of -0.0077101900825511304
# medical_specialty_Obstetrics has weight of -0.007475087008361993
# discharge_disposition_id_2 has weight of -0.007474165149571241
# medical_specialty_Pediatrics has weight of -0.0063466306576725525
# discharge_disposition_id_20 has weight of -0.006339414097750472
# medical_specialty_Speech has weight of -0.005816089492943623
# discharge_disposition_id_24 has weight of -0.005745293005784409
# medical_specialty_Proctology has weight of -0.005725897106043851
# admission_type_id_8 has weight of -0.005496895165674992
# glipizide_Up has weight of -0.005243467967917008
# discharge_disposition_id_17 has weight of -0.005099166904600669
# medical_specialty_Neurophysiology has weight of -0.005081213434329561
# tolazamide_Steady has weight of -0.005052015532199684
# A1Cresult_>8 has weight of -0.005028820969764691
# medical_specialty_Pediatrics-Hematology-Oncology has weight of -0.004944750237194919
# medical_specialty_Psychiatry has weight of -0.004764410912270804
# metformin-rosiglitazone_Steady has weight of -0.004669529517376764
# admission_source_id_14 has weight of -0.004591145085914621
# diag_3_val_Musculoskeletal has weight of -0.004579339762047151
# medical_specialty_Perinatology has weight of -0.00456725180684996
# medical_specialty_Anesthesiology has weight of -0.004386741979665324
# medical_specialty_Anesthesiology-Pediatric has weight of -0.004016882014683318
# acetohexamide_No has weight of -0.0039026180537813215
# chlorpropamide_Down has weight of -0.003834096846793317
# miglitol_No has weight of -0.0038221886373564964
# medical_specialty_Endocrinology-Metabolism has weight of -0.0036377754898277727
# admission_source_id_8 has weight of -0.0035706274564269885
# medical_specialty_Radiology has weight of -0.0034698507490502823
# rosiglitazone_No has weight of -0.0034243596989142187
# repaglinide_Down has weight of -0.00338163779506456
# diag_3_val_Other has weight of -0.0033503306371176927
# metformin-pioglitazone_Steady has weight of -0.003206870726923508
# acarbose_Down has weight of -0.0031730339052348333
# glimepiride_Down has weight of -0.003073868368052731
# admission_source_id_17 has weight of -0.003071945453990388
# medical_specialty_Surgery-Maxillofacial has weight of -0.003046538774305355
# tolbutamide_Steady has weight of -0.002930691668775573
# medical_specialty_Obsterics&Gynecology-GynecologicOnco has weight of -0.0029150117457807504
# medical_specialty_Oncology has weight of -0.002757168394296548
# nateglinide_No has weight of -0.0026224032615878683
# max_glu_serum_None has weight of -0.0026216812874867647
# diag_1_val_None has weight of -0.002447899668052792
# troglitazone_No has weight of -0.002422092381029194
# metformin_Down has weight of -0.0023780891138827026
# glipizide-metformin_No has weight of -0.0022834708394585896
# glyburide-metformin_Down has weight of -0.002172815273699365
# chlorpropamide_No has weight of -0.0018661976756143082
# diag_2_val_Musculoskeletal has weight of -0.0017413254038699101
# change_No has weight of -0.0017316506525584337
# max_glu_serum_>200 has weight of -0.0017033409501504468
# race_AfricanAmerican has weight of -0.0013190118434111072
# medical_specialty_Surgery-Pediatric has weight of -0.0009631349664730338
# medical_specialty_Psychology has weight of -0.0008795339137825837
# medical_specialty_Pediatrics-Neurology has weight of -0.0008686264003651038
# glyburide_Steady has weight of -0.0007886255130756713
# pioglitazone_Down has weight of -0.0006245151878657695
# discharge_disposition_id_27 has weight of -0.0006129053647638624
# glyburide-metformin_No has weight of -0.0005748305739358885
# medical_specialty_Ophthalmology has weight of -8.318747221038905e-06
# medical_specialty_Pediatrics-EmergencyMedicine has weight of 0.0
# medical_specialty_Psychiatry-Addictive has weight of 0.0
# medical_specialty_Surgery-Plastic has weight of 2.7604481340887272e-05
# diag_1_val_Digestive has weight of 9.742142117011535e-05
# medical_specialty_Rheumatology has weight of 0.00012594707298724
# miglitol_Steady has weight of 0.00014486896664619894
# discharge_disposition_id_28 has weight of 0.0002608330406294215
# discharge_disposition_id_15 has weight of 0.000649034702130157
# pioglitazone_Up has weight of 0.0007154288642851317
# miglitol_Up has weight of 0.0007905339315538181
# diag_2_val_Respiratory has weight of 0.0008068196513121814
# medical_specialty_SurgicalSpecialty has weight of 0.000924595434208267
# glyburide_Down has weight of 0.0010477207742253254
# medical_specialty_Pulmonology has weight of 0.0011161648054842548
# glimepiride_Steady has weight of 0.0012147234120284062
# chlorpropamide_Steady has weight of 0.0012220120731838192
# medical_specialty_Surgery-Colon&Rectal has weight of 0.0012254830416413294
# nateglinide_Down has weight of 0.0013003669763062985
# diag_2_val_Genitourinary has weight of 0.0013836863695191363
# medical_specialty_OutreachServices has weight of 0.0014704873210213062
# change_Ch has weight of 0.0017316506525584337
# diag_1_val_Other has weight of 0.0017664486404413413
# glyburide-metformin_Steady has weight of 0.001849774035722093
# nateglinide_Up has weight of 0.002047323661978554
# medical_specialty_Pediatrics-CriticalCare has weight of 0.002097037051271907
# nateglinide_Steady has weight of 0.0021702939909888424
# glipizide-metformin_Steady has weight of 0.0022834708394585653
# discharge_disposition_id_10 has weight of 0.0023557879581702942
# troglitazone_Steady has weight of 0.002422092381029221
# medical_specialty_Surgery-General has weight of 0.002654683350121444
# tolbutamide_No has weight of 0.0029306916687755905
# admission_source_id_22 has weight of 0.003183170409281633
# metformin-pioglitazone_No has weight of 0.003206870726923368
# acarbose_Up has weight of 0.0032661334241943707
# glimepiride_No has weight of 0.0033293320045125474
# diag_2_val_Neoplasms has weight of 0.0036266225027044275
# tolazamide_No has weight of 0.0037418444121057963
# acetohexamide_Steady has weight of 0.0039026180537811775
# medical_specialty_InfectiousDiseases has weight of 0.003991968018837921
# discharge_disposition_id_12 has weight of 0.00461080203684948
# metformin-rosiglitazone_No has weight of 0.004669529517376851
# medical_specialty_Psychiatry-Child/Adolescent has weight of 0.004769209753835848
# chlorpropamide_Up has weight of 0.004814332263799677
# admission_source_id_3 has weight of 0.0050104549256692055
# medical_specialty_Cardiology-Pediatric has weight of 0.005192645372874007
# medical_specialty_Hematology has weight of 0.005207947180493413
# medical_specialty_Dentistry has weight of 0.005288846903568521
# discharge_disposition_id_16 has weight of 0.005707791224066329
# glyburide_No has weight of 0.005955836779674193
# medical_specialty_Hospitalist has weight of 0.006025235697500719
# medical_specialty_PhysicianNotFound has weight of 0.006270953592149836
# medical_specialty_Hematology/Oncology has weight of 0.006320412011218964
# diag_3_val_Respiratory has weight of 0.006386074825094077
# medical_specialty_Osteopath has weight of 0.006410179772381755
# diag_3_val_Diabeties has weight of 0.006449259544553219
# medical_specialty_Radiologist has weight of 0.006451944964288364
# medical_specialty_Pathology has weight of 0.006543945655472796
# medical_specialty_Family/GeneralPractice has weight of 0.006660819987063707
# medical_specialty_SportsMedicine has weight of 0.006869041015297393
# tolazamide_Up has weight of 0.0069602108513119884
# medical_specialty_Pediatrics-InfectiousDiseases has weight of 0.007117723096228089
# medical_specialty_Dermatology has weight of 0.007175118569862688
# medical_specialty_Surgery-PlasticwithinHeadandNeck has weight of 0.007219512793120743
# rosiglitazone_Steady has weight of 0.007624381542349358
# glipizide_Down has weight of 0.007681198089534392
# medical_specialty_AllergyandImmunology has weight of 0.007775501812247846
# medical_specialty_Resident has weight of 0.007792758179760004
# diag_3_val_Digestive has weight of 0.007801493374263476
# glipizide_Steady has weight of 0.007806930962552844
# medical_specialty_Pediatrics-Pulmonology has weight of 0.00804675851291889
# diag_2_val_Diabeties has weight of 0.008442273944383901
# diag_1_val_Circulatory has weight of 0.008501060172428888
# pioglitazone_Steady has weight of 0.008549802640792565
# miglitol_Down has weight of 0.009212360790112022
# medical_specialty_Pediatrics-AllergyandImmunology has weight of 0.009560373411363501
# acarbose_Steady has weight of 0.009574038440301056
# diag_3_val_Circulatory has weight of 0.00976862030535561
# medical_specialty_Gastroenterology has weight of 0.009858748949902638
# medical_specialty_Surgery-Vascular has weight of 0.010004827458943086
# medical_specialty_Podiatry has weight of 0.010123751802042375
# insulin_Steady has weight of 0.010482298407915461
# medication_count has weight of 0.01144246976248031
# gender_Female has weight of 0.01235097623851827
# diag_1_val_Respiratory has weight of 0.012796882270268773
# repaglinide_Steady has weight of 0.013091330597841094
# discharge_disposition_id_4 has weight of 0.015042347851116805
# admission_source_id_20 has weight of 0.015304372591940422
# diag_2_val_Circulatory has weight of 0.017744442460178162
# max_glu_serum_>300 has weight of 0.018370332151755066
# A1Cresult_None has weight of 0.019070212529286285
# metformin_No has weight of 0.019453620805335824
# diag_3_val_Genitourinary has weight of 0.020502380387410576
# race_Caucasian has weight of 0.022519181597871002
# medical_specialty_Nephrology has weight of 0.022662932567393705
# discharge_disposition_id_6 has weight of 0.02373441297250879
# meds_increased_1 has weight of 0.025961217555949847
# discharge_disposition_id_5 has weight of 0.02658057985924124
# diag_1_val_Diabeties has weight of 0.029326368681718198
# time_in_hospital has weight of 0.02965768441095813
# medical_specialty_Emergency/Trauma has weight of 0.02997949458543862
# diabetesMed_Yes has weight of 0.031562381362086375
# age has weight of 0.03173895362684017
# medical_specialty_Unspecified has weight of 0.0491366663226261
# insulin_Up has weight of 0.04964869127109404
# discharge_disposition_id_8 has weight of 0.05436123389822545
# admission_type_id_2 has weight of 0.0552806053256329
# admission_type_id_6 has weight of 0.05791206526384699
# num_medications has weight of 0.05956596372926968
# discharge_disposition_id_9 has weight of 0.06009416155308867
# admission_source_id_7 has weight of 0.06860860813200988
# num_lab_procedures has weight of 0.08641535436244312
# number_outpatient has weight of 0.09001802804441005
# admission_source_id_25 has weight of 0.09953776707850857
# admission_source_id_10 has weight of 0.10104184029203224
# number_diagnoses has weight of 0.1118686784402719
# number_emergency has weight of 0.13409795699504992
# admission_type_id_7 has weight of 0.16708549176327991
# discharge_disposition_id_7 has weight of 0.18023500164121475
# discharge_disposition_id_23 has weight of 0.18206385905435865
# number_inpatient has weight of 0.2641627662038676
# F1: 0.5816903386355671 ACC: 0.5810651468998722 AUC: 0.6144495848303639
# Confusion Matrix
#  [[6360 4609]
#  [3918 5467]]
# Wall time: 4.45 s

# %% [markdown]
# ### LR 3 -- One hot encoded, scaled, includes medications variables in for loop for multiple iterations

# %%
df_mlt_hot = pd.concat([df_zg_hot_x, df_zg_y], axis=1)

# %%
#Code for LR 3
df_mlt_hot = pd.concat([df_zg_hot_x, df_zg_y], axis=1)
from sklearn.model_selection import ShuffleSplit

#Converting the dataframe into a Numpy Matrix
if 'readmitted_tf' in df_mlt_hot:
    y = df_mlt_hot['readmitted_tf'].values
    del df_mlt_hot['readmitted_tf']
    X = df_mlt_hot.values
    
num_cv_iterations = 3
num_instances = len(y)
#0.2 indicates the 80/20 split
cv_object = ShuffleSplit(n_splits = num_cv_iterations, test_size = 0.2)

#-----------------------------------------------------
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None)

iter_num = 0
# Run through the cross validation loop and set the training
# and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    X_train = X[train_indices]
    y_train = y[train_indices]
    X_test = X[test_indices]
    y_test = y[test_indices]

    #Train the logisitic regression model on the training data
    lr_clf.fit(X_train, y_train)
    
    #Find the optimal cutoff point
    y_pred_cut = lr_clf.predict_proba(X_train)
    cutoff = Find_Optimal_Cutoff(y_train, y_pred_cut)
    y_hat_probs = lr_clf.predict_proba(X_test)
    y_hat = np.where(y_hat_probs >= cutoff, 1, 0)
    y_hat = y_hat[:,1]
    
    rocCurvePlot(y_hat_probs, y_test)

    #Geting the accuracy and confusion matrix for this iteration
    print("==== Iteration:", iter_num, "====")
    f1 = f1_score(y_test, y_hat, average = 'weighted')
    acc = accuracy_score(y_test, y_hat)
    roc = roc_auc_score(y_test, lr_clf.predict_proba(X_test)[:,1])
    conf = mt.confusion_matrix(y_test, y_hat)
    print("F1:", f1, "ACC:", acc, "AUC:", roc, "\nConfusion Matrix\n", conf)

    iter_num+=1

#Print all of the coefficient weights
weights = lr_clf.coef_.T
variable_names = df_mlt_hot.columns
allWeight = zip(weights, variable_names)
allWeight = sorted(allWeight, key = lambda x: x[0])
for coef, name in allWeight:
    print(name, 'has weight of', coef[0])

#Bar plot of the coefficient weights
pd.Series(lr_clf.coef_[0].T,index = df_mlt_hot.columns).plot(kind = 'bar')
plt.show()
# Out:
# ==== Iteration: 0 ====
# F1: 0.6670725847709221 ACC: 0.6667485506534342 AUC: 0.7379756081285807
# Confusion Matrix
#  [[7254 3606]
#  [3177 6317]]
# ==== Iteration: 1 ====
# F1: 0.6709497311518471 ACC: 0.6705807212341555 AUC: 0.7428350452433358
# Confusion Matrix
#  [[7316 3588]
#  [3117 6333]]
# ==== Iteration: 2 ====
# F1: 0.6648262743102858 ACC: 0.6642920310504078 AUC: 0.733199817245661
# Confusion Matrix
#  [[7340 3700]
#  [3133 6181]]
# discharge_disposition_id_11 has weight of -5.610037469242389
# discharge_disposition_id_14 has weight of -2.5919351881711594
# discharge_disposition_id_13 has weight of -2.0430742072075665
# admission_source_id_9 has weight of -1.2787437494977945
# medical_specialty_Surgery-Cardiovascular/Thoracic has weight of -0.993587942925444
# medical_specialty_Pediatrics-Endocrinology has weight of -0.911263760179738
# admission_source_id_4 has weight of -0.8059204429025607
# discharge_disposition_id_19 has weight of -0.7983473549221337
# admission_type_id_4 has weight of -0.7962774797671208
# admission_source_id_5 has weight of -0.7838256156595141
# admission_source_id_6 has weight of -0.7747583030553594
# admission_type_id_3 has weight of -0.739773356834184
# medical_specialty_ObstetricsandGynecology has weight of -0.7154989121985335
# medical_specialty_Surgery-Neuro has weight of -0.7002595413650016
# admission_type_id_5 has weight of -0.6938443625495283
# admission_type_id_8 has weight of -0.6853013934357173
# admission_source_id_2 has weight of -0.6676625893475887
# admission_source_id_17 has weight of -0.6495093313694854
# admission_type_id_1 has weight of -0.619127366289189
# medical_specialty_Endocrinology-Metabolism has weight of -0.6109613221000214
# medical_specialty_Gynecology has weight of -0.6097366685164584
# admission_source_id_1 has weight of -0.5658515721205581
# medical_specialty_Surgeon has weight of -0.5355667661518777
# admission_source_id_8 has weight of -0.4982294860951445
# discharge_disposition_id_20 has weight of -0.496140651130869
# medical_specialty_Surgery-Cardiovascular has weight of -0.49151509917798847
# medical_specialty_Orthopedics-Reconstructive has weight of -0.4853176967881698
# medical_specialty_Otolaryngology has weight of -0.4567884809898248
# medical_specialty_Endocrinology has weight of -0.45167464493013526
# medical_specialty_Pediatrics-Hematology-Oncology has weight of -0.44018669571019736
# medical_specialty_Surgery-Thoracic has weight of -0.43820658384415995
# medical_specialty_Surgery-Maxillofacial has weight of -0.3871461372276517
# discharge_disposition_id_24 has weight of -0.3709923302136608
# medical_specialty_Obstetrics has weight of -0.37056762636256674
# admission_type_id_2 has weight of -0.3646926129190257
# diag_1_val_None has weight of -0.3425130950703829
# race_Unspecified has weight of -0.29208139576908926
# medical_specialty_Neurophysiology has weight of -0.28598995762568996
# medical_specialty_Neurology has weight of -0.2851768004360363
# medical_specialty_Proctology has weight of -0.279667243986234
# medical_specialty_InternalMedicine has weight of -0.2644850963024141
# admission_source_id_14 has weight of -0.2610932342902633
# meds_increased_0 has weight of -0.2520824260947797
# admission_source_id_7 has weight of -0.2421461286150269
# admission_source_id_3 has weight of -0.23266408638912747
# medical_specialty_Anesthesiology has weight of -0.23031351474429432
# diabetesMed_No has weight of -0.229556031397691
# medical_specialty_Oncology has weight of -0.20462289677505446
# diag_3_val_Injury has weight of -0.20138419436489494
# diag_2_val_Injury has weight of -0.18537486463461939
# gender_Male has weight of -0.183915768591406
# medical_specialty_Pulmonology has weight of -0.18238373660923501
# A1Cresult_Norm has weight of -0.15268187713166667
# change_Ch has weight of -0.15095114700782103
# max_glu_serum_None has weight of -0.1477994201085774
# medical_specialty_Surgery-Pediatric has weight of -0.1354387156832027
# change_No has weight of -0.13542900211047257
# max_glu_serum_Norm has weight of -0.13254642149381676
# race_Asian has weight of -0.13096057852053714
# diag_2_val_None has weight of -0.124308893474609
# medical_specialty_Psychiatry has weight of -0.1228360756976923
# discharge_disposition_id_27 has weight of -0.12282160820412326
# diag_3_val_Neoplasms has weight of -0.1186180386776105
# diag_1_val_Genitourinary has weight of -0.1124180634031594
# medical_specialty_DCPTEAM has weight of -0.11211669685732369
# diag_2_val_Other has weight of -0.105237036469547
# medical_specialty_Cardiology has weight of -0.10383292092954673
# gender_Female has weight of -0.10246438058754691
# medical_specialty_Orthopedics has weight of -0.1012840780668059
# medical_specialty_PhysicalMedicineandRehabilitation has weight of -0.09504538193946516
# diag_1_val_Injury has weight of -0.09429224015363603
# race_Other has weight of -0.0937994529620285
# A1Cresult_>7 has weight of -0.08717527034544816
# max_glu_serum_>200 has weight of -0.0821626985213377
# medical_specialty_Pediatrics-Neurology has weight of -0.07900143943688528
# discharge_disposition_id_18 has weight of -0.07700985151315712
# discharge_disposition_id_17 has weight of -0.07607404365472525
# diag_1_val_Neoplasms has weight of -0.0731662938126416
# medical_specialty_Rheumatology has weight of -0.06595915731441256
# medical_specialty_Psychology has weight of -0.06580629504090257
# discharge_disposition_id_25 has weight of -0.06330298360355549
# A1Cresult_>8 has weight of -0.059622318701598745
# diabetesMed_Yes has weight of -0.0568241178211261
# diag_2_val_Digestive has weight of -0.05566460054686291
# medical_specialty_Hematology has weight of -0.054888843214922746
# admission_source_id_20 has weight of -0.05327960632089038
# diag_3_val_None has weight of -0.04753539227296526
# diag_3_val_Other has weight of -0.04700306749838589
# diag_2_val_Musculoskeletal has weight of -0.04645432036753759
# medical_specialty_Pediatrics has weight of -0.04078919713808576
# diag_3_val_Musculoskeletal has weight of -0.03856138295745341
# meds_increased_1 has weight of -0.034297723001955764
# num_procedures has weight of -0.02855363501725008
# medical_specialty_Psychiatry-Child/Adolescent has weight of -0.022000195890112585
# race_Hispanic has weight of -0.012000018870547921
# diag_3_val_Circulatory has weight of -0.010418357093174312
# medical_specialty_Urology has weight of -0.009791508904682915
# diag_1_val_Musculoskeletal has weight of -0.007888170541444766
# time_in_hospital has weight of -0.0021977575782059656
# medical_specialty_Perinatology has weight of 0.0
# medical_specialty_Psychiatry-Addictive has weight of 0.0
# medical_specialty_Speech has weight of 0.0
# medical_specialty_Anesthesiology-Pediatric has weight of 0.0019949182760501845
# diag_1_val_Other has weight of 0.004433456016631884
# num_lab_procedures has weight of 0.00458322500836912
# medical_specialty_Family/GeneralPractice has weight of 0.009300627186455721
# num_medications has weight of 0.010728770461811159
# A1Cresult_None has weight of 0.01309931713466418
# diag_2_val_Neoplasms has weight of 0.013963709676904182
# diag_2_val_Genitourinary has weight of 0.018236931919703627
# medical_specialty_Obsterics&Gynecology-GynecologicOnco has weight of 0.01881813775436528
# admission_type_id_6 has weight of 0.019309328600607727
# diag_1_val_Digestive has weight of 0.021149724689075555
# diag_3_val_Digestive has weight of 0.02123844278031618
# medication_count has weight of 0.022167019550120074
# diag_3_val_Respiratory has weight of 0.02422739709575875
# medical_specialty_Surgery-General has weight of 0.024360529203004626
# admission_source_id_22 has weight of 0.025750455924587676
# diag_2_val_Respiratory has weight of 0.028742986438939865
# medical_specialty_Ophthalmology has weight of 0.03295541420361924
# diag_2_val_Circulatory has weight of 0.035557717210308676
# diag_1_val_Respiratory has weight of 0.043819882101226136
# age has weight of 0.04787967601347445
# diag_3_val_Diabeties has weight of 0.05644407961828961
# diag_1_val_Circulatory has weight of 0.0590946973711384
# discharge_disposition_id_15 has weight of 0.06112431310240882
# discharge_disposition_id_22 has weight of 0.06258593954813528
# medical_specialty_Radiology has weight of 0.06693714579766703
# medical_specialty_SurgicalSpecialty has weight of 0.06987665479427707
# diag_3_val_Genitourinary has weight of 0.0752303641900043
# max_glu_serum_>300 has weight of 0.07612839106587836
# number_diagnoses has weight of 0.09019505184409948
# number_outpatient has weight of 0.09963788955997126
# race_AfricanAmerican has weight of 0.10281750053257398
# discharge_disposition_id_3 has weight of 0.11481830506779149
# medical_specialty_Hospitalist has weight of 0.12462514992467008
# medical_specialty_Unspecified has weight of 0.13172125168023205
# diag_2_val_Diabeties has weight of 0.1341582210388268
# race_Caucasian has weight of 0.13964379643738897
# medical_specialty_Radiologist has weight of 0.16657724844221117
# medical_specialty_Surgery-Plastic has weight of 0.17480237910251245
# medical_specialty_Emergency/Trauma has weight of 0.18684400518003041
# discharge_disposition_id_2 has weight of 0.19636581522596538
# medical_specialty_Nephrology has weight of 0.21258011869872875
# medical_specialty_Surgery-Colon&Rectal has weight of 0.21409987368339634
# diag_1_val_Diabeties has weight of 0.21539995359993572
# medical_specialty_OutreachServices has weight of 0.2196862621226919
# discharge_disposition_id_1 has weight of 0.2239149046652796
# medical_specialty_Pediatrics-EmergencyMedicine has weight of 0.24501722204573215
# discharge_disposition_id_12 has weight of 0.2627297896717295
# medical_specialty_Gastroenterology has weight of 0.2714746454300727
# number_emergency has weight of 0.27431256445255553
# medical_specialty_Surgery-Vascular has weight of 0.3004255919743866
# medical_specialty_Pediatrics-CriticalCare has weight of 0.3027143501306191
# discharge_disposition_id_10 has weight of 0.3097474456382699
# medical_specialty_Hematology/Oncology has weight of 0.3396882194102057
# discharge_disposition_id_28 has weight of 0.35598802084311054
# number_inpatient has weight of 0.360862162338417
# medical_specialty_AllergyandImmunology has weight of 0.36249531538770635
# medical_specialty_Osteopath has weight of 0.36293968090699746
# discharge_disposition_id_6 has weight of 0.36784151811150056
# medical_specialty_Dentistry has weight of 0.3831785563824489
# medical_specialty_SportsMedicine has weight of 0.3951630823784943
# medical_specialty_Pathology has weight of 0.41685530040598595
# medical_specialty_InfectiousDiseases has weight of 0.43578418610294756
# medical_specialty_Dermatology has weight of 0.445034075075801
# discharge_disposition_id_4 has weight of 0.4472657699461308
# medical_specialty_Surgery-PlasticwithinHeadandNeck has weight of 0.4687853085295388
# medical_specialty_PhysicianNotFound has weight of 0.48607383302827
# medical_specialty_Resident has weight of 0.49241439325517045
# medical_specialty_Pediatrics-InfectiousDiseases has weight of 0.5077137324020952
# discharge_disposition_id_16 has weight of 0.5096522236788491
# medical_specialty_Pediatrics-AllergyandImmunology has weight of 0.6106735150988032
# medical_specialty_Podiatry has weight of 0.6130827944136504
# discharge_disposition_id_5 has weight of 0.6284447647867879
# medical_specialty_Cardiology-Pediatric has weight of 0.9433680108573387
# medical_specialty_Pediatrics-Pulmonology has weight of 1.0152659526246244
# discharge_disposition_id_8 has weight of 1.5748585081571949
# discharge_disposition_id_7 has weight of 2.143736208874352
# discharge_disposition_id_23 has weight of 2.3084030482965456
# discharge_disposition_id_9 has weight of 2.3958789630634274
# admission_source_id_25 has weight of 3.223653236134182
# admission_source_id_10 has weight of 3.277900304420512
# admission_type_id_7 has weight of 3.5933270940449242

# %% [markdown]
# ### LR 4+

# %% [markdown]
# ###### Other model results
# Below are accuracy results of other models we tried during our evaluation, but decided to not  showcase as their results were not nessecarily superiror to those above.
#
# * Cross Validation, no medications, with SGD - ACC: 58.9%
#
# * No medications, No scaling - ACC: 66.9%
#
# * No medications, scaled - ACC: 66.9%
#
# * Medications, scaled - ACC: 67%

# %% [markdown]
# ## Support Vector Machine Models

# %% [markdown]
# ### Data Pre-processing and Transformations for SVM

# %%
#Reimporting the data to ensure transformations are not persisted from above analysis.
directory = 'C:/githubrepo/7331_Project/data/'
df = pd.read_csv(directory + 'Diabetic_Cleaned.csv')
df_clean = df
df_clean.replace('?', np.nan, inplace=True)

# %% [markdown]
# We found num_lab_procedures is highly correlated with admission_type_id during EDA. So we would exclude one of them in our model. Below we describe of some of the categorical variables for context in the analysis.

# %%
df_clean[['age','gender','race','diag_1_val','diag_2_val',"admission_source","admission_type","discharge_disposition","insulin"]].describe().transpose()
# Out:
#                         count unique                 top   freq
# age                    101766     10             [70-80)  26068
# gender                 101766      2              Female  54711
# race                   101766      6           Caucasian  76099
# diag_1_val             101766     10         Circulatory  30437
# diag_2_val             101766     10         Circulatory  31881
# admission_source        95783     14  Physician Referral  36269
# admission_type          97684      7           Emergency  32219
# discharge_disposition   98086     25  Discharged to home  55967
# insulin                101766      4                  No  47497

# %% [markdown]
# Because the gender attribute binary, there is no need to encode it using OneHotEncoding. We can just convert it to an integer. Age can be coded into int since it is ordinal. However, we should transform the race, diag_1_val attributes to take on different values--one for each possible variable outcome. One hot encoding is all about making the euclid distances even among levels of features.
#
# Preparing the data for SVM ideally including the following steps in the sequence: one hot encoding, normalize (to make the features contribute equally in euclid distance), PCA, use principle comp for SVM. Refer to this paper for more info on FE:
# https://media.licdn.com/dms/document/C4D1FAQGdKsBchRiF7A/feedshare-document-pdf-analyzed/0?e=1560106800&v=beta&t=toMignhoXC9PRfpoHkzKawyxUSjSCMeZJnBsoPn_SUo. This paper also mentioned log feature help with the skewness. We will use these techniques in the numerous SVM models we train below.

# %%
# Gender transformation
#can also use binary encoder to achieve this
df_clean.gender[df_clean.gender == 'Male'] = 0
df_clean.gender[df_clean.gender == 'Female'] = 1

df_clean["gender"] = df_clean["gender"].astype(int)

# %%
#10 age groups; Ordinal encoding
#feature density plot of age can help with answering the question like: does people older age tend to be readmitted?
#can use map/apply function to achieve this

df_clean.age[df_clean.age== '[0-10)'] = 1
df_clean.age[df_clean.age== '[10-20)'] = 2
df_clean.age[df_clean.age== '[20-30)'] = 3
df_clean.age[df_clean.age== '[30-40)'] = 4
df_clean.age[df_clean.age== '[40-50)'] = 5
df_clean.age[df_clean.age== '[50-60)'] = 6
df_clean.age[df_clean.age== '[60-70)'] = 7
df_clean.age[df_clean.age== '[70-80)'] = 8
df_clean.age[df_clean.age== '[80-90)'] = 9
df_clean.age[df_clean.age== '[90-100)'] = 10

df_clean["age"] = df_clean["age"].astype(int)

# %%
#one hot encoding categorical variables
#FE based on Feature Importance plot from LR model
#add more important features: discharge_disposition_id, admission_source_id. 
#I think they should be categorical, so I put them in dummy list

dummiesList=["diag_1_val","diag_2_val","diag_3_val","race","A1Cresult","admission_type","insulin","admission_source","discharge_disposition"]
df_clean_wDummies = pd.get_dummies(df_clean[dummiesList])

# %%
#combine with numerical features we decide to use and target readmitted_tf

NumFeatures=["num_lab_procedures","number_outpatient","number_emergency", "number_inpatient", "medication_count","number_diagnoses", "gender","age","readmitted_tf"]
df_clean_wDummies= pd.concat((df_clean_wDummies, df_clean[NumFeatures]), axis=1)

# %%
#More transformation for SVM analysis
if 'Lnumber_emergency' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_emergency'] 
    # if 'number_emergency' column still exists, delete it (as we created an ismale column)
if 'Lnum_diagnoses' in df_clean_wDummies:
    del df_clean_wDummies['Lnum_diagnoses']
if 'Lnumber_outpatient' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_outpatient']    
    
if 'Lnum_lab_procedures' in df_clean_wDummies:
    del df_clean_wDummies['Lnum_lab_procedures'] 
if 'Lnumber_inpatient' in df_clean_wDummies:
    del df_clean_wDummies['Lnumber_inpatient']

# %%
# Ensuring we have all the correct data types for analysis. 
df_clean_wDummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 99 columns):
# diag_1_val_Circulatory                                                                                                             101766 non-null uint8
# diag_1_val_Diabeties                                                                                                               101766 non-null uint8
# diag_1_val_Digestive                                                                                                               101766 non-null uint8
# diag_1_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_1_val_Injury                                                                                                                  101766 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_1_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_1_val_None                                                                                                                    101766 non-null uint8
# diag_1_val_Other                                                                                                                   101766 non-null uint8
# diag_1_val_Respiratory                                                                                                             101766 non-null uint8
# diag_2_val_Circulatory                                                                                                             101766 non-null uint8
# diag_2_val_Diabeties                                                                                                               101766 non-null uint8
# diag_2_val_Digestive                                                                                                               101766 non-null uint8
# diag_2_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_2_val_Injury                                                                                                                  101766 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_2_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_2_val_None                                                                                                                    101766 non-null uint8
# diag_2_val_Other                                                                                                                   101766 non-null uint8
# diag_2_val_Respiratory                                                                                                             101766 non-null uint8
# diag_3_val_Circulatory                                                                                                             101766 non-null uint8
# diag_3_val_Diabeties                                                                                                               101766 non-null uint8
# diag_3_val_Digestive                                                                                                               101766 non-null uint8
# diag_3_val_Genitourinary                                                                                                           101766 non-null uint8
# diag_3_val_Injury                                                                                                                  101766 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         101766 non-null uint8
# diag_3_val_Neoplasms                                                                                                               101766 non-null uint8
# diag_3_val_None                                                                                                                    101766 non-null uint8
# diag_3_val_Other                                                                                                                   101766 non-null uint8
# diag_3_val_Respiratory                                                                                                             101766 non-null uint8
# race_AfricanAmerican                                                                                                               101766 non-null uint8
# race_Asian                                                                                                                         101766 non-null uint8
# race_Caucasian                                                                                                                     101766 non-null uint8
# race_Hispanic                                                                                                                      101766 non-null uint8
# race_Other                                                                                                                         101766 non-null uint8
# race_Unspecified                                                                                                                   101766 non-null uint8
# A1Cresult_>7                                                                                                                       101766 non-null uint8
# A1Cresult_>8                                                                                                                       101766 non-null uint8
# A1Cresult_None                                                                                                                     101766 non-null uint8
# A1Cresult_Norm                                                                                                                     101766 non-null uint8
# admission_type_Elective                                                                                                            101766 non-null uint8
# admission_type_Emergency                                                                                                           101766 non-null uint8
# admission_type_Newborn                                                                                                             101766 non-null uint8
# admission_type_Not Available                                                                                                       101766 non-null uint8
# admission_type_Not Mapped                                                                                                          101766 non-null uint8
# admission_type_Trauma Center                                                                                                       101766 non-null uint8
# admission_type_Urgent                                                                                                              101766 non-null uint8
# insulin_Down                                                                                                                       101766 non-null uint8
# insulin_No                                                                                                                         101766 non-null uint8
# insulin_Steady                                                                                                                     101766 non-null uint8
# insulin_Up                                                                                                                         101766 non-null uint8
# admission_source_Clinic Referral                                                                                                   101766 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             101766 non-null uint8
# admission_source_Emergency Room                                                                                                    101766 non-null uint8
# admission_source_Extramural Birth                                                                                                  101766 non-null uint8
# admission_source_HMO Referral                                                                                                      101766 non-null uint8
# admission_source_Not Available                                                                                                     101766 non-null uint8
# admission_source_Not Mapped                                                                                                        101766 non-null uint8
# admission_source_Physician Referral                                                                                                101766 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           101766 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    101766 non-null uint8
# admission_source_Transfer from a hospital                                                                                          101766 non-null uint8
# admission_source_Transfer from another health care facility                                                                        101766 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            101766 non-null uint8
# admission_source_Transfer from hospital inpt/same fac reslt in a sep claim                                                         101766 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    101766 non-null uint8
# discharge_disposition_Discharged to home                                                                                           101766 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to a federal health care facility.                                                    101766 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         101766 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      101766 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             101766 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        101766 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         101766 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                101766 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      101766 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    101766 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  101766 non-null uint8
# discharge_disposition_Expired                                                                                                      101766 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     101766 non-null uint8
# discharge_disposition_Expired in a medical facility. Medicaid only, hospice.                                                       101766 non-null uint8
# discharge_disposition_Hospice / home                                                                                               101766 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   101766 non-null uint8
# discharge_disposition_Left AMA                                                                                                     101766 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                101766 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   101766 non-null uint8
# discharge_disposition_Still patient or expected to return for outpatient services                                                  101766 non-null uint8
# num_lab_procedures                                                                                                                 101766 non-null int64
# number_outpatient                                                                                                                  101766 non-null int64
# number_emergency                                                                                                                   101766 non-null int64
# number_inpatient                                                                                                                   101766 non-null int64
# medication_count                                                                                                                   101766 non-null int64
# number_diagnoses                                                                                                                   101766 non-null int64
# gender                                                                                                                             101766 non-null int32
# age                                                                                                                                101766 non-null int32
# readmitted_tf                                                                                                                      101766 non-null int64
# dtypes: int32(2), int64(7), uint8(90)
# memory usage: 14.9 MB

# %% [markdown]
# ### Training and Testing Split for SVM

# %%
df_imputed=df_clean_wDummies

from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'readmitted_tf' in df_imputed:
    y = df_imputed['readmitted_tf'].values # get the labels we want
    del df_imputed['readmitted_tf'] # get rid of the class label
    X = df_imputed.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
## Training and Testing Split
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

# %%
# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)
from sklearn.preprocessing import StandardScaler
scl_obj = StandardScaler()

scl_obj.fit(X_train)
X_test_scaled = scl_obj.transform(X_test)

X_train_scaled = scl_obj.transform(X_train) 
# apply to training
X_test_scaled = scl_obj.transform(X_test)
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### SVM 1 - SVM w/ RBF Kernel

# %%
##Warning: this cell takes approx 14 minutes run time
#%%time
from sklearn.svm import SVC

# Train model
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

# %%
from sklearn import metrics as mt

#Obtaining accuracy for SVM 
acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)

#Output upfront in case of differing results when running on different computer
#accuracy: 0.6822246241525007
#[[9460 1446]
# [5022 4426]]
# Out:
# accuracy: 0.5391077920801808
# [[10667   373]
#  [ 9008   306]]

# %%
# Looking at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (58433, 98)
# (58433,)
# [29672 28761]

# %%
# Now let's do some different analysis with the SVM and look at the instances that were chosen as support vectors

# Now lets look at the support for the vectors and see if we they are indicative of anything
# grab the rows that were selected as support vectors 
#(these are usually instances that are hard to classify)

# make a dataframe of the training data
df_tested_on = df_imputed.iloc[train_indices] # saved from above, the indices chosen for training
# now get the support vectors from the trained model
df_support = df_tested_on.iloc[svm_clf.support_,:]

df_support['readmitted_tf'] = y[svm_clf.support_] # add back in the 'Survived' Column to the pandas dataframe
df_imputed['readmitted_tf'] = y # also add it back in for the original data
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77008 entries, 54306 to 48603
# Data columns (total 99 columns):
# diag_1_val_Circulatory                                                                                                             77008 non-null uint8
# diag_1_val_Diabeties                                                                                                               77008 non-null uint8
# diag_1_val_Digestive                                                                                                               77008 non-null uint8
# diag_1_val_Genitourinary                                                                                                           77008 non-null uint8
# diag_1_val_Injury                                                                                                                  77008 non-null uint8
# diag_1_val_Musculoskeletal                                                                                                         77008 non-null uint8
# diag_1_val_Neoplasms                                                                                                               77008 non-null uint8
# diag_1_val_None                                                                                                                    77008 non-null uint8
# diag_1_val_Other                                                                                                                   77008 non-null uint8
# diag_1_val_Respiratory                                                                                                             77008 non-null uint8
# diag_2_val_Circulatory                                                                                                             77008 non-null uint8
# diag_2_val_Diabeties                                                                                                               77008 non-null uint8
# diag_2_val_Digestive                                                                                                               77008 non-null uint8
# diag_2_val_Genitourinary                                                                                                           77008 non-null uint8
# diag_2_val_Injury                                                                                                                  77008 non-null uint8
# diag_2_val_Musculoskeletal                                                                                                         77008 non-null uint8
# diag_2_val_Neoplasms                                                                                                               77008 non-null uint8
# diag_2_val_None                                                                                                                    77008 non-null uint8
# diag_2_val_Other                                                                                                                   77008 non-null uint8
# diag_2_val_Respiratory                                                                                                             77008 non-null uint8
# diag_3_val_Circulatory                                                                                                             77008 non-null uint8
# diag_3_val_Diabeties                                                                                                               77008 non-null uint8
# diag_3_val_Digestive                                                                                                               77008 non-null uint8
# diag_3_val_Genitourinary                                                                                                           77008 non-null uint8
# diag_3_val_Injury                                                                                                                  77008 non-null uint8
# diag_3_val_Musculoskeletal                                                                                                         77008 non-null uint8
# diag_3_val_Neoplasms                                                                                                               77008 non-null uint8
# diag_3_val_None                                                                                                                    77008 non-null uint8
# diag_3_val_Other                                                                                                                   77008 non-null uint8
# diag_3_val_Respiratory                                                                                                             77008 non-null uint8
# race_AfricanAmerican                                                                                                               77008 non-null uint8
# race_Asian                                                                                                                         77008 non-null uint8
# race_Caucasian                                                                                                                     77008 non-null uint8
# race_Hispanic                                                                                                                      77008 non-null uint8
# race_Other                                                                                                                         77008 non-null uint8
# race_Unspecified                                                                                                                   77008 non-null uint8
# A1Cresult_>7                                                                                                                       77008 non-null uint8
# A1Cresult_>8                                                                                                                       77008 non-null uint8
# A1Cresult_None                                                                                                                     77008 non-null uint8
# A1Cresult_Norm                                                                                                                     77008 non-null uint8
# admission_type_Elective                                                                                                            77008 non-null uint8
# admission_type_Emergency                                                                                                           77008 non-null uint8
# admission_type_Newborn                                                                                                             77008 non-null uint8
# admission_type_Not Available                                                                                                       77008 non-null uint8
# admission_type_Not Mapped                                                                                                          77008 non-null uint8
# admission_type_Trauma Center                                                                                                       77008 non-null uint8
# admission_type_Urgent                                                                                                              77008 non-null uint8
# insulin_Down                                                                                                                       77008 non-null uint8
# insulin_No                                                                                                                         77008 non-null uint8
# insulin_Steady                                                                                                                     77008 non-null uint8
# insulin_Up                                                                                                                         77008 non-null uint8
# admission_source_Clinic Referral                                                                                                   77008 non-null uint8
# admission_source_Court/Law Enforcement                                                                                             77008 non-null uint8
# admission_source_Emergency Room                                                                                                    77008 non-null uint8
# admission_source_Extramural Birth                                                                                                  77008 non-null uint8
# admission_source_HMO Referral                                                                                                      77008 non-null uint8
# admission_source_Not Available                                                                                                     77008 non-null uint8
# admission_source_Not Mapped                                                                                                        77008 non-null uint8
# admission_source_Physician Referral                                                                                                77008 non-null uint8
# admission_source_Transfer from Ambulatory Surgery Center                                                                           77008 non-null uint8
# admission_source_Transfer from a Skilled Nursing Facility (SNF)                                                                    77008 non-null uint8
# admission_source_Transfer from a hospital                                                                                          77008 non-null uint8
# admission_source_Transfer from another health care facility                                                                        77008 non-null uint8
# admission_source_Transfer from critical access hospital                                                                            77008 non-null uint8
# admission_source_Transfer from hospital inpt/same fac reslt in a sep claim                                                         77008 non-null uint8
# discharge_disposition_Admitted as an inpatient to this hospital                                                                    77008 non-null uint8
# discharge_disposition_Discharged to home                                                                                           77008 non-null uint8
# discharge_disposition_Discharged/transferred to ICF                                                                                77008 non-null uint8
# discharge_disposition_Discharged/transferred to SNF                                                                                77008 non-null uint8
# discharge_disposition_Discharged/transferred to a federal health care facility.                                                    77008 non-null uint8
# discharge_disposition_Discharged/transferred to a long term care hospital.                                                         77008 non-null uint8
# discharge_disposition_Discharged/transferred to a nursing facility certified under Medicaid but not certified under Medicare.      77008 non-null uint8
# discharge_disposition_Discharged/transferred to another rehab fac including rehab units of a hospital.                             77008 non-null uint8
# discharge_disposition_Discharged/transferred to another short term hospital                                                        77008 non-null uint8
# discharge_disposition_Discharged/transferred to another type of inpatient care institution                                         77008 non-null uint8
# discharge_disposition_Discharged/transferred to home under care of Home IV provider                                                77008 non-null uint8
# discharge_disposition_Discharged/transferred to home with home health service                                                      77008 non-null uint8
# discharge_disposition_Discharged/transferred within this institution to Medicare approved swing bed                                77008 non-null uint8
# discharge_disposition_Discharged/transferred/referred another institution for outpatient services                                  77008 non-null uint8
# discharge_disposition_Discharged/transferred/referred to a psychiatric hospital of psychiatric distinct part unit of a hospital    77008 non-null uint8
# discharge_disposition_Discharged/transferred/referred to this institution for outpatient services                                  77008 non-null uint8
# discharge_disposition_Expired                                                                                                      77008 non-null uint8
# discharge_disposition_Expired at home. Medicaid only, hospice.                                                                     77008 non-null uint8
# discharge_disposition_Expired in a medical facility. Medicaid only, hospice.                                                       77008 non-null uint8
# discharge_disposition_Hospice / home                                                                                               77008 non-null uint8
# discharge_disposition_Hospice / medical facility                                                                                   77008 non-null uint8
# discharge_disposition_Left AMA                                                                                                     77008 non-null uint8
# discharge_disposition_Neonate discharged to another hospital for neonatal aftercare                                                77008 non-null uint8
# discharge_disposition_Not Mapped                                                                                                   77008 non-null uint8
# discharge_disposition_Still patient or expected to return for outpatient services                                                  77008 non-null uint8
# num_lab_procedures                                                                                                                 77008 non-null int64
# number_outpatient                                                                                                                  77008 non-null int64
# number_emergency                                                                                                                   77008 non-null int64
# number_inpatient                                                                                                                   77008 non-null int64
# medication_count                                                                                                                   77008 non-null int64
# number_diagnoses                                                                                                                   77008 non-null int64
# gender                                                                                                                             77008 non-null int32
# age                                                                                                                                77008 non-null int32
# readmitted_tf                                                                                                                      77008 non-null int64
# dtypes: int32(2), int64(7), uint8(90)
# memory usage: 11.9 MB

# %%
# now lets see the statistics of these attributes
from pandas.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['readmitted_tf'])
df_grouped = df_imputed.groupby(['readmitted_tf'])

# plot KDE of Different variables
vars_to_plot = ['age','gender','num_lab_procedures','medication_count']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Original)')

# %% [markdown]
# ### SVM 2 -- Linear Kernel for SVM

# %%
## Warning: this cell takes 45+ minutes to run 
#Try linear kernel for SVM
#Run linear kernel once to show that has lower accuracy for our dataset. The reason can be seen from PCA plots. PCA plots here show our data is not linearaly separable. (We did not reduce dimensions in this case, so we did not create a scree plot.)


#did not update every time, just run once to show that linear kernel has lower accuracy in our data.
#try linear kernel, 25 mins run , ACC worse
#more feature engineering can be done to improve the acc
from sklearn.svm import SVC
# train the model just as before
svm_clf = SVC(C=0.5, kernel='linear', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object
y_hat = svm_clf.predict(X_test_scaled)
#print("Done")

# %%
from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)

#Because this takes so long to run, we included the accuracy and confusion matrix
#below because we ran out of time when when combines our separate ipynb files.

#accuracy: 0.614031639972487
#[[9672 1312]
# [6544 2826]]

# %% [markdown]
# Create PCA plot to see if our dataset is linearaly separable

# %%
#WARNING: Takes 1 hour to run
#reduce dimensionality of data set to 2 feauters.
from sklearn.decomposition import PCA
pca = PCA(n_components=2).fit(X_train)
pca_2d = pca.transform(X_train)


#part of the code was taken from:
#http://www.dummies.com/programming/big-data/data-science/how-to-visualize-the-classifier-in-an-svm-supervised-learning-model/
import pylab as pl
plt.figure(figsize=(20,15))
for i in range(0, pca_2d.shape[0]):
    if y_train[i] == 0:
        c1 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='r', s=1,marker='+')
    elif y_train[i] == 1:
        c2 = pl.scatter(pca_2d[i,0],pca_2d[i,1],c='g', s=20,marker='*')
pl.legend([c1, c2], ['Not readmitted', 'Readmitted'])
pl.title('Diabetes data set')
pl.show()

# %% [markdown]
# Here is the output of the above PCA code.

# %%
from IPython.display import Image
Image(filename='C:/Users/Zack/Desktop/PCA without log num.png')

# %% [markdown]
# The PCA plot below is for dataset with log transformation of numerical variables. From these plots we can see, log transformation of numerical variables change the look of pca plot siginficantly. Both PCA plots show our data is not linearaly separable.

# %%
from IPython.display import Image
Image(filename='/Users/samanthasprague/Downloads/PCA1.png')

# %% [markdown]
# ### SVM 3 -- SGD SVM

# %%
# %%time

#SGD made SVM model train fast. this was done in seconds comparing with no SGD 14 mins run.
from sklearn.model_selection import StratifiedShuffleSplit 
from sklearn import metrics as mt
cv = StratifiedShuffleSplit( n_splits=1,test_size=0.5)
# use some compact notation for creating a linear SVM classifier with stichastic descent
from sklearn.linear_model import SGDClassifier

regularize_const = 0.1
iterations = 5
svm_sgd = SGDClassifier(alpha=regularize_const,
        fit_intercept=True, l1_ratio=0.0, learning_rate='optimal',
        loss='hinge', n_iter=iterations, n_jobs=-1, penalty='l2')

scl = StandardScaler()
for train_idx, test_idx in cv.split(X,y):
    svm_sgd.fit(scl.fit_transform(X[train_idx]),y[train_idx])
    yhat = svm_sgd.predict(scl.transform(X[test_idx]))
    
    conf = mt.confusion_matrix(y[test_idx],yhat)
    acc = mt.accuracy_score(y[test_idx],yhat)

print('SVM_SGD:', acc)
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:152: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SVM_SGD: 0.6558772084979266
# Wall time: 502 ms
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# Runtime comparsion of SVM vs. SVM_SGD
# From the results below, we can see SVM_SGD runs 1000X faster than SVM, from 14 mins in SVM to 708 ms in SVM_SGD. SGD does help the SVM model to trian in a reasonable timeframe.

# %% [markdown]
# ## SVM 4+ Models:
# A number of models were built to explore on the effect of log transformation of numerical variables and feature engineering. We did not include the code for all of them, but we summarize the performances of all models below. Below is a summary of the models used above for SVM 1-3. These models used extensive feature creation methods to gain similar accuracies to the LR models above.
#
# SVM 1 SVM - RBF: 0.6822
#
# SVM 2 SVM - Linear: 0.6140
#
# SVM 3 SVM SGD - RBF: 0.6554
#
#
# Other models built but not present in this analysis notebook are below. Bold are the variations made on the input data to asses performance. These models did not provide the same accuracy as advanced feature creation, but were important in demonstrating the evolution of the models built, and how we arose at the best accuracies of SVMs above.
#
# **Basic model without log num - baseline:**
# * SVM RBF: 0.6293
# * SVM SGD - RBF: 0.6098
# Note: Data was not linearly seperable so decided to use rbf in future models
#
# **Updated with log num:**
# * SVM RBF: 0.6202
# * SVM SGD - RBF: 0.6136
#
# **Log num features add more features to increase acc**
# * SVM - RBF: 0.6526
# * SVM SGD - RBF: 0.6361
#
# **Without log num add more features to increase acc**
# * SVM - RBF :0.6588
# * SVM SGD - RBF: 0.6337
#
# More analysis on methods to avoid long training times can be seen in the execeptional work section of this notebook. In addition, we used Gridsearch in order to tune hyper parameters for SVM.

# %% [markdown]
# <a id="ModelAdvantages"></a>
# ## Model Advantages

# %% [markdown]
# **Requirements:** Discuss the advantages of each model for each classification task. Does one type of model offer superior performance over another in terms of prediction accuracy? In terms of training time or efficiency?

# %% [markdown]
# ### Advantages to Logistic Regression Models

# %% [markdown]
# **Answer:**
# * Logistic regression models are easier to inperpret and understand
# * Have less barriers to entry on the code required to produce a result and intepret
# * Training code runs in a few seconds
# * Feature engineering is easy to apply and manipulate for better results
# * Less parameters to tweak/tune for performance gain
# * For this application, the accuracy was nearly identical

# %% [markdown]
# ### Advantages to Support Vector Machine Models

# %% [markdown]
# **Answer:**
# * SVMs can unlock complex relationships not always indentified with LRs
# * Has more parameters that allow for specific tuning
# * Has non-parametric option (RBF, aka the Kernel Trick) for increase in accuracy
# * See a large performance gain for training time when leveraging SGD
# * Can be used for many data types
# * Not as sensitive to outliers compared to LR
# * SVM has less predicition time because only points near the boundary make a difference

# %% [markdown]
# ### Question: Does one type of model offer superior performance over another in terms of prediction accuracy? In terms of training time or efficiency?

# %% [markdown]
# ###### Performance Evalution: Accuracy

# %% [markdown]
# | Model Type | Accuracy | AUC |
# |------------|----------|-----|
# |Logistic Regression 1: OHE, Not Scaled, No Medications | 67% | 74% |
# |Logistic Regression 2: SGD, OHE, Not Scaled, No Medications | 58% | 61% |
# |Logistic Regression 3: OHE, Scaled, Medications, Loop | 66% | 73% |
#
#
# | Model Type | Accuracy |
# |------------|----------|
# |Support Vector Machine 1: RBF Kernel | 68% |
# |Support Vector Machine 2: Linear Kernel | 61% |
# |Support Vector Machine 3: SGD SVM RBF Kernel | 65%|

# %% [markdown]
# **Answer:** After extensive analysis, we were able to produce accarcies of rough 67-68% for both SVM and LR models. However, it should be noted that the complexity of SVMs provided a lot of hurdles in producing a model that would perform at the same level as the LR using the exact same input data. The time it took to train SVMs provided a lot of hurdles to producing better accuracies. There was far more innovation in creating new features and optimizing run time with the SVM models. While leveraging SGD gave improvements to training time for both the LR and SVM models, we wanted to be able to evaluate how leverage SGD would effect the performace from an accuracy perspective. You can see the using SGD for the logistic regression model drops the accuracy drastically from 67% to 58%. You can also see from the tables above that leveraging a linear kernel in an SVM also gave sub-par performance. This is likely due to the fact that our data is not linearly seperable. The SGD SVM RBF gives a a 3% drop in accuracy when using the same inputs. Throughout our analysis we were able to improve our model accuracies from approximately 58% to 68% leveraging innovation in new features and model tuning parameters.

# %% [markdown]
# ###### Performance Evaluation: Training Time and Effeiciency

# %% [markdown]
# | Model Type | Training Time |
# |------------|---------------|
# |Logistic Regression 1: OHE, Not Scaled, No Medications| 15.4 seconds |
# |Logistic Regression 2: SGD, OHE, Not Scaled, No Medications| 8 seconds |
# |Logistic Regression 3: OHE, Scaled, Medications, Loop| 20 seconds |
# |Support Vector Machine 1: RBF Kernel | 14 minutes|
# |Support Vector Machine 2: Linear Kernel| 45+ minutes |
# |Support Vector Machine 3: SGD SVM | 7 seconds |

# %% [markdown]
# **Answer:** As you can see from the chart above, logistic regression models had a superior advantage over SVMs in terms of training time and efficiencies when leveraging traditional loss functions. It should be noted that times calculated during runtime displayed were on 2.7 GHz Intel Core i7 with 16 GB of Memory. The run time will differ when the machine exeucting the notebook differs. These times are merely approximate to showcase the magnitude difference from executing an LR to an SVM. This can have major advantages when using large data if the performance of these models are similar. It does not make sense to leverage an SVM unless it provides superior performance to a LR. In our case, the SVM algorithm does not seem to help with preditive power. It make more sense to leverage a LR model due to the effencies gained with an LR.
#
# It should also be noted here that used stochastic gradient decent provides a gain of effeicies to traditional loss functions in both the logistic regression models and SVMs. There is a very large gain of effeiciencies specifically with SVMs. You can see that the RBF Kernel for the traditional loss function takes approximately 14 mintues, where the SDG RBF Kernel takes 7 seconds to run. This provides a 1000x efficiency gain in using SGD for SVMs. The decrease in training for LR is also present, but not as drastic, dropping from 15 second to 8 seconds. Again, these are approximately time values calculated at run time on a MacOS. You can see from the table indicating accuracy, however, that this increase in efficiency for trainings does come with a slight decline in performance. Both the LR and SVM models produced saw a decline in performance when leveraging the SGD. When leveraging large data sets, it should be noted that SGD provides greater gain of efficiencies, but needs to be balanced against the loss of performance.

# %% [markdown]
# <a id="InterpretFeatureImportance"></a>
# ## Interpret Feature Importance

# %% [markdown]
# **Requirements:** Use the weights from logistic regression to interpret the importance of different features for the classification task. Explain your interpretation in detail. Why do you think some variables are more important?

# %% [markdown]
# Below is a table representation of the most important variables on readmission for diabetes from LR 3. This analysis looks at variables that are likely to both increase and decrease readmission. All variables examined below are specifically called out in the table below.

# %% [markdown]
# | Co-efficent | Name | Value |
# |------------|-------| ------|
# |$\beta_{1}$| Discharge_Disposition_ID_11 | -0.873 |
# |$\beta_{2}$| Discharge_Disposition_ID_14 | -0.174 |
# |$\beta_{3}$| Discharge_Disposition_ID_23 | 0.373 |
# |$\beta_{4}$| Admission_Source_ID_2 | -0.120 |
# |$\beta_{5}$| Admission_Source_ID_10 | 0.508  |
# |$\beta_{6}$| Admission_Source_ID_25 | 0.491 |
# |$\beta_{7}$| Admission_Type_ID_7 | 0.585 |
# |$\beta_{8}$| Admission_Type_ID_3 | -0.106 |
# |$\beta_{9}$| Admission_Type_ID_4 | -0.12 |

# %% [markdown]
# For the entire set of predictors, we can use this below visualization to examine logistic weights.

# %%
#Bar plot of the coefficient weights
pd.Series(lr_clf.coef_[0].T,index = df_mlt_hot.columns).plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### Question:  Explain your interpretation in detail. Why do you think some variables are more important?

# %% [markdown]
# **Answer:**
# From sorting the weights of the variables in ascending order above, some variables have more importance then others because they have stronger predictive power. Variables with weights to the left from 0 are responsible for the higher chance of person NOT being readmitted and variables to the right from 0 are responsible for increasing of the chance of the person being readmitted. Seven (7) of the most important can be interpreted in the following way:
#
# * With a discharge disposition of either “Expired” (id 11) or “Hospice / medical facility” (id14), that patient would not likely be readmitted wheras a disposition of “Discharged/transferred to a long term care hospital” (id23) would more likely be re-admitted
#
# * If a patient admission source was a “Clinical Referral” (id 2), s/he would not likely be readmitted as if the admission was a “Transfer from critical access hospital” (id 10) or “Transfer from Ambulatory Surgery Center” (id 25).
#
# * Logically, a patient with an admission type of a “Trauma Center” (id 7) was more likely to be readmitted than a patient where the type is “Elective” (id 3) or “Newborn” (id 4).
#
# * The greater the number of times a patient was an inpatient, the less likely s/he would be readmitted. This is consistent with most treatment practices and insurance coverage. On the contrary, the less the number of times a patient was an outpatient, the more likely s/he would be readmitted.
#
# * Interestingly, the less the number of emergencies a patient had, the more likely s/he would be re-admitted.
#
# * With a range of 1-16 number of diagnoses, nine (9) diagnoses was the number where 49% of patients would likely be readmitted.
#
# * The greater the number of lab procedures a patient underwent suggests that the patient was slightly less likely to be readmitted than patients who did not have as many lab procedures.

# %% [markdown]
# <a id="InterpretSupportVectors"></a>
# ## Interpret Support Vectors

# %% [markdown]
# **Requirements:** Look at the chosen support vectors for the classification task. Do these provide any insight into the data? Explain.

# %% [markdown]
# Relooking at the support vectors from SVM 1, we have provided an analysis below:

# %%
# Taking the code from above and printing it again for easy analysis
# now lets see the statistics of these attributes
#from pandas.tools.plotting import boxplot

# group the original data and the support vectors
df_grouped_support = df_support.groupby(['readmitted_tf'])
df_grouped = df_imputed.groupby(['readmitted_tf'])

# plot KDE of Different variables
vars_to_plot = ['age','gender','num_lab_procedures','medication_count']

for v in vars_to_plot:
    plt.figure(figsize=(10,4))
    # plot support vector stats
    plt.subplot(1,2,1)
    ax = df_grouped_support[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Instances chosen as Support Vectors)')
    
    # plot original distributions
    plt.subplot(1,2,2)
    ax = df_grouped[v].plot.kde() 
    plt.legend(['readmitted_0','readmitted_1'])
    plt.title(v+' (Original)')

# %% [markdown]
# ### Question: Do these provide any insight into the data? Explain.

# %% [markdown]
# **Answer:** The feature density plots above show the comparison of the support vectors(left) and the the original feature(right). The feature density plots of age and medication_count vector are very similare to the original ones, showing the support vectors are the most useful data points that they represent the data structure of original data so well. When looking at gender vectors, it has similar to the original on readmitted_1 group but it has lower values in readmitted_0 group at gender 0 (male) comparing to the original data.
# When looking at num_lab_procedures vectors, it has similar to the original on readmitted_0 group but it has higher values in readmitted_1 group comparing to the original data.

# %% [markdown]
# <a id="Exceptional Work"></a>
# ## Exceptional Work

# %% [markdown]
# Below is code that uses subsampling techniques to help with training time of SVM, and other more advanced techniques like hyper-parameter tuning with GridsearchCV for SVM. These techniques demonstrate advanced knowledge of the model techniques and the in-depth understanding of how to tune SVM models for both effeciencies and performance.

# %% [markdown]
# #### Subsampling technique for SVM

# %%
#%%time
#SGD made SVM model train fast. This was done in seconds comparing with no SGD 14 mins run.
from sklearn.model_selection import StratifiedShuffleSplit 
from sklearn import metrics as mt
cv = StratifiedShuffleSplit( n_splits=1,test_size=0.5)
# use some compact notation for creating a linear SVM classifier with stichastic descent
from sklearn.linear_model import SGDClassifier

regularize_const = 0.1
iterations = 5
svm_sgd = SGDClassifier(alpha=regularize_const,
        fit_intercept=True, l1_ratio=0.0, learning_rate='optimal',
        loss='hinge', n_iter=iterations, n_jobs=-1, penalty='l2')

scl = StandardScaler()
for train_idx, test_idx in cv.split(X,y):
    svm_sgd.fit(scl.fit_transform(X[train_idx]),y[train_idx])
    yhat = svm_sgd.predict(scl.transform(X[test_idx]))
    
    conf = mt.confusion_matrix(y[test_idx],yhat)
    acc = mt.accuracy_score(y[test_idx],yhat)

print('SVM_SGD:', acc)
# Out:
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:152: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# SVM_SGD: 0.6614193345518149
# C:\ProgramData\Anaconda3\envs\DS7331_35r\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# #### GridSearchCV with subsampling w/ smaller parameter list

# %%
#GridSearchCV on subsample
from sklearn import svm, grid_search
from sklearn.model_selection import GridSearchCV

#for the sake of time, to make the run time reasonable, I used only 3 different values for C and 2 different values for gammas.
#runtime this way 3*2*3*10 mins=3hr
#otherwise it would take more than ten hours to run

def svc_param_selection(X, y, nfolds):
    Cs = [0.01, 0.5, 1]
    gammas = [0.1, 1]
    param_grid = {'C': Cs, 'gamma' : gammas}
    grid_search = GridSearchCV(svm.SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, y)
    grid_search.best_params_
    return grid_search.best_params_

# %%
#Warning: this section takes approx 20 min to run 
#%%time
svc_param_selection(X_train_scaled, y_train,3)
#{'C': 1, 'gamma': 0.1}

# %%
#1.6 mins
#%%time
#try SVM with parameters from svc_param_selection() function output c=1, gammas=0.1
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=1, kernel='rbf', degree=3, gamma=0.1) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)  


#Here is the output in case it takes a while to run
#accuracy: 0.6040284942274625
#[[1775  483]
# [1129  684]]

# %% [markdown]
# #### GridSearchCV with subsampling with larger parameter list

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm, grid_search
def svc_param_selection(X, y, nfolds):
    Cs = [0.001, 0.01, 0.1, 1, 10]
    gammas = [0.001, 0.01, 0.1, 1]
    param_grid = {'C': Cs, 'gamma' : gammas}
    grid_search = GridSearchCV(svm.SVC(kernel='rbf'), param_grid, cv=nfolds)
    grid_search.fit(X, y)
    grid_search.best_params_
    return grid_search.best_params_

# %%
##Warning: this code takes a long time to run -- Estimation 1 hr
#actual time
#%%time
svc_param_selection(X_train_scaled, y_train,3)

#Here is the output so you do not need to wait for it to run
#Wall time: 1h 15min 50s
#Out[55]:
#{'C': 1, 'gamma': 0.01}

# %%
#%%time
#try SVM with parameters from svc_param_selection() function output c=1, gammas=0.1
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=1, kernel='rbf', degree=3, gamma=0.01) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled)

from sklearn import metrics as mt

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)  


#Here is the accuracy so you do not need to run the code
#accuracy: 0.672316384180791
#[[1890  368]
# [ 966  847]]
#Wall time: 41.1 s

# %% [markdown]
# <a id="References"></a>
# ## References

# %% [markdown]
# World Health Organization. 10 Facts on Diabetes. https://www.who.int/features/factfiles/diabetes/en/
